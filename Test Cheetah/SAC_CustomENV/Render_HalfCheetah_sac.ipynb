# %%
import gymnasium as gym
import time
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Caricamento del modello
model = SAC.load("sac_HalfCheetah_model")  # Assicurati che il percorso sia corretto

# Creazione dell'ambiente *con* DummyVecEnv per VecNormalize
render_env = DummyVecEnv([lambda: gym.make("HalfCheetah-v5",
                        reset_noise_scale=0.13635555699602933,
                        forward_reward_weight=0.7151140526343989,
                        ctrl_cost_weight=0.19342622590821706,
                        render_mode='human')])  # Puoi cambiare 'human' con 'rgb_array'

# Caricamento della normalizzazione
render_env = VecNormalize.load("vecnormalize_HalfCheetah.pkl", render_env)  # Assicurati che il percorso sia corretto

render_env.training = False
render_env.norm_reward = True  # Normalizza anche le reward se vuoi

# Reset dell'ambiente
obs = render_env.reset()  # Ottieni le osservazioni (è un array numpy)

done = False

# Loop per eseguire il rendering
while not done:
    action, _ = model.predict(obs)
    obs, rewards, dones, infos = render_env.step(action)  # Corretto: 4 valori
    render_env.render()  # Mostra l'ambiente a schermo (se render_mode='human')
    time.sleep(0.01)

    # Gestione del 'done' (dones può essere un array anche con 1 solo env)
    done = dones[0]  # Prendo il primo elemento per il mio singolo ambiente

render_env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 30
#      28 while not done:
#      29     action, _ = model.predict(obs)
# ---> 30     obs, rewards, dones, infos = render_env.step(action)  # Corretto: 4 valori
#      31     render_env.render()  # Mostra l'ambiente a schermo (se render_mode='human')
#      32     time.sleep(0.01)
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:207, in VecEnv.step(self, actions)
#     200 """
#     201 Step the environments with the given action
#     202
#     203 :param actions: the action
#     204 :return: observation, reward, done, information
#     205 """
#     206 self.step_async(actions)
# --> 207 return self.step_wait()
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/vec_normalize.py:181, in VecNormalize.step_wait(self)
#     174 def step_wait(self) -> VecEnvStepReturn:
#     175     """
#     176     Apply sequence of actions to sequence of environments
#     177     actions -> (observations, rewards, dones)
#     178
#     179     where ``dones`` is a boolean vector indicating whether each element is new.
#     180     """
# --> 181     obs, rewards, dones, infos = self.venv.step_wait()
#     182     assert isinstance(obs, (np.ndarray, dict))  # for mypy
#     183     self.old_obs = obs
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/envs/mujoco/half_cheetah_v5.py:236, in HalfCheetahEnv.step(self, action)
#     233 info = {"x_position": x_position_after, "x_velocity": x_velocity, **reward_info}
#     235 if self.render_mode == "human":
# --> 236     self.render()
#     237 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     238 return observation, reward, False, False, info
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_env.py:164, in MujocoEnv.render(self)
#     160 def render(self):
#     161     """
#     162     Render a frame from the MuJoCo simulation as specified by the render_mode.
#     163     """
# --> 164     return self.mujoco_renderer.render(self.render_mode)
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:711, in MujocoRenderer.render(self, render_mode)
#     709     return viewer.render(render_mode=render_mode, camera_id=self.camera_id)
#     710 elif render_mode == "human":
# --> 711     return viewer.render()
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:437, in WindowViewer.render(self)
#     435         self._loop_count = 1
#     436     while self._loop_count > 0:
# --> 437         update()
#     438         self._loop_count -= 1
#     440 # clear overlay
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:418, in WindowViewer.render.<locals>.update()
#     408     for gridpos, [t1, t2] in self._overlays.items():
#     409         mujoco.mjr_overlay(
#     410             mujoco.mjtFontScale.mjFONTSCALE_150,
#     411             gridpos,
#    (...)
#     415             self.con,
#     416         )
# --> 418 glfw.swap_buffers(self.window)
#     419 glfw.poll_events()
#     420 self._time_per_render = 0.9 * self._time_per_render + 0.1 * (
#     421     time.time() - render_start
#     422 )
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/glfw/__init__.py:2380, in swap_buffers(window)
#    2373 def swap_buffers(window):
#    2374     """
#    2375     Swaps the front and back buffers of the specified window.
#    2376
#    2377     Wrapper for:
#    2378         void glfwSwapBuffers(GLFWwindow* window);
#    2379     """
# -> 2380     _glfw.glfwSwapBuffers(window)
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/glfw/__init__.py:687, in _prepare_errcheck.<locals>.errcheck(result, *args)
#     679 def _prepare_errcheck():
#     680     """
#     681     This function sets the errcheck attribute of all ctypes wrapped functions
#     682     to evaluate the _exc_info_from_callback global variable and re-raise any
#    (...)
#     685     using the _callback_exception_decorator.
#     686     """
# --> 687     def errcheck(result, *args):
#     688         global _exc_info_from_callback
#     689         if _exc_info_from_callback is not None:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
