# %%
import gymnasium as gym
import numpy as np
import os
import torch
import matplotlib.pyplot as plt
import imageio
import time

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback, CallbackList
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Numero di ambienti paralleli per il training
NUM_ENVS = 4

def make_env():
    return lambda: gym.make("HalfCheetah-v5", 
                            reset_noise_scale=0.18925327466415615,
                            forward_reward_weight=1.158890288504633,
                            ctrl_cost_weight=0.05108108521573771,
                            render_mode='none')

# Creazione degli ambienti per il training (DummyVecEnv per compatibilità con VecNormalize)
env = DummyVecEnv([make_env() for _ in range(NUM_ENVS)])
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# Selezione automatica del device (GPU/CPU)
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"

# Parametri del modello migliorati
model_params = {
    "policy": "MlpPolicy",
    "env": env,
    "learning_rate": 8.272618650819588e-05,
    "n_steps": 2048,
    "batch_size": 256,  # Multiplo di n_steps per stabilità
    "n_epochs": 10,
    "gamma": 0.9808272185952741,
    "gae_lambda": 0.9080997013001573,
    "clip_range": 0.2,  # Ridotto per maggiore stabilità
    "ent_coef": 0.05,  # Aumentato per migliorare esplorazione
    "verbose": 1,
    "tensorboard_log": "./ppo_HalfCheetah_tensorboard/",
    "device": "cpu",
    "policy_kwargs": dict(net_arch=[256, 256, 128])
}

# Funzione per creare l'ambiente di valutazione
def make_eval_env():
    return lambda: Monitor(gym.make("HalfCheetah-v5", 
                                    reset_noise_scale=0.18925327466415615,
                                    forward_reward_weight=1.158890288504633,
                                    ctrl_cost_weight=0.05108108521573771,
                                    render_mode='none'))

# Creazione dell'ambiente di valutazione
eval_env = DummyVecEnv([make_eval_env()])
eval_env = VecNormalize.load("vecnormalize_HalfCheetah.pkl", eval_env)

# Callback per valutazione e salvataggi
eval_callback = EvalCallback(eval_env, best_model_save_path="./logs/best_model",
                             log_path="./logs/", eval_freq=20000, deterministic=True, render=False)
checkpoint_callback = CheckpointCallback(save_freq=10000, save_path="./logs/checkpoints/",
                                         name_prefix="ppo_halfcheetah_checkpoint")

# Creazione e training del modello
model = PPO(**model_params)
model.learn(total_timesteps=1_000_000, callback=CallbackList([eval_callback, checkpoint_callback]))

# Salvataggio del modello e normalizzazione
model.save("ppo_HalfCheetah_model")
env.save("vecnormalize_HalfCheetah.pkl")

# Caricamento del modello e della normalizzazione per la valutazione
model = PPO.load("ppo_HalfCheetah_model", device=device)
eval_env = VecNormalize.load("vecnormalize_HalfCheetah.pkl", eval_env)
eval_env.training = False

def evaluate_agent(model, env, episodes=100):
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=episodes, deterministic=True)
    print(f"Mean Reward: {mean_reward:.2f} ± {std_reward:.2f}")
    return mean_reward, std_reward

# Valutazione del modello allenato
mean_reward_trained, std_reward_trained = evaluate_agent(model, eval_env, episodes=100)
# Out:
# Using cpu device
# Logging to ./ppo_HalfCheetah_tensorboard/PPO_12
# ------------------------------
# | time/              |       |
# |    fps             | 15666 |
# |    iterations      | 1     |
# |    time_elapsed    | 1     |
# |    total_timesteps | 16384 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8889        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008369913 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.57       |
# |    explained_variance   | -1.09       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.385      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00546    |
# |    std                  | 1.02        |
# |    value_loss           | 0.0704      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7815        |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008637838 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.67       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.427      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00709    |
# |    std                  | 1.03        |
# |    value_loss           | 0.0378      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7459        |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008201398 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.76       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.432      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00812    |
# |    std                  | 1.05        |
# |    value_loss           | 0.0475      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7273         |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0077569894 |
# |    clip_fraction        | 0.0738       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.84        |
# |    explained_variance   | 0.582        |
# |    learning_rate        | 8.27e-05     |
# |    loss                 | -0.431       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00773     |
# |    std                  | 1.06         |
# |    value_loss           | 0.0387       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7141        |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008282283 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.92       |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.433      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00856    |
# |    std                  | 1.08        |
# |    value_loss           | 0.0388      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7078       |
# |    iterations           | 7          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.00856209 |
# |    clip_fraction        | 0.0823     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.02      |
# |    explained_variance   | 0.615      |
# |    learning_rate        | 8.27e-05   |
# |    loss                 | -0.449     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00873   |
# |    std                  | 1.1        |
# |    value_loss           | 0.0345     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6976        |
# |    iterations           | 8           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008501987 |
# |    clip_fraction        | 0.0911      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.1        |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.443      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 1.11        |
# |    value_loss           | 0.0339      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6909        |
# |    iterations           | 9           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.008614077 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.18       |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.469      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 1.12        |
# |    value_loss           | 0.0294      |
# -----------------------------------------
# Eval num_timesteps=160000, episode_reward=-5.78 +/- 2.48
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -5.78       |
# | time/                   |             |
# |    total_timesteps      | 160000      |
# | train/                  |             |
# |    approx_kl            | 0.008578295 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.26       |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.457      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 1.14        |
# |    value_loss           | 0.0342      |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 6642   |
# |    iterations      | 10     |
# |    time_elapsed    | 24     |
# |    total_timesteps | 163840 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6646        |
# |    iterations           | 11          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008103596 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.33       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.466      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 1.15        |
# |    value_loss           | 0.0329      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6612        |
# |    iterations           | 12          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.009261889 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.4        |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.467      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 1.17        |
# |    value_loss           | 0.0326      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6606       |
# |    iterations           | 13         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.00922408 |
# |    clip_fraction        | 0.0979     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.48      |
# |    explained_variance   | 0.539      |
# |    learning_rate        | 8.27e-05   |
# |    loss                 | -0.477     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0135    |
# |    std                  | 1.18       |
# |    value_loss           | 0.0343     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6582        |
# |    iterations           | 14          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.008573143 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.55       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.48       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 1.2         |
# |    value_loss           | 0.0314      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6585        |
# |    iterations           | 15          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.010013382 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.63       |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.486      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 1.21        |
# |    value_loss           | 0.0307      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6562       |
# |    iterations           | 16         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.00863865 |
# |    clip_fraction        | 0.0932     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.7       |
# |    explained_variance   | 0.599      |
# |    learning_rate        | 8.27e-05   |
# |    loss                 | -0.49      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0148    |
# |    std                  | 1.22       |
# |    value_loss           | 0.0323     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6568        |
# |    iterations           | 17          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.009052604 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.75       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.496      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 1.24        |
# |    value_loss           | 0.0313      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6566        |
# |    iterations           | 18          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.010068303 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.81       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.503      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 1.25        |
# |    value_loss           | 0.0327      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6559        |
# |    iterations           | 19          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.009275285 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.85       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.521      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 1.25        |
# |    value_loss           | 0.0285      |
# -----------------------------------------
# Eval num_timesteps=320000, episode_reward=1205.88 +/- 40.66
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 1.21e+03    |
# | time/                   |             |
# |    total_timesteps      | 320000      |
# | train/                  |             |
# |    approx_kl            | 0.009392941 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.89       |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.508      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 1.26        |
# |    value_loss           | 0.0287      |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 6427   |
# |    iterations      | 20     |
# |    time_elapsed    | 50     |
# |    total_timesteps | 327680 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6433        |
# |    iterations           | 21          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.010805693 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.94       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.506      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 1.28        |
# |    value_loss           | 0.0275      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6412        |
# |    iterations           | 22          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.010397518 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.516      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 1.29        |
# |    value_loss           | 0.0262      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6405       |
# |    iterations           | 23         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.00946734 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10        |
# |    explained_variance   | 0.298      |
# |    learning_rate        | 8.27e-05   |
# |    loss                 | -0.516     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0159    |
# |    std                  | 1.3        |
# |    value_loss           | 0.0232     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6403        |
# |    iterations           | 24          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.010348236 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.532      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 1.31        |
# |    value_loss           | 0.0215      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6408       |
# |    iterations           | 25         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 409600     |
# | train/                  |            |
# |    approx_kl            | 0.01059979 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.1      |
# |    explained_variance   | 0.801      |
# |    learning_rate        | 8.27e-05   |
# |    loss                 | -0.538     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0198    |
# |    std                  | 1.32       |
# |    value_loss           | 0.0201     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6419        |
# |    iterations           | 26          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.011146963 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.53       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 1.33        |
# |    value_loss           | 0.0186      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6431        |
# |    iterations           | 27          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.010378679 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.509      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 1.33        |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6440        |
# |    iterations           | 28          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.009965621 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.543      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 1.34        |
# |    value_loss           | 0.0165      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6430        |
# |    iterations           | 29          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.010652024 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.533      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 1.35        |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# Eval num_timesteps=480000, episode_reward=1553.15 +/- 240.00
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 1.55e+03    |
# | time/                   |             |
# |    total_timesteps      | 480000      |
# | train/                  |             |
# |    approx_kl            | 0.011594415 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.534      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0211     |
# |    std                  | 1.35        |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 6355   |
# |    iterations      | 30     |
# |    time_elapsed    | 77     |
# |    total_timesteps | 491520 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6350        |
# |    iterations           | 31          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.011060049 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.534      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 1.36        |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6343        |
# |    iterations           | 32          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.011388807 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.538      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0211     |
# |    std                  | 1.36        |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6341        |
# |    iterations           | 33          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.010486446 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.545      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 1.37        |
# |    value_loss           | 0.00898     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6349         |
# |    iterations           | 34           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0106846895 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.3        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 8.27e-05     |
# |    loss                 | -0.536       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0197      |
# |    std                  | 1.37         |
# |    value_loss           | 0.00864      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6343        |
# |    iterations           | 35          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.011213141 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.539      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 1.38        |
# |    value_loss           | 0.00902     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6341        |
# |    iterations           | 36          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.011152217 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.544      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 1.4         |
# |    value_loss           | 0.00769     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6338        |
# |    iterations           | 37          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.010716643 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.538      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 1.4         |
# |    value_loss           | 0.0071      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6335        |
# |    iterations           | 38          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.011342183 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.543      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 1.41        |
# |    value_loss           | 0.00653     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6335        |
# |    iterations           | 39          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.010504944 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.56       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 1.42        |
# |    value_loss           | 0.00578     |
# -----------------------------------------
# Eval num_timesteps=640000, episode_reward=1711.67 +/- 33.07
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 1.71e+03     |
# | time/                   |              |
# |    total_timesteps      | 640000       |
# | train/                  |              |
# |    approx_kl            | 0.0114840865 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.5        |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 8.27e-05     |
# |    loss                 | -0.542       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0194      |
# |    std                  | 1.43         |
# |    value_loss           | 0.00585      |
# ------------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 6296   |
# |    iterations      | 40     |
# |    time_elapsed    | 104    |
# |    total_timesteps | 655360 |
# -------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6300         |
# |    iterations           | 41           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0114114825 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.5        |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 8.27e-05     |
# |    loss                 | -0.546       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0183      |
# |    std                  | 1.44         |
# |    value_loss           | 0.0053       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6300        |
# |    iterations           | 42          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.010787653 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.558      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 1.45        |
# |    value_loss           | 0.00496     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6307        |
# |    iterations           | 43          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.009984499 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.562      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 1.46        |
# |    value_loss           | 0.00486     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6315        |
# |    iterations           | 44          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.010294678 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.559      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 1.48        |
# |    value_loss           | 0.00482     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 6322      |
# |    iterations           | 45        |
# |    time_elapsed         | 116       |
# |    total_timesteps      | 737280    |
# | train/                  |           |
# |    approx_kl            | 0.0104605 |
# |    clip_fraction        | 0.114     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -10.7     |
# |    explained_variance   | 0.679     |
# |    learning_rate        | 8.27e-05  |
# |    loss                 | -0.55     |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0178   |
# |    std                  | 1.48      |
# |    value_loss           | 0.00431   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6336        |
# |    iterations           | 46          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.009881549 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.545      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 1.5         |
# |    value_loss           | 0.00429     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6343        |
# |    iterations           | 47          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.010123668 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.557      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 1.51        |
# |    value_loss           | 0.00417     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6353        |
# |    iterations           | 48          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.010581515 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.567      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 1.52        |
# |    value_loss           | 0.00389     |
# -----------------------------------------
# Eval num_timesteps=800000, episode_reward=1867.31 +/- 13.70
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 1.87e+03    |
# | time/                   |             |
# |    total_timesteps      | 800000      |
# | train/                  |             |
# |    approx_kl            | 0.010710575 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.567      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 1.53        |
# |    value_loss           | 0.00351     |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 6321   |
# |    iterations      | 49     |
# |    time_elapsed    | 126    |
# |    total_timesteps | 802816 |
# -------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6328         |
# |    iterations           | 50           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0105678355 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 8.27e-05     |
# |    loss                 | -0.569       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0173      |
# |    std                  | 1.54         |
# |    value_loss           | 0.00387      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6340        |
# |    iterations           | 51          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.010412479 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.58       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 1.56        |
# |    value_loss           | 0.00364     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6348        |
# |    iterations           | 52          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.010637275 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.574      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 1.56        |
# |    value_loss           | 0.00352     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6357        |
# |    iterations           | 53          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.010201103 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.57       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 1.58        |
# |    value_loss           | 0.00344     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6361        |
# |    iterations           | 54          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.010957246 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.569      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 1.59        |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6372        |
# |    iterations           | 55          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.010914009 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.582      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 1.6         |
# |    value_loss           | 0.00334     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6370        |
# |    iterations           | 56          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.010959227 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.581      |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 1.62        |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6372        |
# |    iterations           | 57          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.010699172 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.576      |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 1.63        |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6377        |
# |    iterations           | 58          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.011876076 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.569      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 1.65        |
# |    value_loss           | 0.00284     |
# -----------------------------------------
# Eval num_timesteps=960000, episode_reward=1955.36 +/- 44.64
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 1.96e+03    |
# | time/                   |             |
# |    total_timesteps      | 960000      |
# | train/                  |             |
# |    approx_kl            | 0.010498684 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.585      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 1.66        |
# |    value_loss           | 0.00288     |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 6346   |
# |    iterations      | 59     |
# |    time_elapsed    | 152    |
# |    total_timesteps | 966656 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6341        |
# |    iterations           | 60          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.011093352 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.574      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 1.67        |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6340        |
# |    iterations           | 61          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.010518467 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 8.27e-05    |
# |    loss                 | -0.59       |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 1.68        |
# |    value_loss           | 0.00249     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6342       |
# |    iterations           | 62         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 1015808    |
# | train/                  |            |
# |    approx_kl            | 0.01087681 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.3      |
# |    explained_variance   | 0.672      |
# |    learning_rate        | 8.27e-05   |
# |    loss                 | -0.588     |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.016     |
# |    std                  | 1.7        |
# |    value_loss           | 0.00258    |
# ----------------------------------------
# Mean Reward: -164.04 ± 205.56

# %%
#5. Salviamo il modello
model.save("ppo_HalfCheetah_model")
env.save("vecnormalize_HalfCheetah.pkl")    # salviamo anche i parametri di normalizzazione
