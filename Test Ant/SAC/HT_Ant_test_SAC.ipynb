# %%
import gymnasium as gym
from stable_baselines3 import SAC, PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import numpy as np
import tensorboard
import optuna
import gc

# from stable_baselines3_jax import SAC
# from stable_baselines3_jax.common.evaluation import evaluate_policy
# from stable_baselines3_jax.common.vec_env import SubprocVecEnv, VecNormalize

# %%
def make_env(reset_noise_scale, forward_reward_weight, ctrl_cost_weight, healthy_reward, contact_cost_weight, healthy_z_range, contact_force_range):
    """
    Crea e restituisce l'ambiente Ant-v5 dalla libreria Gymnasium con i parametri specificati.
    """
    # Ant-v5 è l’ambiente più recente in Gymnasium.
    return gym.make("Ant-v5", 
                    reset_noise_scale=reset_noise_scale, 
                    forward_reward_weight=forward_reward_weight, 
                    ctrl_cost_weight=ctrl_cost_weight, 
                    healthy_reward=healthy_reward, 
                    contact_cost_weight = contact_cost_weight,
                    healthy_z_range=healthy_z_range,
                    contact_force_range=contact_force_range)
                   # render_mode='none')

# %%
# Hyperparameter tuning con Optuna

def objective(trial):
    # Parametri dell'environment
    reset_noise_scale = trial.suggest_float('reset_noise_scale', 0, 0.3)           # Default circa 0.1; esploriamo da 0.05 a 0.2
    forward_reward_weight = trial.suggest_float('forward_reward_weight', 1.6, 1.9)     # Default tipico è 1; esploriamo da 0.5 a 1.5
    ctrl_cost_weight = trial.suggest_float('ctrl_cost_weight', 1.2, 1.6)               # Default tipico 0.5; esploriamo da 0.1 a 1.0
    healthy_reward = trial.suggest_float('healthy_reward', 2.1, 2.5)                   # Default tipico 1; esploriamo da 0.5 a 1.5

    # Parametri aggiuntivi per Ant-v5
    contact_cost_weight = trial.suggest_float('contact_cost_weight', 1e-6, 1e-4)  # Es. range intorno a 5e-4 come default
    healthy_z_lower = trial.suggest_float('healthy_z_lower', 0.1, 0.4)             # Per definire l'intervallo di altezze "sane"
    healthy_z_upper = trial.suggest_float('healthy_z_upper', 1.1, 1.4)
    contact_force_min = trial.suggest_float('contact_force_min', -1.3, -1)         # Modificabile se usi forze di contatto
    contact_force_max = trial.suggest_float('contact_force_max', 0.8, 1.1)

    # Crea l'ambiente passando tutti i parametri
    # env = make_env(
    #     reset_noise_scale,
    #     forward_reward_weight,
    #     ctrl_cost_weight,
    #     healthy_reward,
    #     contact_cost_weight=contact_cost_weight,
    #     healthy_z_range=(healthy_z_lower, healthy_z_upper),
    #     contact_force_range=(contact_force_min, contact_force_max)
    # )
    # env = DummyVecEnv([lambda: env])
    # env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # MULTIPROCESSING (MULTIENVIRONMENTS) 
    NUM_ENVS=6
    env = SubprocVecEnv([
        lambda: make_env(
            reset_noise_scale,
            forward_reward_weight,
            ctrl_cost_weight,
            healthy_reward,
            contact_cost_weight=contact_cost_weight,
            healthy_z_range=(healthy_z_lower, healthy_z_upper),
            contact_force_range=(contact_force_min, contact_force_max)
        ) for _ in range(NUM_ENVS)
    ])
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    env.training = False # Setta l'environment in modalità di valutazione
    env.norm_reward = False # Disabilita la normalizzazione della reward. Questo è importante per valutare correttamente il modello.

    # ---------------------------
    # Iperparametri per il modello SAC
    # ---------------------------
    # Parametri di ottimizzazione
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True)
    learning_starts = trial.suggest_int('learning_starts', 1000, 10000, step=1000)
    # Buffer di replay: tipicamente per SAC si usano grandi dimensioni
    #buffer_size = trial.suggest_int('buffer_size', 50000, 1000000, step=50000)
    batch_size = trial.suggest_categorical('batch_size', [256, 512, 1024, 2048])  
    gamma = trial.suggest_float('gamma', 0.93, 0.96)
    # Tau per il soft update della target network (molto sensibile in SAC)
    tau = trial.suggest_float('tau', 0.005, 0.05)
    ent_coef = trial.suggest_float('ent_coef', 0.0, 0.1)
    # Frequenza e passi di aggiornamento: controllano quanti step di gradient descent effettuare
    train_freq = trial.suggest_int('train_freq', 1, 10)
    gradient_steps = trial.suggest_int('gradient_steps', 1, 10)

    # Iperparametro per penalizzare la varianza dei reward, utile per evitare soluzioni troppo instabili
    # variance_penalty_weight = trial.suggest_float('variance_penalty_weight', 0.0, 0.5)

    # Crea ed allena il modello SAC con i parametri ottimizzati
    model = SAC("MlpPolicy", env,
                learning_rate=learning_rate,
                buffer_size=50000,
                learning_starts=learning_starts,
                batch_size=batch_size,
                gamma=gamma,
                tau=tau,
                ent_coef=ent_coef,
                train_freq=train_freq,
                gradient_steps=gradient_steps,
                seed=42,
                verbose=0)
    model.learn(total_timesteps=50000)

    # Valuta il modello su 200 episodi (200 è ottimale)
    episodes = 200
    # episode_rewards = []
    # for episode in range(episodes):
    #     obs = env.reset()
    #     done = False
    #     episode_reward = 0
    #     while not done:
    #         action, _states = model.predict(obs)
    #         obs, reward, done, info = env.step(action)
    #         episode_reward += reward
    #     episode_rewards.append(episode_reward)

    # # Calcola reward media e varianza
    # mean_reward = np.mean(episode_rewards)
    # reward_std = np.std(episode_rewards)

    # # Definisce l'obiettivo: massimizzare la reward media penalizzando la varianza
    # score = mean_reward - std_penalty_weight * reward_std

    # print(f'Mean is: {mean_reward}, Std is: {reward_std}\n')

    

    mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=episodes)

    # Chiudi e rilascia le risorse
    env.close()
    del model, env
    gc.collect()

    return mean_reward
# Crea uno studio Optuna e ottimizza l'obiettivo
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=300)

# Stampa i migliori iperparametri trovati
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2025-02-17 10:35:47,241] A new study created in memory with name: no-name-da3b0d48-4966-4a80-9778-ccb6838a9742
# /Users/ignazioemanuelepicciche/Documents/Ignazio PC/ucbm/deep_learning/Reinforcement_Learning_MuJoCu/.venv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2025-02-17 10:36:33,526] Trial 0 finished with value: 601.6952262351025 and parameters: {'reset_noise_scale': 0.19119718607806552, 'forward_reward_weight': 1.6804491245737976, 'ctrl_cost_weight': 1.207769020927843, 'healthy_reward': 2.272478700295021, 'contact_cost_weight': 8.624552952429674e-05, 'healthy_z_lower': 0.38279248859253384, 'healthy_z_upper': 1.2171170680345178, 'contact_force_min': -1.0198298269633561, 'contact_force_max': 0.9574785640914556, 'learning_rate': 0.00024459622520117355, 'learning_starts': 7000, 'batch_size': 512, 'gamma': 0.9543705145678568, 'tau': 0.015441338990150507, 'ent_coef': 0.06876165247531794, 'train_freq': 8, 'gradient_steps': 2}. Best is trial 0 with value: 601.6952262351025.
# [I 2025-02-17 10:37:51,214] Trial 1 finished with value: 396.30643822649336 and parameters: {'reset_noise_scale': 0.1181019218488185, 'forward_reward_weight': 1.7601243542189988, 'ctrl_cost_weight': 1.2362528910674222, 'healthy_reward': 2.4059488944840246, 'contact_cost_weight': 8.515301561422618e-06, 'healthy_z_lower': 0.10101664381823469, 'healthy_z_upper': 1.3771872317600788, 'contact_force_min': -1.2483677559135935, 'contact_force_max': 0.8346702942658225, 'learning_rate': 2.0811222969412835e-05, 'learning_starts': 8000, 'batch_size': 512, 'gamma': 0.9579054338829693, 'tau': 0.023270571272607427, 'ent_coef': 0.022499795692118518, 'train_freq': 7, 'gradient_steps': 7}. Best is trial 0 with value: 601.6952262351025.
# [I 2025-02-17 10:38:46,556] Trial 2 finished with value: 2086.3617699998154 and parameters: {'reset_noise_scale': 0.1373099124666212, 'forward_reward_weight': 1.780014877351446, 'ctrl_cost_weight': 1.2628894295836952, 'healthy_reward': 2.4940162574700273, 'contact_cost_weight': 4.005291349262265e-05, 'healthy_z_lower': 0.28662864023163365, 'healthy_z_upper': 1.1535837326341691, 'contact_force_min': -1.271588089872571, 'contact_force_max': 1.06928815600204, 'learning_rate': 0.00034319961726613353, 'learning_starts': 8000, 'batch_size': 1024, 'gamma': 0.9324968621100818, 'tau': 0.0335245208804116, 'ent_coef': 0.07557279838667687, 'train_freq': 5, 'gradient_steps': 2}. Best is trial 2 with value: 2086.3617699998154.
# [I 2025-02-17 10:40:26,304] Trial 3 finished with value: 1708.9397405242826 and parameters: {'reset_noise_scale': 0.1384583434450193, 'forward_reward_weight': 1.8712209539395417, 'ctrl_cost_weight': 1.2369138342512205, 'healthy_reward': 2.199199940604498, 'contact_cost_weight': 3.2103776947549056e-05, 'healthy_z_lower': 0.21381346821895347, 'healthy_z_upper': 1.3857638761477744, 'contact_force_min': -1.1016672592651287, 'contact_force_max': 0.9339188241491948, 'learning_rate': 0.00010073644905979928, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9591340799877307, 'tau': 0.021106790195402386, 'ent_coef': 0.07845331748625364, 'train_freq': 4, 'gradient_steps': 9}. Best is trial 2 with value: 2086.3617699998154.
# [I 2025-02-17 10:42:43,624] Trial 4 finished with value: 2042.1400633031249 and parameters: {'reset_noise_scale': 0.05637981540772645, 'forward_reward_weight': 1.7714169147929117, 'ctrl_cost_weight': 1.2914364534054303, 'healthy_reward': 2.156564014508812, 'contact_cost_weight': 6.959932509850878e-06, 'healthy_z_lower': 0.1393878761568561, 'healthy_z_upper': 1.391528216396018, 'contact_force_min': -1.0022926521571325, 'contact_force_max': 0.8440199259785499, 'learning_rate': 0.00020317054837064243, 'learning_starts': 9000, 'batch_size': 1024, 'gamma': 0.9519446944842226, 'tau': 0.043867979307878946, 'ent_coef': 0.012167359181477811, 'train_freq': 2, 'gradient_steps': 3}. Best is trial 2 with value: 2086.3617699998154.
# [I 2025-02-17 10:45:56,350] Trial 5 finished with value: 1941.110062717303 and parameters: {'reset_noise_scale': 0.2814696308432625, 'forward_reward_weight': 1.6332760874325003, 'ctrl_cost_weight': 1.4592720725558155, 'healthy_reward': 2.158371617720495, 'contact_cost_weight': 7.533825458699403e-05, 'healthy_z_lower': 0.12801024442030176, 'healthy_z_upper': 1.1666644541453588, 'contact_force_min': -1.1023426796105165, 'contact_force_max': 1.0913516759696342, 'learning_rate': 6.376132119534536e-05, 'learning_starts': 5000, 'batch_size': 512, 'gamma': 0.932393888239744, 'tau': 0.03521879375918623, 'ent_coef': 0.05065981813596337, 'train_freq': 3, 'gradient_steps': 10}. Best is trial 2 with value: 2086.3617699998154.
# [I 2025-02-17 10:48:12,344] Trial 6 finished with value: 1193.7603791833262 and parameters: {'reset_noise_scale': 0.2717649662102784, 'forward_reward_weight': 1.6455209765170142, 'ctrl_cost_weight': 1.5770959210105424, 'healthy_reward': 2.399289120400138, 'contact_cost_weight': 8.090154187528115e-05, 'healthy_z_lower': 0.3416547130688383, 'healthy_z_upper': 1.3959048641502678, 'contact_force_min': -1.109114948671966, 'contact_force_max': 0.9095815986015484, 'learning_rate': 3.300836219874508e-05, 'learning_starts': 6000, 'batch_size': 1024, 'gamma': 0.9328336960858216, 'tau': 0.008437711454208836, 'ent_coef': 0.06207165570307358, 'train_freq': 2, 'gradient_steps': 3}. Best is trial 2 with value: 2086.3617699998154.
# [I 2025-02-17 10:49:21,603] Trial 7 finished with value: 158.21115637686822 and parameters: {'reset_noise_scale': 0.27416112693141165, 'forward_reward_weight': 1.8826917347776713, 'ctrl_cost_weight': 1.519671233314417, 'healthy_reward': 2.4239961346591636, 'contact_cost_weight': 4.483605576162523e-06, 'healthy_z_lower': 0.2908423703209412, 'healthy_z_upper': 1.1346856878741176, 'contact_force_min': -1.094965819335612, 'contact_force_max': 0.9266003411709031, 'learning_rate': 1.6181456202252396e-05, 'learning_starts': 2000, 'batch_size': 1024, 'gamma': 0.9480737600450733, 'tau': 0.012065638502001827, 'ent_coef': 0.09279927015158355, 'train_freq': 10, 'gradient_steps': 5}. Best is trial 2 with value: 2086.3617699998154.
# [I 2025-02-17 10:49:55,996] Trial 8 finished with value: -744.052273769075 and parameters: {'reset_noise_scale': 0.2741446674343769, 'forward_reward_weight': 1.7873251828331802, 'ctrl_cost_weight': 1.5985113506191755, 'healthy_reward': 2.121534956314664, 'contact_cost_weight': 9.141323923924202e-05, 'healthy_z_lower': 0.15762583506234443, 'healthy_z_upper': 1.1773902713732658, 'contact_force_min': -1.16603720080506, 'contact_force_max': 0.939732725775041, 'learning_rate': 3.108199481454047e-05, 'learning_starts': 3000, 'batch_size': 256, 'gamma': 0.9564810438571757, 'tau': 0.024360757220065477, 'ent_coef': 0.00897847562888796, 'train_freq': 7, 'gradient_steps': 1}. Best is trial 2 with value: 2086.3617699998154.
# [I 2025-02-17 11:01:26,919] Trial 9 finished with value: 1986.6387159788608 and parameters: {'reset_noise_scale': 0.06413017022468344, 'forward_reward_weight': 1.819734892048157, 'ctrl_cost_weight': 1.536861892340465, 'healthy_reward': 2.253981488334066, 'contact_cost_weight': 1.614592090848929e-05, 'healthy_z_lower': 0.15288597676173765, 'healthy_z_upper': 1.2209859046885627, 'contact_force_min': -1.1800443926388102, 'contact_force_max': 1.0179219489576765, 'learning_rate': 1.8201912980399896e-05, 'learning_starts': 6000, 'batch_size': 1024, 'gamma': 0.9432706707687163, 'tau': 0.030541812894554255, 'ent_coef': 0.09614075494318584, 'train_freq': 1, 'gradient_steps': 9}. Best is trial 2 with value: 2086.3617699998154.
# [I 2025-02-17 11:04:13,113] Trial 10 finished with value: 2309.0745261017723 and parameters: {'reset_noise_scale': 0.010724202620271073, 'forward_reward_weight': 1.7096968698979735, 'ctrl_cost_weight': 1.350491508266014, 'healthy_reward': 2.4932941251619978, 'contact_cost_weight': 5.541630222586708e-05, 'healthy_z_lower': 0.24157075589640353, 'healthy_z_upper': 1.2882511335119204, 'contact_force_min': -1.2949897941080115, 'contact_force_max': 1.099201981477927, 'learning_rate': 0.0009941682684203256, 'learning_starts': 10000, 'batch_size': 2048, 'gamma': 0.9394210472799794, 'tau': 0.049392007469963264, 'ent_coef': 0.03398967876316593, 'train_freq': 5, 'gradient_steps': 5}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:07:06,474] Trial 11 finished with value: 1614.1416141138852 and parameters: {'reset_noise_scale': 0.002592587007403918, 'forward_reward_weight': 1.7250563630088547, 'ctrl_cost_weight': 1.342897278443691, 'healthy_reward': 2.4999297796849453, 'contact_cost_weight': 5.4028129728324225e-05, 'healthy_z_lower': 0.2543871705610172, 'healthy_z_upper': 1.3018038597729267, 'contact_force_min': -1.278750385089435, 'contact_force_max': 1.089457484461306, 'learning_rate': 0.0008636113354664747, 'learning_starts': 10000, 'batch_size': 2048, 'gamma': 0.9389490925393794, 'tau': 0.048180398906294594, 'ent_coef': 0.03515630537278841, 'train_freq': 5, 'gradient_steps': 5}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:10:33,205] Trial 12 finished with value: 1098.6414999429066 and parameters: {'reset_noise_scale': 0.1973798864793718, 'forward_reward_weight': 1.7103204713092581, 'ctrl_cost_weight': 1.3768501525014971, 'healthy_reward': 2.475849070532125, 'contact_cost_weight': 5.19008218073648e-05, 'healthy_z_lower': 0.2892609480882308, 'healthy_z_upper': 1.296559616452486, 'contact_force_min': -1.2961431859470014, 'contact_force_max': 1.0345142079793948, 'learning_rate': 0.0009273646738528855, 'learning_starts': 10000, 'batch_size': 2048, 'gamma': 0.9371018807431848, 'tau': 0.038297170594172036, 'ent_coef': 0.04036741802923241, 'train_freq': 5, 'gradient_steps': 7}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:12:12,581] Trial 13 finished with value: 2066.4106106950344 and parameters: {'reset_noise_scale': 0.08589118983191091, 'forward_reward_weight': 1.829592159428657, 'ctrl_cost_weight': 1.319237718110166, 'healthy_reward': 2.3406391811123184, 'contact_cost_weight': 3.652143318498667e-05, 'healthy_z_lower': 0.21128969969621655, 'healthy_z_upper': 1.108490744619207, 'contact_force_min': -1.224591053820033, 'contact_force_max': 1.0195049330423687, 'learning_rate': 0.0004150621621010182, 'learning_starts': 8000, 'batch_size': 2048, 'gamma': 0.9384814532624223, 'tau': 0.04951559870472633, 'ent_coef': 0.05211088793754702, 'train_freq': 6, 'gradient_steps': 3}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:16:16,171] Trial 14 finished with value: 1892.9691129428934 and parameters: {'reset_noise_scale': 0.0025077411087370844, 'forward_reward_weight': 1.683596939757098, 'ctrl_cost_weight': 1.4136584282115814, 'healthy_reward': 2.343513689386606, 'contact_cost_weight': 6.560423712128927e-05, 'healthy_z_lower': 0.3008271740146146, 'healthy_z_upper': 1.2801301772002942, 'contact_force_min': -1.2223810714806402, 'contact_force_max': 1.0531796785153094, 'learning_rate': 0.0004348238938430268, 'learning_starts': 8000, 'batch_size': 2048, 'gamma': 0.9426375597908716, 'tau': 0.039440901617671324, 'ent_coef': 0.08037043944213187, 'train_freq': 4, 'gradient_steps': 6}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:16:53,584] Trial 15 finished with value: 2032.0957040749117 and parameters: {'reset_noise_scale': 0.1897199075599133, 'forward_reward_weight': 1.7311911608379686, 'ctrl_cost_weight': 1.2866689804675395, 'healthy_reward': 2.4632393841352767, 'contact_cost_weight': 3.4632696938784085e-05, 'healthy_z_lower': 0.22405477533159934, 'healthy_z_upper': 1.3263445163188186, 'contact_force_min': -1.2656667893376161, 'contact_force_max': 0.9775652290161781, 'learning_rate': 0.0004386016212055831, 'learning_starts': 10000, 'batch_size': 1024, 'gamma': 0.9308312390574135, 'tau': 0.029685081434166784, 'ent_coef': 0.03278894268184268, 'train_freq': 9, 'gradient_steps': 1}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:19:06,078] Trial 16 finished with value: 2186.93275822795 and parameters: {'reset_noise_scale': 0.23345723295710272, 'forward_reward_weight': 1.7987032062829797, 'ctrl_cost_weight': 1.4354516394477042, 'healthy_reward': 2.444937309921455, 'contact_cost_weight': 6.439399357116418e-05, 'healthy_z_lower': 0.25262232752923197, 'healthy_z_upper': 1.2317135254766884, 'contact_force_min': -1.1959023424815713, 'contact_force_max': 1.0646675976168578, 'learning_rate': 0.00019467204945033094, 'learning_starts': 4000, 'batch_size': 2048, 'gamma': 0.9353090727919197, 'tau': 0.04266509249640765, 'ent_coef': 0.0013254739772702862, 'train_freq': 6, 'gradient_steps': 4}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:21:03,207] Trial 17 finished with value: 1978.9674963439618 and parameters: {'reset_noise_scale': 0.2310191790896988, 'forward_reward_weight': 1.6012233103774112, 'ctrl_cost_weight': 1.4458574168800156, 'healthy_reward': 2.3604117455573803, 'contact_cost_weight': 9.964277231037917e-05, 'healthy_z_lower': 0.19270364415854468, 'healthy_z_upper': 1.2445688917169693, 'contact_force_min': -1.218989936931409, 'contact_force_max': 0.9898151827719468, 'learning_rate': 0.00011812510310328933, 'learning_starts': 4000, 'batch_size': 2048, 'gamma': 0.9469197584396971, 'tau': 0.04301979367988415, 'ent_coef': 0.0026163310926525934, 'train_freq': 7, 'gradient_steps': 4}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:24:16,169] Trial 18 finished with value: 1873.681014784908 and parameters: {'reset_noise_scale': 0.21709776732674574, 'forward_reward_weight': 1.817025946203255, 'ctrl_cost_weight': 1.3767183985086768, 'healthy_reward': 2.441820956382175, 'contact_cost_weight': 6.613026421135129e-05, 'healthy_z_lower': 0.2599791024725018, 'healthy_z_upper': 1.3280684171004804, 'contact_force_min': -1.1916021330435482, 'contact_force_max': 0.8838687227994712, 'learning_rate': 5.717742990831383e-05, 'learning_starts': 1000, 'batch_size': 2048, 'gamma': 0.9369957941583383, 'tau': 0.043483927096581575, 'ent_coef': 0.02085531146779364, 'train_freq': 6, 'gradient_steps': 6}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:27:08,309] Trial 19 finished with value: 1027.7298354244813 and parameters: {'reset_noise_scale': 0.16791405853666064, 'forward_reward_weight': 1.8481757474837133, 'ctrl_cost_weight': 1.4774493071612285, 'healthy_reward': 2.3794798947291156, 'contact_cost_weight': 6.525392614234052e-05, 'healthy_z_lower': 0.3382172795541558, 'healthy_z_upper': 1.259403819091508, 'contact_force_min': -1.1407214038472133, 'contact_force_max': 1.0568268564604326, 'learning_rate': 0.0007216454809719343, 'learning_starts': 4000, 'batch_size': 2048, 'gamma': 0.9411971411316618, 'tau': 0.04945979332340596, 'ent_coef': 0.022552606642133967, 'train_freq': 4, 'gradient_steps': 4}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:29:50,311] Trial 20 finished with value: 2007.273117755486 and parameters: {'reset_noise_scale': 0.23444569829482914, 'forward_reward_weight': 1.689458433416857, 'ctrl_cost_weight': 1.4200748330260426, 'healthy_reward': 2.2960866534445015, 'contact_cost_weight': 4.651836942531217e-05, 'healthy_z_lower': 0.1824684882869826, 'healthy_z_upper': 1.1995722781115803, 'contact_force_min': -1.049503055244012, 'contact_force_max': 0.8021106623376166, 'learning_rate': 0.000159499340079059, 'learning_starts': 5000, 'batch_size': 2048, 'gamma': 0.9349847836977838, 'tau': 0.039914448096479684, 'ent_coef': 0.002671873438742485, 'train_freq': 8, 'gradient_steps': 7}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:30:46,851] Trial 21 finished with value: 2050.6597947686537 and parameters: {'reset_noise_scale': 0.10447612471013071, 'forward_reward_weight': 1.7877201177473543, 'ctrl_cost_weight': 1.3455864749244033, 'healthy_reward': 2.495621848195852, 'contact_cost_weight': 4.241932565333498e-05, 'healthy_z_lower': 0.2484654232612842, 'healthy_z_upper': 1.1601096625235523, 'contact_force_min': -1.2977259182392378, 'contact_force_max': 1.0955503027782882, 'learning_rate': 0.0002954098307331901, 'learning_starts': 7000, 'batch_size': 256, 'gamma': 0.935152440099129, 'tau': 0.03411945634703885, 'ent_coef': 0.061979924205990314, 'train_freq': 5, 'gradient_steps': 4}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:31:38,478] Trial 22 finished with value: 2182.7495483877137 and parameters: {'reset_noise_scale': 0.030806748559536027, 'forward_reward_weight': 1.7940895027719395, 'ctrl_cost_weight': 1.2823373845264026, 'healthy_reward': 2.4506231057489822, 'contact_cost_weight': 2.3761828599669098e-05, 'healthy_z_lower': 0.31939297442809655, 'healthy_z_upper': 1.1015495486503741, 'contact_force_min': -1.2408077666606534, 'contact_force_max': 1.058748692166729, 'learning_rate': 0.0005959350063250207, 'learning_starts': 9000, 'batch_size': 1024, 'gamma': 0.9307489875945432, 'tau': 0.04543308185693138, 'ent_coef': 0.04100701184311051, 'train_freq': 6, 'gradient_steps': 2}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:33:01,108] Trial 23 finished with value: 2222.6325750181313 and parameters: {'reset_noise_scale': 0.035685656113593686, 'forward_reward_weight': 1.7411169185484223, 'ctrl_cost_weight': 1.3241043457653603, 'healthy_reward': 2.448813897149834, 'contact_cost_weight': 2.4017893737397932e-05, 'healthy_z_lower': 0.33233947038370387, 'healthy_z_upper': 1.3443011501722895, 'contact_force_min': -1.2473740431512899, 'contact_force_max': 1.0626783822311892, 'learning_rate': 0.0005606272999539794, 'learning_starts': 3000, 'batch_size': 2048, 'gamma': 0.9300427639475061, 'tau': 0.0456741753941302, 'ent_coef': 0.04276257086313248, 'train_freq': 6, 'gradient_steps': 2}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:35:09,226] Trial 24 finished with value: 2261.4559501149506 and parameters: {'reset_noise_scale': 0.03183936828971537, 'forward_reward_weight': 1.7422129627814598, 'ctrl_cost_weight': 1.3837717305915391, 'healthy_reward': 2.4298252668048885, 'contact_cost_weight': 5.8280171415954914e-05, 'healthy_z_lower': 0.3687792898637636, 'healthy_z_upper': 1.3489906255626134, 'contact_force_min': -1.201534804686487, 'contact_force_max': 0.9967753917048956, 'learning_rate': 0.0005764712532744401, 'learning_starts': 3000, 'batch_size': 2048, 'gamma': 0.9348282890400507, 'tau': 0.046166356537176614, 'ent_coef': 0.02821737506513585, 'train_freq': 8, 'gradient_steps': 5}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:38:15,450] Trial 25 finished with value: 1503.0149240912497 and parameters: {'reset_noise_scale': 0.03753022029477177, 'forward_reward_weight': 1.7426319374530925, 'ctrl_cost_weight': 1.3816997691789308, 'healthy_reward': 2.419107321122633, 'contact_cost_weight': 5.614404745776765e-05, 'healthy_z_lower': 0.3995330262370563, 'healthy_z_upper': 1.3515448030764938, 'contact_force_min': -1.249722341477006, 'contact_force_max': 0.9993124716795039, 'learning_rate': 0.0005724424092942445, 'learning_starts': 2000, 'batch_size': 2048, 'gamma': 0.94050201776238, 'tau': 0.046092672288547284, 'ent_coef': 0.028879486057231868, 'train_freq': 8, 'gradient_steps': 8}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:40:10,275] Trial 26 finished with value: 1408.1325775474427 and parameters: {'reset_noise_scale': 0.024844524715629798, 'forward_reward_weight': 1.7077470806789967, 'ctrl_cost_weight': 1.3358063235423014, 'healthy_reward': 2.386072767102626, 'contact_cost_weight': 2.5322235955530626e-05, 'healthy_z_lower': 0.36924291450964564, 'healthy_z_upper': 1.3438843491034365, 'contact_force_min': -1.2087641822169188, 'contact_force_max': 1.0260936066871582, 'learning_rate': 0.0009554840745224843, 'learning_starts': 3000, 'batch_size': 2048, 'gamma': 0.9341684704542275, 'tau': 0.04051878505193964, 'ent_coef': 0.04689940277741906, 'train_freq': 10, 'gradient_steps': 5}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:42:28,758] Trial 27 finished with value: 1459.9352501671663 and parameters: {'reset_noise_scale': 0.07534175769026062, 'forward_reward_weight': 1.754076757042671, 'ctrl_cost_weight': 1.3139248664707508, 'healthy_reward': 2.467646092627095, 'contact_cost_weight': 7.37512532523548e-05, 'healthy_z_lower': 0.32562218033983215, 'healthy_z_upper': 1.3621641392446453, 'contact_force_min': -1.1416355590380396, 'contact_force_max': 1.0396576757189648, 'learning_rate': 0.0005337818071570324, 'learning_starts': 1000, 'batch_size': 2048, 'gamma': 0.9457240355941572, 'tau': 0.03679431265645168, 'ent_coef': 0.04145313605855287, 'train_freq': 9, 'gradient_steps': 6}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:44:22,165] Trial 28 finished with value: 2229.652958674514 and parameters: {'reset_noise_scale': 0.043187125298643124, 'forward_reward_weight': 1.711717704692372, 'ctrl_cost_weight': 1.3964752776673814, 'healthy_reward': 2.321356224683932, 'contact_cost_weight': 5.983946107369665e-05, 'healthy_z_lower': 0.36777351150210824, 'healthy_z_upper': 1.32160607511535, 'contact_force_min': -1.2433043124721228, 'contact_force_max': 0.9712774170934475, 'learning_rate': 0.0006837916728436427, 'learning_starts': 3000, 'batch_size': 2048, 'gamma': 0.9498954084509595, 'tau': 0.04715444463638853, 'ent_coef': 0.05702763260896439, 'train_freq': 7, 'gradient_steps': 3}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:45:22,057] Trial 29 finished with value: 2092.7050558114147 and parameters: {'reset_noise_scale': 0.09578127367193899, 'forward_reward_weight': 1.658994189621653, 'ctrl_cost_weight': 1.484024769169533, 'healthy_reward': 2.2396223000902955, 'contact_cost_weight': 6.093914735399788e-05, 'healthy_z_lower': 0.3583663819920604, 'healthy_z_upper': 1.270358954486458, 'contact_force_min': -1.1647537852893863, 'contact_force_max': 0.9632137176386981, 'learning_rate': 0.00032973482774469357, 'learning_starts': 2000, 'batch_size': 512, 'gamma': 0.9498081201720648, 'tau': 0.04997901304023568, 'ent_coef': 0.056389486154726706, 'train_freq': 9, 'gradient_steps': 3}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:47:46,725] Trial 30 finished with value: 1805.603230844573 and parameters: {'reset_noise_scale': 0.05303176030914341, 'forward_reward_weight': 1.7064871978436045, 'ctrl_cost_weight': 1.3991396865907801, 'healthy_reward': 2.331050280745725, 'contact_cost_weight': 7.242228189371083e-05, 'healthy_z_lower': 0.3879453260979808, 'healthy_z_upper': 1.3137542713365213, 'contact_force_min': -1.2697719143915414, 'contact_force_max': 0.9622041810850829, 'learning_rate': 0.00026741867985639845, 'learning_starts': 5000, 'batch_size': 2048, 'gamma': 0.9531050914477421, 'tau': 0.017353667181448703, 'ent_coef': 0.06751854412500394, 'train_freq': 7, 'gradient_steps': 5}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:48:53,618] Trial 31 finished with value: 1921.3162286048587 and parameters: {'reset_noise_scale': 0.019832479472606246, 'forward_reward_weight': 1.7330775886737473, 'ctrl_cost_weight': 1.3634992364026135, 'healthy_reward': 2.291592495327086, 'contact_cost_weight': 4.7131218079759065e-05, 'healthy_z_lower': 0.369667748677672, 'healthy_z_upper': 1.332828029191458, 'contact_force_min': -1.2422232154880872, 'contact_force_max': 1.0008920755968351, 'learning_rate': 0.0007556884253111675, 'learning_starts': 3000, 'batch_size': 2048, 'gamma': 0.9505820504817755, 'tau': 0.04775864570689584, 'ent_coef': 0.0333679523779135, 'train_freq': 8, 'gradient_steps': 2}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:50:10,909] Trial 32 finished with value: 520.0124396932998 and parameters: {'reset_noise_scale': 0.011153059602160235, 'forward_reward_weight': 1.6647188769203105, 'ctrl_cost_weight': 1.3584630867694358, 'healthy_reward': 2.42637375298695, 'contact_cost_weight': 5.8626611419375217e-05, 'healthy_z_lower': 0.351468776813953, 'healthy_z_upper': 1.3613873071846143, 'contact_force_min': -1.241167858929869, 'contact_force_max': 1.0743941732668445, 'learning_rate': 1.0318037482579625e-05, 'learning_starts': 3000, 'batch_size': 2048, 'gamma': 0.9554969901278336, 'tau': 0.046985831598969505, 'ent_coef': 0.024562515774876566, 'train_freq': 7, 'gradient_steps': 2}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:51:07,684] Trial 33 finished with value: 2013.2269263201952 and parameters: {'reset_noise_scale': 0.043978218247439194, 'forward_reward_weight': 1.7462295889772483, 'ctrl_cost_weight': 1.3971815295504377, 'healthy_reward': 2.3157429166709207, 'contact_cost_weight': 4.698558307246194e-05, 'healthy_z_lower': 0.3162001577202818, 'healthy_z_upper': 1.2918633937848885, 'contact_force_min': -1.286363479560366, 'contact_force_max': 0.9035410533251998, 'learning_rate': 0.0006366607938724487, 'learning_starts': 4000, 'batch_size': 2048, 'gamma': 0.9369558453614482, 'tau': 0.04165607585337567, 'ent_coef': 0.045893700724470014, 'train_freq': 8, 'gradient_steps': 1}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:52:02,224] Trial 34 finished with value: 2246.0648837269705 and parameters: {'reset_noise_scale': 0.11511858926350557, 'forward_reward_weight': 1.6941044559596088, 'ctrl_cost_weight': 1.2300575918931518, 'healthy_reward': 2.4771639507661183, 'contact_cost_weight': 1.2277996338956552e-05, 'healthy_z_lower': 0.37888894976096005, 'healthy_z_upper': 1.3154606585274888, 'contact_force_min': -1.2600002863113342, 'contact_force_max': 0.9797467898461524, 'learning_rate': 0.000995176699083944, 'learning_starts': 2000, 'batch_size': 512, 'gamma': 0.9303434043717727, 'tau': 0.04554223956125236, 'ent_coef': 0.016242946164683296, 'train_freq': 7, 'gradient_steps': 3}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:53:00,344] Trial 35 finished with value: 2126.6088724403176 and parameters: {'reset_noise_scale': 0.12744457648817495, 'forward_reward_weight': 1.6953582229167243, 'ctrl_cost_weight': 1.2117621077016836, 'healthy_reward': 2.4821009430028145, 'contact_cost_weight': 8.209071449505686e-05, 'healthy_z_lower': 0.38044236595252523, 'healthy_z_upper': 1.31152551927322, 'contact_force_min': -1.2619180716600942, 'contact_force_max': 0.9784813405849759, 'learning_rate': 0.0009368443291277794, 'learning_starts': 1000, 'batch_size': 512, 'gamma': 0.9443370178916021, 'tau': 0.044969633537402236, 'ent_coef': 0.012922812009463491, 'train_freq': 7, 'gradient_steps': 4}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:53:51,808] Trial 36 finished with value: 1952.5386154483242 and parameters: {'reset_noise_scale': 0.07379372467681972, 'forward_reward_weight': 1.7639884401546604, 'ctrl_cost_weight': 1.2513566901580704, 'healthy_reward': 2.2154774675857065, 'contact_cost_weight': 1.0991895595587638e-05, 'healthy_z_lower': 0.27351806298140696, 'healthy_z_upper': 1.3739375241545555, 'contact_force_min': -1.2053960009765061, 'contact_force_max': 0.9469936984850316, 'learning_rate': 0.00043514633799253855, 'learning_starts': 2000, 'batch_size': 512, 'gamma': 0.9325740506049001, 'tau': 0.03733931634939719, 'ent_coef': 0.016720006711835548, 'train_freq': 9, 'gradient_steps': 3}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:54:53,610] Trial 37 finished with value: 1701.449741535703 and parameters: {'reset_noise_scale': 0.10693465018815343, 'forward_reward_weight': 1.6684743367082315, 'ctrl_cost_weight': 1.2074010690625634, 'healthy_reward': 2.371091868543344, 'contact_cost_weight': 3.901215015539033e-05, 'healthy_z_lower': 0.3624810121777841, 'healthy_z_upper': 1.2720707669211047, 'contact_force_min': -1.2836940190806296, 'contact_force_max': 0.8805619584826201, 'learning_rate': 0.0007380077894083189, 'learning_starts': 7000, 'batch_size': 512, 'gamma': 0.9399883244329917, 'tau': 0.04180926666858189, 'ent_coef': 0.028260118564750365, 'train_freq': 8, 'gradient_steps': 6}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:56:30,937] Trial 38 finished with value: 2088.5462950131882 and parameters: {'reset_noise_scale': 0.15882582474504514, 'forward_reward_weight': 1.7236503977941822, 'ctrl_cost_weight': 1.2647589098429344, 'healthy_reward': 2.4017161527642927, 'contact_cost_weight': 5.26203954061501e-05, 'healthy_z_lower': 0.3077544242527773, 'healthy_z_upper': 1.312359533608312, 'contact_force_min': -1.2584226334466346, 'contact_force_max': 0.9205839150829712, 'learning_rate': 0.00021923036180124817, 'learning_starts': 2000, 'batch_size': 512, 'gamma': 0.933257499282967, 'tau': 0.03130518149549931, 'ent_coef': 0.018394353296307394, 'train_freq': 3, 'gradient_steps': 4}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:57:17,881] Trial 39 finished with value: 2234.6340373348958 and parameters: {'reset_noise_scale': 0.13866384273497445, 'forward_reward_weight': 1.631131540433722, 'ctrl_cost_weight': 1.300597552990646, 'healthy_reward': 2.420012585599158, 'contact_cost_weight': 2.80381942874653e-05, 'healthy_z_lower': 0.23267993492720518, 'healthy_z_upper': 1.3801730822226894, 'contact_force_min': -1.2996210122257472, 'contact_force_max': 1.0044626233147689, 'learning_rate': 0.0003578358834813466, 'learning_starts': 6000, 'batch_size': 256, 'gamma': 0.9481572696418953, 'tau': 0.02282617250207024, 'ent_coef': 0.007965905985091696, 'train_freq': 7, 'gradient_steps': 3}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:58:51,741] Trial 40 finished with value: 1928.9919899812687 and parameters: {'reset_noise_scale': 0.14502284549199765, 'forward_reward_weight': 1.6201023444024552, 'ctrl_cost_weight': 1.2352626952104258, 'healthy_reward': 2.414492160398219, 'contact_cost_weight': 1.577502339043512e-05, 'healthy_z_lower': 0.269857778249936, 'healthy_z_upper': 1.3792999295438104, 'contact_force_min': -1.2942860011712305, 'contact_force_max': 1.000296882287576, 'learning_rate': 0.0003338401335103297, 'learning_starts': 6000, 'batch_size': 256, 'gamma': 0.9418134044317776, 'tau': 0.022647853191259743, 'ent_coef': 0.014376348334941409, 'train_freq': 4, 'gradient_steps': 7}. Best is trial 10 with value: 2309.0745261017723.
# [I 2025-02-17 11:59:39,211] Trial 41 finished with value: 2467.7886982408168 and parameters: {'reset_noise_scale': 0.12931471756749796, 'forward_reward_weight': 1.640514676081255, 'ctrl_cost_weight': 1.3034746123392722, 'healthy_reward': 2.481787382345853, 'contact_cost_weight': 2.0313073424480255e-06, 'healthy_z_lower': 0.2285833992575254, 'healthy_z_upper': 1.39903865805895, 'contact_force_min': -1.2756674817209526, 'contact_force_max': 0.9761173083444922, 'learning_rate': 0.0006911546453655102, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9488474125931651, 'tau': 0.02568259185575727, 'ent_coef': 0.01197031160049647, 'train_freq': 7, 'gradient_steps': 3}. Best is trial 41 with value: 2467.7886982408168.
# [I 2025-02-17 12:00:40,262] Trial 42 finished with value: 2360.733655371815 and parameters: {'reset_noise_scale': 0.1157961267760192, 'forward_reward_weight': 1.6392833370065103, 'ctrl_cost_weight': 1.2884279546818942, 'healthy_reward': 2.47852455700073, 'contact_cost_weight': 4.369735225252636e-06, 'healthy_z_lower': 0.22061355156066745, 'healthy_z_upper': 1.3956110642922661, 'contact_force_min': -1.2754292499340758, 'contact_force_max': 0.954567462527512, 'learning_rate': 0.0004718333175602846, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9478066770057728, 'tau': 0.016695388220153887, 'ent_coef': 0.007025519422214403, 'train_freq': 7, 'gradient_steps': 5}. Best is trial 41 with value: 2467.7886982408168.
# [I 2025-02-17 12:01:54,368] Trial 43 finished with value: 2402.927047981009 and parameters: {'reset_noise_scale': 0.12102167086546099, 'forward_reward_weight': 1.6491816944999942, 'ctrl_cost_weight': 1.266461423396308, 'healthy_reward': 2.481006013838475, 'contact_cost_weight': 4.914599862896e-06, 'healthy_z_lower': 0.2007651973526442, 'healthy_z_upper': 1.3983956102416264, 'contact_force_min': -1.2754315435492527, 'contact_force_max': 0.9498007546664543, 'learning_rate': 0.0009735399223502833, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.946729015097763, 'tau': 0.017006008209475655, 'ent_coef': 0.007321505644810582, 'train_freq': 5, 'gradient_steps': 5}. Best is trial 41 with value: 2467.7886982408168.
# [I 2025-02-17 12:03:52,671] Trial 44 finished with value: 2314.0017045657196 and parameters: {'reset_noise_scale': 0.1721874596476221, 'forward_reward_weight': 1.6472092636197582, 'ctrl_cost_weight': 1.2696620994793537, 'healthy_reward': 2.495945542814885, 'contact_cost_weight': 2.632195229558295e-06, 'healthy_z_lower': 0.1967190805683237, 'healthy_z_upper': 1.3955921284763708, 'contact_force_min': -1.276306095649026, 'contact_force_max': 0.9535137154814425, 'learning_rate': 0.0004965396259735395, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9453481239611027, 'tau': 0.018476474260082205, 'ent_coef': 0.007911398657979633, 'train_freq': 3, 'gradient_steps': 5}. Best is trial 41 with value: 2467.7886982408168.
# [I 2025-02-17 12:06:19,467] Trial 45 finished with value: 2350.9610293804667 and parameters: {'reset_noise_scale': 0.17441223023730928, 'forward_reward_weight': 1.6484257505479705, 'ctrl_cost_weight': 1.268876409088224, 'healthy_reward': 2.499229264512534, 'contact_cost_weight': 1.893336206327155e-06, 'healthy_z_lower': 0.1925751247590724, 'healthy_z_upper': 1.3974584931605782, 'contact_force_min': -1.2772967235104888, 'contact_force_max': 0.9371995783954019, 'learning_rate': 0.0008050904146249555, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9457003694534591, 'tau': 0.017464462328308974, 'ent_coef': 0.009393701030942114, 'train_freq': 3, 'gradient_steps': 5}. Best is trial 41 with value: 2467.7886982408168.
# [I 2025-02-17 12:08:48,103] Trial 46 finished with value: 2575.6134060190902 and parameters: {'reset_noise_scale': 0.15774990885907564, 'forward_reward_weight': 1.6472121306377379, 'ctrl_cost_weight': 1.2719277637850412, 'healthy_reward': 2.464156991243087, 'contact_cost_weight': 5.36955787017861e-06, 'healthy_z_lower': 0.19427211512306347, 'healthy_z_upper': 1.387957430289873, 'contact_force_min': -1.2784673651355416, 'contact_force_max': 0.9495662387569828, 'learning_rate': 0.0004641814246109329, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9460658826270153, 'tau': 0.017794901730367116, 'ent_coef': 0.007927919548439974, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:12:58,449] Trial 47 finished with value: 2252.1745550013943 and parameters: {'reset_noise_scale': 0.1271061435457948, 'forward_reward_weight': 1.6136075559588312, 'ctrl_cost_weight': 1.2477632270957524, 'healthy_reward': 2.4632883805092387, 'contact_cost_weight': 1.4728915394999754e-06, 'healthy_z_lower': 0.1725183098012489, 'healthy_z_upper': 1.3883417535549103, 'contact_force_min': -1.2290305916206035, 'contact_force_max': 0.9315519183593927, 'learning_rate': 0.0007554302583213531, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.94801250594769, 'tau': 0.01247826225361368, 'ent_coef': 0.0068354207791811086, 'train_freq': 2, 'gradient_steps': 7}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:20:36,808] Trial 48 finished with value: 2473.1430500435754 and parameters: {'reset_noise_scale': 0.1825286281108941, 'forward_reward_weight': 1.6425703176873097, 'ctrl_cost_weight': 1.2928735955752162, 'healthy_reward': 2.4783714507171037, 'contact_cost_weight': 7.012730901952731e-06, 'healthy_z_lower': 0.11397806441892624, 'healthy_z_upper': 1.3976471967852608, 'contact_force_min': -1.2782742145478272, 'contact_force_max': 0.9115669460794982, 'learning_rate': 6.774285622571215e-05, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9518296377903961, 'tau': 0.02549217216427781, 'ent_coef': 0.011372394397218977, 'train_freq': 1, 'gradient_steps': 8}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:24:45,547] Trial 49 finished with value: 2187.79512202729 and parameters: {'reset_noise_scale': 0.19269794880094587, 'forward_reward_weight': 1.6337629289649502, 'ctrl_cost_weight': 1.2979474534181648, 'healthy_reward': 2.4611180290955392, 'contact_cost_weight': 8.230159647681265e-06, 'healthy_z_lower': 0.21294031458615503, 'healthy_z_upper': 1.3640470300471241, 'contact_force_min': -1.050641684239827, 'contact_force_max': 0.8986182089213437, 'learning_rate': 6.738864850033522e-05, 'learning_starts': 8000, 'batch_size': 256, 'gamma': 0.9529095513364058, 'tau': 0.025837417390604904, 'ent_coef': 0.004251215896656203, 'train_freq': 2, 'gradient_steps': 10}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:31:14,678] Trial 50 finished with value: 2293.001053200631 and parameters: {'reset_noise_scale': 0.15947353860445207, 'forward_reward_weight': 1.6761298407200675, 'ctrl_cost_weight': 1.3079044727578422, 'healthy_reward': 2.477092403320168, 'contact_cost_weight': 1.8441802916115066e-05, 'healthy_z_lower': 0.10322831634649834, 'healthy_z_upper': 1.371900380417802, 'contact_force_min': -1.2763113671778414, 'contact_force_max': 0.9183664323421642, 'learning_rate': 4.172825029377625e-05, 'learning_starts': 8000, 'batch_size': 256, 'gamma': 0.9439377832760867, 'tau': 0.013293152875931767, 'ent_coef': 0.01129302546851784, 'train_freq': 1, 'gradient_steps': 8}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:33:33,863] Trial 51 finished with value: 1961.3588949383982 and parameters: {'reset_noise_scale': 0.17938845260972905, 'forward_reward_weight': 1.6490334471320598, 'ctrl_cost_weight': 1.2784370029966152, 'healthy_reward': 2.4823014032591084, 'contact_cost_weight': 5.742746770599384e-06, 'healthy_z_lower': 0.15859673060671237, 'healthy_z_upper': 1.397323639839195, 'contact_force_min': -1.2835634195370709, 'contact_force_max': 0.9425083053774549, 'learning_rate': 8.279483817919449e-05, 'learning_starts': 10000, 'batch_size': 256, 'gamma': 0.9465612222700114, 'tau': 0.00737084042850876, 'ent_coef': 0.00031905498931743704, 'train_freq': 3, 'gradient_steps': 8}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:40:20,099] Trial 52 finished with value: 2165.1183628170215 and parameters: {'reset_noise_scale': 0.15370166254266696, 'forward_reward_weight': 1.6321793872931263, 'ctrl_cost_weight': 1.2539820258785979, 'healthy_reward': 2.440057513901908, 'contact_cost_weight': 1.0486247970634578e-05, 'healthy_z_lower': 0.13451309906826003, 'healthy_z_upper': 1.3993914804853846, 'contact_force_min': -1.2685295489950033, 'contact_force_max': 0.8708690151365986, 'learning_rate': 0.00011891305275283097, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9513109344558367, 'tau': 0.020482887651250066, 'ent_coef': 0.012444154271889801, 'train_freq': 1, 'gradient_steps': 9}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:42:06,910] Trial 53 finished with value: 1733.6102194998791 and parameters: {'reset_noise_scale': 0.2147002574141034, 'forward_reward_weight': 1.6544988976292032, 'ctrl_cost_weight': 1.2222266240114934, 'healthy_reward': 2.4985445820552425, 'contact_cost_weight': 6.030065831638317e-06, 'healthy_z_lower': 0.20413756228637472, 'healthy_z_upper': 1.3854065385045633, 'contact_force_min': -1.25564225793039, 'contact_force_max': 0.9355609638712296, 'learning_rate': 4.923407505508014e-05, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9484201651632613, 'tau': 0.010063809826943798, 'ent_coef': 0.005302213232357583, 'train_freq': 4, 'gradient_steps': 8}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:44:49,726] Trial 54 finished with value: 2227.1621059431136 and parameters: {'reset_noise_scale': 0.1349189262927769, 'forward_reward_weight': 1.6242495483759343, 'ctrl_cost_weight': 1.3293729577710192, 'healthy_reward': 2.457370723174829, 'contact_cost_weight': 1.863698497041676e-05, 'healthy_z_lower': 0.22611232462823713, 'healthy_z_upper': 1.3696028438574683, 'contact_force_min': -1.230976112978546, 'contact_force_max': 0.9543138619782229, 'learning_rate': 8.078171175053157e-05, 'learning_starts': 8000, 'batch_size': 256, 'gamma': 0.9466244721844563, 'tau': 0.015805766211228114, 'ent_coef': 0.019291547021812124, 'train_freq': 2, 'gradient_steps': 6}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:46:56,409] Trial 55 finished with value: 2464.976448025725 and parameters: {'reset_noise_scale': 0.18462793917289003, 'forward_reward_weight': 1.6033294456358629, 'ctrl_cost_weight': 1.2879057980801458, 'healthy_reward': 2.484867754075328, 'contact_cost_weight': 1.005228828096252e-06, 'healthy_z_lower': 0.17842105349297097, 'healthy_z_upper': 1.3853571941249272, 'contact_force_min': -1.284725695605938, 'contact_force_max': 0.9167876595089842, 'learning_rate': 0.0007849937594740504, 'learning_starts': 10000, 'batch_size': 256, 'gamma': 0.9591695208121823, 'tau': 0.019827152400822765, 'ent_coef': 0.01049811935092649, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:48:33,492] Trial 56 finished with value: 2273.072160384959 and parameters: {'reset_noise_scale': 0.20617811946949782, 'forward_reward_weight': 1.6002231153437099, 'ctrl_cost_weight': 1.288669147812879, 'healthy_reward': 2.438248513797075, 'contact_cost_weight': 1.4656706832140363e-05, 'healthy_z_lower': 0.11053133205837996, 'healthy_z_upper': 1.3799078800858144, 'contact_force_min': -1.2905769899790178, 'contact_force_max': 0.8576114199324048, 'learning_rate': 0.0003951817402259285, 'learning_starts': 10000, 'batch_size': 256, 'gamma': 0.959852245293107, 'tau': 0.027637134168393553, 'ent_coef': 0.023677354588468747, 'train_freq': 5, 'gradient_steps': 7}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:53:15,691] Trial 57 finished with value: 2161.7461385504425 and parameters: {'reset_noise_scale': 0.12052551829216791, 'forward_reward_weight': 1.6139362372591026, 'ctrl_cost_weight': 1.2441618204573432, 'healthy_reward': 2.4832891284116654, 'contact_cost_weight': 8.068138335206962e-06, 'healthy_z_lower': 0.16996312515350534, 'healthy_z_upper': 1.3577057242065946, 'contact_force_min': -1.2682473389023856, 'contact_force_max': 0.911860525438244, 'learning_rate': 2.6025962780250834e-05, 'learning_starts': 10000, 'batch_size': 256, 'gamma': 0.9564652256507684, 'tau': 0.020096822873253126, 'ent_coef': 0.011257191439104343, 'train_freq': 1, 'gradient_steps': 6}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:55:03,050] Trial 58 finished with value: 1886.908698283662 and parameters: {'reset_noise_scale': 0.1853088434786, 'forward_reward_weight': 1.676401811386036, 'ctrl_cost_weight': 1.3089567486491345, 'healthy_reward': 2.1748609731154005, 'contact_cost_weight': 2.0095140456786484e-05, 'healthy_z_lower': 0.12109761680851805, 'healthy_z_upper': 1.389738200561196, 'contact_force_min': -1.1209791537691158, 'contact_force_max': 0.9043970526421121, 'learning_rate': 0.00014576048879360944, 'learning_starts': 10000, 'batch_size': 256, 'gamma': 0.9576088047802995, 'tau': 0.024875774224262945, 'ent_coef': 0.004256047413898434, 'train_freq': 4, 'gradient_steps': 7}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:56:40,134] Trial 59 finished with value: 2507.658786273971 and parameters: {'reset_noise_scale': 0.1464682670796663, 'forward_reward_weight': 1.6358884187525113, 'ctrl_cost_weight': 1.2767681938918978, 'healthy_reward': 2.392541313667023, 'contact_cost_weight': 5.9433633146486394e-06, 'healthy_z_lower': 0.23843789930388187, 'healthy_z_upper': 1.335889946048476, 'contact_force_min': -1.2543876597473684, 'contact_force_max': 0.8954097602837784, 'learning_rate': 0.0008364959987507456, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9491070619996734, 'tau': 0.027549042467937393, 'ent_coef': 0.015497294489679063, 'train_freq': 6, 'gradient_steps': 9}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 12:58:51,996] Trial 60 finished with value: 2031.2151651299419 and parameters: {'reset_noise_scale': 0.24943519924292112, 'forward_reward_weight': 1.6151121632561793, 'ctrl_cost_weight': 1.2610325515182612, 'healthy_reward': 2.35707729059192, 'contact_cost_weight': 1.2922052724914757e-05, 'healthy_z_lower': 0.1532994707227429, 'healthy_z_upper': 1.3425138521871167, 'contact_force_min': -1.2538643644620584, 'contact_force_max': 0.8955827631460386, 'learning_rate': 0.0008196381880881991, 'learning_starts': 8000, 'batch_size': 256, 'gamma': 0.9546280474002583, 'tau': 0.0276021792199935, 'ent_coef': 0.09000637984643482, 'train_freq': 5, 'gradient_steps': 9}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 13:01:06,678] Trial 61 finished with value: 2307.8461387666243 and parameters: {'reset_noise_scale': 0.14432349333934671, 'forward_reward_weight': 1.6381338429451853, 'ctrl_cost_weight': 1.2887804000294347, 'healthy_reward': 2.46931247804028, 'contact_cost_weight': 4.938390966917749e-06, 'healthy_z_lower': 0.24133459835672247, 'healthy_z_upper': 1.385585647904527, 'contact_force_min': -1.286454604722226, 'contact_force_max': 0.9240751549551033, 'learning_rate': 0.00048754873225885357, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9490760951606186, 'tau': 0.014530101357918934, 'ent_coef': 0.00032580654663127984, 'train_freq': 6, 'gradient_steps': 10}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 13:03:07,557] Trial 62 finished with value: 2375.750317010426 and parameters: {'reset_noise_scale': 0.16404119931499833, 'forward_reward_weight': 1.6073727328625864, 'ctrl_cost_weight': 1.273220816693701, 'healthy_reward': 2.394818989906892, 'contact_cost_weight': 7.464175936027545e-06, 'healthy_z_lower': 0.22630011841783154, 'healthy_z_upper': 1.3706890138026768, 'contact_force_min': -1.2708598703186125, 'contact_force_max': 0.9667424773500621, 'learning_rate': 0.0006457781408305289, 'learning_starts': 9000, 'batch_size': 256, 'gamma': 0.9523034001508999, 'tau': 0.02973361481521117, 'ent_coef': 0.01600905223759759, 'train_freq': 6, 'gradient_steps': 9}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 13:05:09,430] Trial 63 finished with value: 2424.0529314640025 and parameters: {'reset_noise_scale': 0.1642097736722841, 'forward_reward_weight': 1.6085193861246048, 'ctrl_cost_weight': 1.2747956329942463, 'healthy_reward': 2.397672195557975, 'contact_cost_weight': 9.345491234721645e-06, 'healthy_z_lower': 0.18230132361588738, 'healthy_z_upper': 1.3713161086326626, 'contact_force_min': -1.2353778549663423, 'contact_force_max': 0.8929785614599677, 'learning_rate': 0.0006594386485926385, 'learning_starts': 8000, 'batch_size': 256, 'gamma': 0.9531122191653646, 'tau': 0.03257786407182447, 'ent_coef': 0.020882897887365588, 'train_freq': 6, 'gradient_steps': 9}. Best is trial 46 with value: 2575.6134060190902.
# [I 2025-02-17 13:07:20,378] Trial 64 finished with value: 2390.8546502227337 and parameters: {'reset_noise_scale': 0.14780037448474292, 'forward_reward_weight': 1.6254372877816814, 'ctrl_cost_weight': 1.323579878670475, 'healthy_reward': 2.449715276564757, 'contact_cost_weight': 1.0438652857865747e-06, 'healthy_z_lower': 0.1827318368782495, 'healthy_z_upper': 1.358373042532808, 'contact_force_min': -1.2516511426958923, 'contact_force_max': 0.8921071439228331, 'learning_rate': 0.0006588645140647081, 'learning_starts': 8000, 'batch_size': 256, 'gamma': 0.9538343581713785, 'tau': 0.032275755698831385, 'ent_coef': 0.021151754580921195, 'train_freq': 6, 'gradient_steps': 9}. Best is trial 46 with value: 2575.6134060190902.
# ...
# [I 2025-02-17 20:26:58,744] Trial 279 finished with value: 2296.4864110055128 and parameters: {'reset_noise_scale': 0.19968623623761994, 'forward_reward_weight': 1.8994256320641059, 'ctrl_cost_weight': 1.5829740230728835, 'healthy_reward': 2.383780091720804, 'contact_cost_weight': 1.1133833601423891e-05, 'healthy_z_lower': 0.15599693311441692, 'healthy_z_upper': 1.349416143335133, 'contact_force_min': -1.2146711425651588, 'contact_force_max': 0.8972596443044468, 'learning_rate': 0.0008004787092454167, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9496107461373696, 'tau': 0.022719439370399615, 'ent_coef': 0.04998288309554869, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:29:04,254] Trial 280 finished with value: 1758.487700195357 and parameters: {'reset_noise_scale': 0.05714534678971028, 'forward_reward_weight': 1.6323711046643647, 'ctrl_cost_weight': 1.3564063351804856, 'healthy_reward': 2.4116188118111492, 'contact_cost_weight': 8.116168861012879e-05, 'healthy_z_lower': 0.29848490804318933, 'healthy_z_upper': 1.33619169464101, 'contact_force_min': -1.2420224479355149, 'contact_force_max': 0.914372445383709, 'learning_rate': 0.0005209498210780045, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9368894897256123, 'tau': 0.020906360336347747, 'ent_coef': 0.052218839194754785, 'train_freq': 3, 'gradient_steps': 7}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:32:39,545] Trial 281 finished with value: 2159.804299389174 and parameters: {'reset_noise_scale': 0.21761292402158014, 'forward_reward_weight': 1.6210380551675705, 'ctrl_cost_weight': 1.2796007770072426, 'healthy_reward': 2.4020300830717543, 'contact_cost_weight': 8.547864680039391e-05, 'healthy_z_lower': 0.1305564792221243, 'healthy_z_upper': 1.3240433228845854, 'contact_force_min': -1.2239158004223416, 'contact_force_max': 0.831053362567181, 'learning_rate': 0.0004647893758861519, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9514301785286364, 'tau': 0.018864529949509, 'ent_coef': 0.04768836142902984, 'train_freq': 2, 'gradient_steps': 9}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:34:44,787] Trial 282 finished with value: 2110.204421495987 and parameters: {'reset_noise_scale': 0.20399440779012668, 'forward_reward_weight': 1.6009694153845582, 'ctrl_cost_weight': 1.3185277436390728, 'healthy_reward': 2.3924703104372047, 'contact_cost_weight': 7.699898809986258e-05, 'healthy_z_lower': 0.1724475860667342, 'healthy_z_upper': 1.3742429661780353, 'contact_force_min': -1.2296170313957817, 'contact_force_max': 0.9065150272629636, 'learning_rate': 0.0008902072888035129, 'learning_starts': 3000, 'batch_size': 512, 'gamma': 0.9540799468873195, 'tau': 0.023513978752021873, 'ent_coef': 0.05458648749540726, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:36:38,200] Trial 283 finished with value: 2300.1083094075143 and parameters: {'reset_noise_scale': 0.19445019332952898, 'forward_reward_weight': 1.6382700351526047, 'ctrl_cost_weight': 1.2930500448523259, 'healthy_reward': 2.353586314426743, 'contact_cost_weight': 8.303679431471397e-05, 'healthy_z_lower': 0.16080271022947618, 'healthy_z_upper': 1.33171184201991, 'contact_force_min': -1.1316547809713484, 'contact_force_max': 0.8704481651655969, 'learning_rate': 0.0007284702099596488, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9507896919223879, 'tau': 0.019944438012938093, 'ent_coef': 0.007232621024483616, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:38:59,926] Trial 284 finished with value: 1418.0931005362672 and parameters: {'reset_noise_scale': 0.18794995104845327, 'forward_reward_weight': 1.783313548184445, 'ctrl_cost_weight': 1.265253250031474, 'healthy_reward': 2.3390671336319566, 'contact_cost_weight': 4.816060468016024e-05, 'healthy_z_lower': 0.2656772592870868, 'healthy_z_upper': 1.368995125674889, 'contact_force_min': -1.204894691656382, 'contact_force_max': 0.8894669751977626, 'learning_rate': 0.0006015910404090773, 'learning_starts': 5000, 'batch_size': 512, 'gamma': 0.942410606270444, 'tau': 0.022223270669116734, 'ent_coef': 0.04322201486560215, 'train_freq': 3, 'gradient_steps': 7}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:41:22,176] Trial 285 finished with value: 840.6179789970495 and parameters: {'reset_noise_scale': 0.21292651680053787, 'forward_reward_weight': 1.6301369972779212, 'ctrl_cost_weight': 1.3051334621224118, 'healthy_reward': 2.3707284723410944, 'contact_cost_weight': 7.869828239339098e-05, 'healthy_z_lower': 0.2757791007742938, 'healthy_z_upper': 1.3460080786682669, 'contact_force_min': -1.236362608653728, 'contact_force_max': 0.9217198188109456, 'learning_rate': 0.0008291609037289791, 'learning_starts': 10000, 'batch_size': 1024, 'gamma': 0.9564594175777931, 'tau': 0.028097926027158795, 'ent_coef': 0.04096924129332791, 'train_freq': 4, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:43:41,560] Trial 286 finished with value: 2440.1637807022266 and parameters: {'reset_noise_scale': 0.20294485145601374, 'forward_reward_weight': 1.7962765771677436, 'ctrl_cost_weight': 1.5993985520945877, 'healthy_reward': 2.4074157630502273, 'contact_cost_weight': 9.69657962334344e-06, 'healthy_z_lower': 0.14170613930272458, 'healthy_z_upper': 1.375895656621498, 'contact_force_min': -1.218842259243883, 'contact_force_max': 0.8970328041729765, 'learning_rate': 0.0005358194132529924, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9546579515751262, 'tau': 0.023908177252903708, 'ent_coef': 0.038748078318320625, 'train_freq': 3, 'gradient_steps': 7}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:45:50,428] Trial 287 finished with value: 2209.920849873324 and parameters: {'reset_noise_scale': 0.14746347515395625, 'forward_reward_weight': 1.612252143975468, 'ctrl_cost_weight': 1.2844192696933574, 'healthy_reward': 2.384468303575984, 'contact_cost_weight': 8.138063499533494e-05, 'healthy_z_lower': 0.15261973571552398, 'healthy_z_upper': 1.3090397708395642, 'contact_force_min': -1.2812653216658245, 'contact_force_max': 0.9024067303787413, 'learning_rate': 0.0007256746100918493, 'learning_starts': 2000, 'batch_size': 512, 'gamma': 0.9537131877440322, 'tau': 0.018849676017750196, 'ent_coef': 0.02981847862101333, 'train_freq': 3, 'gradient_steps': 5}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:53:55,941] Trial 288 finished with value: 1728.9941105231464 and parameters: {'reset_noise_scale': 0.19648660039634422, 'forward_reward_weight': 1.6243030233725353, 'ctrl_cost_weight': 1.233303761440796, 'healthy_reward': 2.396970421374251, 'contact_cost_weight': 7.437155834201211e-05, 'healthy_z_lower': 0.18021226024762738, 'healthy_z_upper': 1.3612663509160048, 'contact_force_min': -1.2475916762102324, 'contact_force_max': 0.8815951138787078, 'learning_rate': 0.0009941771345446855, 'learning_starts': 10000, 'batch_size': 2048, 'gamma': 0.945131668752375, 'tau': 0.0212263266843633, 'ent_coef': 0.02261197662706621, 'train_freq': 2, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:56:36,309] Trial 289 finished with value: 2189.3860385753364 and parameters: {'reset_noise_scale': 0.20863996733737583, 'forward_reward_weight': 1.61926394784095, 'ctrl_cost_weight': 1.4865675855556675, 'healthy_reward': 2.288356993343441, 'contact_cost_weight': 3.565335192371251e-05, 'healthy_z_lower': 0.1685480563002464, 'healthy_z_upper': 1.3400985532356364, 'contact_force_min': -1.2108538095372883, 'contact_force_max': 0.9084667542427873, 'learning_rate': 0.0006159072930686031, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9579937808366799, 'tau': 0.015658646832675618, 'ent_coef': 0.0524315250619318, 'train_freq': 3, 'gradient_steps': 9}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 20:58:25,476] Trial 290 finished with value: 2530.9681446645745 and parameters: {'reset_noise_scale': 0.19094246597205639, 'forward_reward_weight': 1.6343100922846183, 'ctrl_cost_weight': 1.5684027354400336, 'healthy_reward': 2.4201035430091307, 'contact_cost_weight': 1.1579467063973572e-05, 'healthy_z_lower': 0.14415862496765772, 'healthy_z_upper': 1.327214200371883, 'contact_force_min': -1.2267275458757712, 'contact_force_max': 0.8425523819643391, 'learning_rate': 0.0007813193016437386, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9553249042959642, 'tau': 0.022754806682224887, 'ent_coef': 0.04880191312733646, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:00:20,061] Trial 291 finished with value: 2091.71454257026 and parameters: {'reset_noise_scale': 0.1853144670256692, 'forward_reward_weight': 1.770200556745048, 'ctrl_cost_weight': 1.5576475367625626, 'healthy_reward': 2.4228716792375504, 'contact_cost_weight': 1.4745370789351095e-05, 'healthy_z_lower': 0.14316228855287674, 'healthy_z_upper': 1.3158997917198085, 'contact_force_min': -1.2255934390162821, 'contact_force_max': 0.8600751294018117, 'learning_rate': 0.0004839546679785792, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9553224752704255, 'tau': 0.022225475616599863, 'ent_coef': 0.049956546466299476, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:02:13,192] Trial 292 finished with value: 2177.454597973903 and parameters: {'reset_noise_scale': 0.1909396930965117, 'forward_reward_weight': 1.6288608215225846, 'ctrl_cost_weight': 1.3400914712506133, 'healthy_reward': 2.4333779993662543, 'contact_cost_weight': 1.2170948944227212e-05, 'healthy_z_lower': 0.13592368001060987, 'healthy_z_upper': 1.3231162462606503, 'contact_force_min': -1.217709528840813, 'contact_force_max': 0.8485781068608301, 'learning_rate': 0.0007693479812725148, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9559961922717861, 'tau': 0.020153650008154583, 'ent_coef': 0.04786443777039144, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:04:05,449] Trial 293 finished with value: 2216.3692853539183 and parameters: {'reset_noise_scale': 0.19873352705917374, 'forward_reward_weight': 1.607405447081634, 'ctrl_cost_weight': 1.5683062207398344, 'healthy_reward': 2.4163176436888505, 'contact_cost_weight': 1.3826405874102584e-05, 'healthy_z_lower': 0.14472385689718692, 'healthy_z_upper': 1.3801146518967076, 'contact_force_min': -1.1868048481770974, 'contact_force_max': 0.8482071685021553, 'learning_rate': 0.0006557881912166518, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9417340703459008, 'tau': 0.02294529371990056, 'ent_coef': 0.04448435986629909, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:05:54,050] Trial 294 finished with value: 2297.0136900606913 and parameters: {'reset_noise_scale': 0.1925920457616438, 'forward_reward_weight': 1.6347473204922964, 'ctrl_cost_weight': 1.5670940029156595, 'healthy_reward': 2.3631252877932445, 'contact_cost_weight': 1.1466619033675653e-05, 'healthy_z_lower': 0.150024223906126, 'healthy_z_upper': 1.3269641910884782, 'contact_force_min': -1.2316933347842383, 'contact_force_max': 0.8365670690913488, 'learning_rate': 0.00040835343014999, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9552656992636014, 'tau': 0.0242669000066213, 'ent_coef': 0.049234459028399444, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:07:54,527] Trial 295 finished with value: 2525.199121962512 and parameters: {'reset_noise_scale': 0.1791310346417161, 'forward_reward_weight': 1.6181748877625506, 'ctrl_cost_weight': 1.5488998689429292, 'healthy_reward': 2.2619197492589156, 'contact_cost_weight': 8.722809436333821e-05, 'healthy_z_lower': 0.15892065013084863, 'healthy_z_upper': 1.3686106601319112, 'contact_force_min': -1.224561252907548, 'contact_force_max': 0.8535855417258909, 'learning_rate': 0.0005842593514725977, 'learning_starts': 4000, 'batch_size': 512, 'gamma': 0.954225410734916, 'tau': 0.0215839395860322, 'ent_coef': 0.004391767356626763, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:09:56,332] Trial 296 finished with value: 2391.246348876454 and parameters: {'reset_noise_scale': 0.2051922945914318, 'forward_reward_weight': 1.6232317495678674, 'ctrl_cost_weight': 1.5742396394470073, 'healthy_reward': 2.4307497292584257, 'contact_cost_weight': 8.474460242454882e-06, 'healthy_z_lower': 0.12804556260215352, 'healthy_z_upper': 1.3749285174644308, 'contact_force_min': -1.2873446837944875, 'contact_force_max': 0.8668274424652076, 'learning_rate': 0.0008896893911801922, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9547333240204703, 'tau': 0.013272149333445223, 'ent_coef': 0.04616722948262764, 'train_freq': 3, 'gradient_steps': 7}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:11:53,357] Trial 297 finished with value: 2414.2649741240725 and parameters: {'reset_noise_scale': 0.22295744682134816, 'forward_reward_weight': 1.6131929978144068, 'ctrl_cost_weight': 1.389445783486884, 'healthy_reward': 2.4084215105836564, 'contact_cost_weight': 1.769145883747438e-05, 'healthy_z_lower': 0.15586516986778598, 'healthy_z_upper': 1.3573969642325285, 'contact_force_min': -1.2117921145815842, 'contact_force_max': 0.8917232260965446, 'learning_rate': 0.0006965737172561073, 'learning_starts': 6000, 'batch_size': 512, 'gamma': 0.9531769462266803, 'tau': 0.01821943279763036, 'ent_coef': 0.0534488689952874, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:14:23,837] Trial 298 finished with value: 2321.842590037087 and parameters: {'reset_noise_scale': 0.1862689395953827, 'forward_reward_weight': 1.8335346439618496, 'ctrl_cost_weight': 1.583928930613323, 'healthy_reward': 2.422374445840118, 'contact_cost_weight': 7.907178627146551e-05, 'healthy_z_lower': 0.16369951493711005, 'healthy_z_upper': 1.3340623112722731, 'contact_force_min': -1.2002722407804585, 'contact_force_max': 0.8123225389111468, 'learning_rate': 0.0007940006642379233, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9568656728753537, 'tau': 0.02309819272446649, 'ent_coef': 0.056229699706609154, 'train_freq': 2, 'gradient_steps': 6}. Best is trial 234 with value: 2921.6025903890572.
# [I 2025-02-17 21:16:41,049] Trial 299 finished with value: 2481.3991185977975 and parameters: {'reset_noise_scale': 0.19767625214079995, 'forward_reward_weight': 1.6384616101136862, 'ctrl_cost_weight': 1.539662122162955, 'healthy_reward': 2.3768875423279106, 'contact_cost_weight': 7.64002619855417e-05, 'healthy_z_lower': 0.13887831488253283, 'healthy_z_upper': 1.382655147973735, 'contact_force_min': -1.0782183268353076, 'contact_force_max': 0.9163795014711206, 'learning_rate': 0.0005261707530149507, 'learning_starts': 10000, 'batch_size': 1024, 'gamma': 0.9536266752919177, 'tau': 0.016895094361814997, 'ent_coef': 0.03410184179571498, 'train_freq': 3, 'gradient_steps': 5}. Best is trial 234 with value: 2921.6025903890572.
# Best hyperparameters:  {'reset_noise_scale': 0.20141630762026747, 'forward_reward_weight': 1.6278491287471968, 'ctrl_cost_weight': 1.2763028508139123, 'healthy_reward': 2.399103414226093, 'contact_cost_weight': 5.2247028604018e-06, 'healthy_z_lower': 0.16940418341206293, 'healthy_z_upper': 1.3272275689129294, 'contact_force_min': -1.2110815310071597, 'contact_force_max': 0.8982646857233315, 'learning_rate': 0.0006839314025125863, 'learning_starts': 4000, 'batch_size': 512, 'gamma': 0.9508951442412019, 'tau': 0.019742481119711143, 'ent_coef': 0.012500206557457209, 'train_freq': 3, 'gradient_steps': 7}
