# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
import numpy as np
import tensorboard
import optuna
import gc

# Install tqdm if not already installed
from tqdm.autonotebook import tqdm as notebook_tqdm


from stable_baselines3.common.evaluation import evaluate_policy

# %%
def make_env(reset_noise_scale, forward_reward_weight, ctrl_cost_weight, healthy_reward, contact_cost_weight, healthy_z_range, contact_force_range):
    """
    Crea e restituisce l'ambiente Ant-v5 dalla libreria Gymnasium con i parametri specificati.
    """
    # Ant-v5 è l’ambiente più recente in Gymnasium.
    return gym.make("Ant-v5", 
                    reset_noise_scale=reset_noise_scale, 
                    forward_reward_weight=forward_reward_weight, 
                    ctrl_cost_weight=ctrl_cost_weight, 
                    healthy_reward=healthy_reward, 
                    contact_cost_weight = contact_cost_weight,
                    healthy_z_range=healthy_z_range,
                    contact_force_range=contact_force_range)
                   # render_mode='none')

# %%
# V1 max 30

# reset_noise_scale = trial.suggest_float('reset_noise_scale', 0.05, 0.2)           # Default circa 0.1; esploriamo da 0.05 a 0.2
    # forward_reward_weight = trial.suggest_float('forward_reward_weight', 0.5, 1.5)     # Default tipico è 1; esploriamo da 0.5 a 1.5
    # ctrl_cost_weight = trial.suggest_float('ctrl_cost_weight', 0.1, 1.0)               # Default tipico 0.5; esploriamo da 0.1 a 1.0
    # healthy_reward = trial.suggest_float('healthy_reward', 0.5, 1.5)                   # Default tipico 1; esploriamo da 0.5 a 1.5
    
    # # Parametri aggiuntivi per Ant-v5
    # contact_cost_weight = trial.suggest_float('contact_cost_weight', 1e-4, 1e-3)  # Es. range intorno a 5e-4 come default
    # healthy_z_lower = trial.suggest_float('healthy_z_lower', 0.1, 0.3)             # Per definire l'intervallo di altezze "sane"
    # healthy_z_upper = trial.suggest_float('healthy_z_upper', 0.8, 1.2)
    # contact_force_min = trial.suggest_float('contact_force_min', -1.0, -0.5)         # Modificabile se usi forze di contatto
    # contact_force_max = trial.suggest_float('contact_force_max', 0.5, 1.0)


    # learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-3)
    # n_steps = trial.suggest_int('n_steps', 2048, 8192, step=2048)
    # batch_size = trial.suggest_categorical('batch_size', [64, 128, 256])  
    # # Per ambienti complessi come Ant, molti esperimenti usano gamma intorno a 0.99-0.995
    # gamma = trial.suggest_float('gamma', 0.99, 0.999)
    # gae_lambda = trial.suggest_float('gae_lambda', 0.8, 1.0)
    # clip_range = trial.suggest_float('clip_range', 0.1, 0.3) 
    # ent_coef = trial.suggest_float('ent_coef', 0.0, 0.1)



# V2 max 1600
 # Parametri dell'environment
# reset_noise_scale = trial.suggest_float('reset_noise_scale', 0.05, 0.2)           # Default circa 0.1; esploriamo da 0.05 a 0.2
# forward_reward_weight = trial.suggest_float('forward_reward_weight', 0.5, 1.5)     # Default tipico è 1; esploriamo da 0.5 a 1.5
# ctrl_cost_weight = trial.suggest_float('ctrl_cost_weight', 0.1, 1.0)               # Default tipico 0.5; esploriamo da 0.1 a 1.0
# healthy_reward = trial.suggest_float('healthy_reward', 0.5, 1.5)                   # Default tipico 1; esploriamo da 0.5 a 1.5

# # Parametri aggiuntivi per Ant-v5
# contact_cost_weight = trial.suggest_float('contact_cost_weight', 1e-4, 1e-3)  # Es. range intorno a 5e-4 come default
# healthy_z_lower = trial.suggest_float('healthy_z_lower', 0.1, 0.3)             # Per definire l'intervallo di altezze "sane"
# healthy_z_upper = trial.suggest_float('healthy_z_upper', 0.8, 1.2)
# contact_force_min = trial.suggest_float('contact_force_min', -1.0, -0.5)         # Modificabile se usi forze di contatto
# contact_force_max = trial.suggest_float('contact_force_max', 0.5, 1.0)

# # Iperparametri per il modello PPO
# learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-3)
# n_steps = trial.suggest_int('n_steps', 2048, 8192, step=2048)
# batch_size = trial.suggest_categorical('batch_size', [512, 1024, 2048, 4096])  
# # Per ambienti complessi come Ant, molti esperimenti usano gamma intorno a 0.99-0.995
# gamma = trial.suggest_float('gamma', 0.965, 0.98)
# gae_lambda = trial.suggest_float('gae_lambda', 0.9, 1.0)
# clip_range = trial.suggest_float('clip_range', 0.3, 0.5) 
# ent_coef = trial.suggest_float('ent_coef', 0.0, 0.1)



# V3 max 2130
 # Parametri dell'environment
# reset_noise_scale = trial.suggest_float('reset_noise_scale', 0.05, 0.2)           # Default circa 0.1; esploriamo da 0.05 a 0.2
# forward_reward_weight = trial.suggest_float('forward_reward_weight', 1, 1.6)     # Default tipico è 1; esploriamo da 0.5 a 1.5
# ctrl_cost_weight = trial.suggest_float('ctrl_cost_weight', 0.5, 1.2)               # Default tipico 0.5; esploriamo da 0.1 a 1.0
# healthy_reward = trial.suggest_float('healthy_reward', 1.4, 1.9)                   # Default tipico 1; esploriamo da 0.5 a 1.5

# # Parametri aggiuntivi per Ant-v5
# contact_cost_weight = trial.suggest_float('contact_cost_weight', 1e-4, 1e-3)  # Es. range intorno a 5e-4 come default
# healthy_z_lower = trial.suggest_float('healthy_z_lower', 0, 0.2)             # Per definire l'intervallo di altezze "sane"
# healthy_z_upper = trial.suggest_float('healthy_z_upper', 0.9, 1.1)
# contact_force_min = trial.suggest_float('contact_force_min', -1.0, -0.5)         # Modificabile se usi forze di contatto
# contact_force_max = trial.suggest_float('contact_force_max', 0.5, 1.0)


# # Iperparametri per il modello PPO
# learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-3)
# n_steps = trial.suggest_int('n_steps', 2048, 8192, step=2048)
# batch_size = trial.suggest_categorical('batch_size', [512, 1024, 2048, 4096])  
# # Per ambienti complessi come Ant, molti esperimenti usano gamma intorno a 0.99-0.995
# gamma = trial.suggest_float('gamma', 0.96, 0.98)
# gae_lambda = trial.suggest_float('gae_lambda', 0.88, 0.99)
# clip_range = trial.suggest_float('clip_range', 0.1, 0.3) 
# ent_coef = trial.suggest_float('ent_coef', 0.0, 0.2)


# V4 max 2681 (BEST)
# # Parametri dell'environment
# reset_noise_scale = trial.suggest_float('reset_noise_scale', 0, 0.8)           # Default circa 0.1; esploriamo da 0.05 a 0.2
# forward_reward_weight = trial.suggest_float('forward_reward_weight', 1.4, 1.8)     # Default tipico è 1; esploriamo da 0.5 a 1.5
# ctrl_cost_weight = trial.suggest_float('ctrl_cost_weight', 1.1, 1.5)               # Default tipico 0.5; esploriamo da 0.1 a 1.0
# healthy_reward = trial.suggest_float('healthy_reward', 2, 2.4)                   # Default tipico 1; esploriamo da 0.5 a 1.5

# # Parametri aggiuntivi per Ant-v5
# contact_cost_weight = trial.suggest_float('contact_cost_weight', 1e-5, 1e-4)  # Es. range intorno a 5e-4 come default
# healthy_z_lower = trial.suggest_float('healthy_z_lower', 0.25, 0.5)             # Per definire l'intervallo di altezze "sane"
# healthy_z_upper = trial.suggest_float('healthy_z_upper', 1, 1.3)
# contact_force_min = trial.suggest_float('contact_force_min', -1.2, -0.9)         # Modificabile se usi forze di contatto
# contact_force_max = trial.suggest_float('contact_force_max', 0.9, 1.2)


# # Iperparametri per il modello PPO
# learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True)
# n_steps = trial.suggest_int('n_steps', 4096, 12288, step=2048)
# batch_size = trial.suggest_categorical('batch_size', [256, 512, 1024, 2048])  
# # Per ambienti complessi come Ant, molti esperimenti usano gamma intorno a 0.99-0.995
# gamma = trial.suggest_float('gamma', 0.93, 0.96)
# gae_lambda = trial.suggest_float('gae_lambda', 0.95, 0.98)
# clip_range = trial.suggest_float('clip_range', 0, 0.2) 
# ent_coef = trial.suggest_float('ent_coef', 0.0, 0.1)


# V4
# # Parametri dell'environment
# reset_noise_scale = trial.suggest_float('reset_noise_scale', 0, 0.3)           # Default circa 0.1; esploriamo da 0.05 a 0.2
# forward_reward_weight = trial.suggest_float('forward_reward_weight', 1.6, 1.9)     # Default tipico è 1; esploriamo da 0.5 a 1.5
# ctrl_cost_weight = trial.suggest_float('ctrl_cost_weight', 1.2, 1.6)               # Default tipico 0.5; esploriamo da 0.1 a 1.0
# healthy_reward = trial.suggest_float('healthy_reward', 2.1, 2.5)                   # Default tipico 1; esploriamo da 0.5 a 1.5

# # Parametri aggiuntivi per Ant-v5
# contact_cost_weight = trial.suggest_float('contact_cost_weight', 1e-6, 1e-4)  # Es. range intorno a 5e-4 come default
# healthy_z_lower = trial.suggest_float('healthy_z_lower', 0.1, 0.4)             # Per definire l'intervallo di altezze "sane"
# healthy_z_upper = trial.suggest_float('healthy_z_upper', 1.1, 1.4)
# contact_force_min = trial.suggest_float('contact_force_min', -1.3, -1)         # Modificabile se usi forze di contatto
# contact_force_max = trial.suggest_float('contact_force_max', 0.8, 1.1)

# # Iperparametri per il modello PPO
# learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True)
# n_steps = trial.suggest_int('n_steps', 4096, 12288, step=2048)
# batch_size = trial.suggest_categorical('batch_size', [256, 512, 1024, 2048])  
# # Per ambienti complessi come Ant, molti esperimenti usano gamma intorno a 0.99-0.995
# gamma = trial.suggest_float('gamma', 0.93, 0.96)
# gae_lambda = trial.suggest_float('gae_lambda', 0.95, 0.98)
# clip_range = trial.suggest_float('clip_range', 0, 0.2) 
# ent_coef = trial.suggest_float('ent_coef', 0.0, 0.1)

# %%
# Hyperparameter tuning con Optuna

def objective(trial):
    # Parametri dell'environment
    reset_noise_scale = trial.suggest_float('reset_noise_scale', 0, 0.8)           # Default circa 0.1; esploriamo da 0.05 a 0.2
    forward_reward_weight = trial.suggest_float('forward_reward_weight', 1.4, 1.8)     # Default tipico è 1; esploriamo da 0.5 a 1.5
    ctrl_cost_weight = trial.suggest_float('ctrl_cost_weight', 1.1, 1.5)               # Default tipico 0.5; esploriamo da 0.1 a 1.0
    healthy_reward = trial.suggest_float('healthy_reward', 2, 2.4)                   # Default tipico 1; esploriamo da 0.5 a 1.5

    # Parametri aggiuntivi per Ant-v5
    contact_cost_weight = trial.suggest_float('contact_cost_weight', 1e-5, 1e-4)  # Es. range intorno a 5e-4 come default
    healthy_z_lower = trial.suggest_float('healthy_z_lower', 0.25, 0.5)             # Per definire l'intervallo di altezze "sane"
    healthy_z_upper = trial.suggest_float('healthy_z_upper', 1, 1.3)
    contact_force_min = trial.suggest_float('contact_force_min', -1.2, -0.9)         # Modificabile se usi forze di contatto
    contact_force_max = trial.suggest_float('contact_force_max', 0.9, 1.2)

    # Crea l'ambiente passando tutti i parametri
    # env = make_env(
    #     reset_noise_scale,
    #     forward_reward_weight,
    #     ctrl_cost_weight,
    #     healthy_reward,
    #     contact_cost_weight=contact_cost_weight,
    #     healthy_z_range=(healthy_z_lower, healthy_z_upper),
    #     contact_force_range=(contact_force_min, contact_force_max)
    # )
    #env = DummyVecEnv([lambda: env])

    # MULTIPROCESSING (MULTIENVIRONMENTS) 
    NUM_ENVS=4
    env = SubprocVecEnv([
        lambda: make_env(
            reset_noise_scale,
            forward_reward_weight,
            ctrl_cost_weight,
            healthy_reward,
            contact_cost_weight=contact_cost_weight,
            healthy_z_range=(healthy_z_lower, healthy_z_upper),
            contact_force_range=(contact_force_min, contact_force_max)
        ) for _ in range(NUM_ENVS)
    ])
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)
    

    env.training = False # Setta l'environment in modalità di valutazione
    env.norm_reward = False # Disabilita la normalizzazione della reward. Questo è importante per valutare correttamente il modello.
    

    # Iperparametri per il modello PPO
    learning_rate = trial.suggest_float('learning_rate', 1e-6, 1e-5, log=True)
    n_steps = trial.suggest_int('n_steps', 4096, 12288, step=2048)
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 128, 256 ])  
    # Per ambienti complessi come Ant, molti esperimenti usano gamma intorno a 0.99-0.995
    gamma = trial.suggest_float('gamma', 0.93, 0.96)
    gae_lambda = trial.suggest_float('gae_lambda', 0.95, 0.98)
    clip_range = trial.suggest_float('clip_range', 0, 0.2) 
    ent_coef = trial.suggest_float('ent_coef', 0.0, 0.1)
    
    # Nuovo iperparametro per la penalizzazione della varianza
    # std_penalty_weight = trial.suggest_float('std_penalty_weight', 0.0, 0.5)



    # Crea ed allena il modello PPO
    model = PPO("MlpPolicy", env,
                learning_rate=learning_rate,
                n_steps=n_steps,
                batch_size=batch_size,
                gamma=gamma,
                gae_lambda=gae_lambda,
                clip_range=clip_range,
                ent_coef=ent_coef,
                seed=42,
                verbose=0)
    model.learn(total_timesteps=200000)

    # Valuta il modello su 200 episodi (200 è ottimale)
    episodes = 200

    # episode_rewards = []
    # for episode in range(episodes):
    #     obs = env.reset()
    #     done = False
    #     episode_reward = 0
    #     while not done:
    #         action, _states = model.predict(obs)
    #         obs, reward, done, info = env.step(action)
    #         episode_reward += reward
    #     episode_rewards.append(episode_reward)

    # # Calcola reward media e varianza
    # mean_reward = np.mean(episode_rewards)
    # reward_std = np.std(episode_rewards)

    # # Definisce l'obiettivo: massimizzare la reward media penalizzando la varianza
    # score = mean_reward - std_penalty_weight * reward_std

    # print(f'Mean is: {mean_reward}, Std is: {reward_std}\n')



    mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=episodes)

    # Chiudi e rilascia le risorse
    env.close()
    del model, env
    gc.collect()

    return mean_reward

# Crea uno studio Optuna e ottimizza l'obiettivo
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=300)

# Stampa i migliori iperparametri trovati
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2025-02-20 19:14:25,331] A new study created in memory with name: no-name-1b93dcd5-99d3-4797-9441-e605c47522f2
# /Users/ignazioemanuelepicciche/Documents/Ignazio PC/ucbm/deep_learning/Reinforcement_Learning_MuJoCu/.venv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2025-02-20 19:16:01,225] Trial 0 finished with value: 2140.2242607528237 and parameters: {'reset_noise_scale': 0.16799371315604486, 'forward_reward_weight': 1.751842416738293, 'ctrl_cost_weight': 1.2259718573283096, 'healthy_reward': 2.127319115760623, 'contact_cost_weight': 4.224653743255615e-05, 'healthy_z_lower': 0.28082572647138015, 'healthy_z_upper': 1.0521980251917054, 'contact_force_min': -0.9990275797378833, 'contact_force_max': 1.100349317954894, 'learning_rate': 1.547836525186356e-06, 'n_steps': 6144, 'batch_size': 32, 'gamma': 0.9579964965076564, 'gae_lambda': 0.9715001079534059, 'clip_range': 0.1376091429260501, 'ent_coef': 0.004799121542302898}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:16:47,373] Trial 1 finished with value: 673.8053440191014 and parameters: {'reset_noise_scale': 0.6324186245714162, 'forward_reward_weight': 1.4991025513670904, 'ctrl_cost_weight': 1.1203140051480318, 'healthy_reward': 2.344871357996498, 'contact_cost_weight': 4.4874231691153626e-05, 'healthy_z_lower': 0.33617155634140194, 'healthy_z_upper': 1.0638663063197062, 'contact_force_min': -1.0062371721948205, 'contact_force_max': 1.016687290465162, 'learning_rate': 1.595319147399005e-06, 'n_steps': 10240, 'batch_size': 128, 'gamma': 0.9510228714262322, 'gae_lambda': 0.9748753388440291, 'clip_range': 0.016598010201599612, 'ent_coef': 0.02783292376223956}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:18:40,326] Trial 2 finished with value: 24.697681024709016 and parameters: {'reset_noise_scale': 0.5183006841531936, 'forward_reward_weight': 1.5421208292326058, 'ctrl_cost_weight': 1.2183760154343686, 'healthy_reward': 2.2714525281883575, 'contact_cost_weight': 1.91056396713958e-05, 'healthy_z_lower': 0.4423451153437327, 'healthy_z_upper': 1.1376621893895185, 'contact_force_min': -1.0748991568181447, 'contact_force_max': 0.9295539072223797, 'learning_rate': 1.4291421243269182e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9420138781228748, 'gae_lambda': 0.9587928860209096, 'clip_range': 0.1376386297384076, 'ent_coef': 0.013258451158901076}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:19:12,577] Trial 3 finished with value: 34.007758696355744 and parameters: {'reset_noise_scale': 0.3744078456724258, 'forward_reward_weight': 1.7165812587508464, 'ctrl_cost_weight': 1.4442696132561026, 'healthy_reward': 2.37754118420513, 'contact_cost_weight': 6.703143954401137e-05, 'healthy_z_lower': 0.48970667485672925, 'healthy_z_upper': 1.1776786291923165, 'contact_force_min': -1.1339227587696146, 'contact_force_max': 0.9908386951044333, 'learning_rate': 3.860735371384518e-06, 'n_steps': 10240, 'batch_size': 256, 'gamma': 0.9464632457264782, 'gae_lambda': 0.954635181183622, 'clip_range': 0.18345015911805412, 'ent_coef': 0.07412826330611826}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:20:29,040] Trial 4 finished with value: 23.48694334226195 and parameters: {'reset_noise_scale': 0.0839108400493239, 'forward_reward_weight': 1.477837999797075, 'ctrl_cost_weight': 1.455475776273408, 'healthy_reward': 2.384769052058938, 'contact_cost_weight': 1.8037580834541068e-05, 'healthy_z_lower': 0.4893517417606589, 'healthy_z_upper': 1.061747348291477, 'contact_force_min': -1.1032196532829548, 'contact_force_max': 1.0983947796622673, 'learning_rate': 4.721475435539942e-06, 'n_steps': 6144, 'batch_size': 32, 'gamma': 0.9415405602185444, 'gae_lambda': 0.9728731443759859, 'clip_range': 0.05022017767860141, 'ent_coef': 0.05854638007514093}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:21:10,477] Trial 5 finished with value: 560.147101639912 and parameters: {'reset_noise_scale': 0.6434699731085369, 'forward_reward_weight': 1.5694267627047052, 'ctrl_cost_weight': 1.2026201478946168, 'healthy_reward': 2.2978798698476233, 'contact_cost_weight': 5.7028856666288136e-05, 'healthy_z_lower': 0.3083498763382515, 'healthy_z_upper': 1.0926296025128999, 'contact_force_min': -1.0510861593756768, 'contact_force_max': 1.004633689680067, 'learning_rate': 6.018229727527878e-06, 'n_steps': 8192, 'batch_size': 256, 'gamma': 0.9344766589747493, 'gae_lambda': 0.9779853921793966, 'clip_range': 0.09226409032919346, 'ent_coef': 0.07265340222428739}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:23:24,281] Trial 6 finished with value: 700.4764785352367 and parameters: {'reset_noise_scale': 0.6957913247391287, 'forward_reward_weight': 1.6742661284655616, 'ctrl_cost_weight': 1.3168180285254873, 'healthy_reward': 2.337583828249192, 'contact_cost_weight': 9.95448800108977e-05, 'healthy_z_lower': 0.32451188372513007, 'healthy_z_upper': 1.2669654243507902, 'contact_force_min': -1.1165606829255306, 'contact_force_max': 1.1889785552622318, 'learning_rate': 3.899573475617213e-06, 'n_steps': 8192, 'batch_size': 16, 'gamma': 0.9335512179152136, 'gae_lambda': 0.9681677443872623, 'clip_range': 0.03783544725718313, 'ent_coef': 0.08889653768148577}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:25:51,072] Trial 7 finished with value: 877.6246676418139 and parameters: {'reset_noise_scale': 0.20027221869610826, 'forward_reward_weight': 1.5301316900547899, 'ctrl_cost_weight': 1.2256067616322928, 'healthy_reward': 2.0527391648291236, 'contact_cost_weight': 4.3940414315739183e-05, 'healthy_z_lower': 0.41213621666829403, 'healthy_z_upper': 1.1273264859882175, 'contact_force_min': -0.9828887244585682, 'contact_force_max': 1.0965672947393303, 'learning_rate': 5.092042848801205e-06, 'n_steps': 12288, 'batch_size': 16, 'gamma': 0.930372522193201, 'gae_lambda': 0.9774083560183381, 'clip_range': 0.04162361167267532, 'ent_coef': 0.0205212259715139}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:27:29,377] Trial 8 finished with value: 2118.424377737795 and parameters: {'reset_noise_scale': 0.13429799959213673, 'forward_reward_weight': 1.7940331186852272, 'ctrl_cost_weight': 1.1209102557410218, 'healthy_reward': 2.107452096159586, 'contact_cost_weight': 3.8701582434532205e-05, 'healthy_z_lower': 0.3101554338367462, 'healthy_z_upper': 1.1472138244590804, 'contact_force_min': -1.1380691140305943, 'contact_force_max': 1.1784604033761044, 'learning_rate': 1.2397828903585433e-06, 'n_steps': 8192, 'batch_size': 32, 'gamma': 0.9448868488126083, 'gae_lambda': 0.9742415807372757, 'clip_range': 0.09723866435540683, 'ent_coef': 0.05656470563519761}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:28:08,124] Trial 9 finished with value: 43.98090551075176 and parameters: {'reset_noise_scale': 0.0625632049592351, 'forward_reward_weight': 1.6722761258758703, 'ctrl_cost_weight': 1.4490311434980925, 'healthy_reward': 2.1727859847970965, 'contact_cost_weight': 8.390088802398203e-05, 'healthy_z_lower': 0.3823390096500332, 'healthy_z_upper': 1.1929494124538658, 'contact_force_min': -1.0010463462989658, 'contact_force_max': 1.1788383662808042, 'learning_rate': 3.1555934610208055e-06, 'n_steps': 10240, 'batch_size': 128, 'gamma': 0.9336081158788729, 'gae_lambda': 0.9742086112718907, 'clip_range': 0.14807332327980682, 'ent_coef': 0.01337123987340545}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:29:36,428] Trial 10 finished with value: 1648.8698052442062 and parameters: {'reset_noise_scale': 0.3113772800121519, 'forward_reward_weight': 1.405227530089212, 'ctrl_cost_weight': 1.3376931961439433, 'healthy_reward': 2.0171196994201437, 'contact_cost_weight': 7.27397642204093e-05, 'healthy_z_lower': 0.250202439484952, 'healthy_z_upper': 1.0231776279478941, 'contact_force_min': -0.9027284375508686, 'contact_force_max': 1.0986980643872535, 'learning_rate': 2.1766285057050728e-06, 'n_steps': 4096, 'batch_size': 32, 'gamma': 0.9590704209572275, 'gae_lambda': 0.9643556765548328, 'clip_range': 0.19749843757429528, 'ent_coef': 0.0003671439247356469}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:31:10,294] Trial 11 finished with value: 2114.8759041358203 and parameters: {'reset_noise_scale': 0.20853546799456027, 'forward_reward_weight': 1.7821041674604308, 'ctrl_cost_weight': 1.1186483505394982, 'healthy_reward': 2.118100616701787, 'contact_cost_weight': 3.395351848613245e-05, 'healthy_z_lower': 0.25530026351329793, 'healthy_z_upper': 1.2552917138741577, 'contact_force_min': -1.186605816373737, 'contact_force_max': 1.1415919390476412, 'learning_rate': 1.0533729825209723e-06, 'n_steps': 6144, 'batch_size': 32, 'gamma': 0.9596407947781, 'gae_lambda': 0.9681719087041001, 'clip_range': 0.09766194634073044, 'ent_coef': 0.04333367867923141}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:32:45,746] Trial 12 finished with value: 1959.0427010626438 and parameters: {'reset_noise_scale': 0.006703412832722272, 'forward_reward_weight': 1.7890496937226983, 'ctrl_cost_weight': 1.1775932899545414, 'healthy_reward': 2.1093245133814484, 'contact_cost_weight': 3.6288275700236846e-05, 'healthy_z_lower': 0.29401371316887703, 'healthy_z_upper': 1.0130322533765377, 'contact_force_min': -1.1995525537252993, 'contact_force_max': 1.1447554451328983, 'learning_rate': 9.543639176868722e-06, 'n_steps': 6144, 'batch_size': 32, 'gamma': 0.952277351886341, 'gae_lambda': 0.9695952226511351, 'clip_range': 0.13498492700135428, 'ent_coef': 0.04349230065008868}. Best is trial 0 with value: 2140.2242607528237.
# [I 2025-02-20 19:34:27,194] Trial 13 finished with value: 2205.662493450197 and parameters: {'reset_noise_scale': 0.20772765344297522, 'forward_reward_weight': 1.7321049332644596, 'ctrl_cost_weight': 1.2661363422851726, 'healthy_reward': 2.206996471301252, 'contact_cost_weight': 2.673160930698065e-05, 'healthy_z_lower': 0.3498019088494627, 'healthy_z_upper': 1.2194320517304493, 'contact_force_min': -0.9532228245310415, 'contact_force_max': 1.0611511267276914, 'learning_rate': 1.0666600734673966e-06, 'n_steps': 4096, 'batch_size': 32, 'gamma': 0.9532133317169009, 'gae_lambda': 0.9618450927235311, 'clip_range': 0.08115330546648353, 'ent_coef': 0.06425395409814053}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:36:05,020] Trial 14 finished with value: 2129.250065238015 and parameters: {'reset_noise_scale': 0.2816830214576056, 'forward_reward_weight': 1.7129564385258784, 'ctrl_cost_weight': 1.2745945605933395, 'healthy_reward': 2.2131588137860416, 'contact_cost_weight': 1.0775541880614393e-05, 'healthy_z_lower': 0.3520237485539782, 'healthy_z_upper': 1.2262013852105598, 'contact_force_min': -0.9351333887384957, 'contact_force_max': 1.0423612747066766, 'learning_rate': 2.049666056346001e-06, 'n_steps': 4096, 'batch_size': 32, 'gamma': 0.9545945476045675, 'gae_lambda': 0.9612106595514942, 'clip_range': 0.07030074461524621, 'ent_coef': 0.09743391915261441}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:37:35,829] Trial 15 finished with value: 1391.3774984168697 and parameters: {'reset_noise_scale': 0.44164678118026174, 'forward_reward_weight': 1.6103846807166835, 'ctrl_cost_weight': 1.358271283217881, 'healthy_reward': 2.2093950015684922, 'contact_cost_weight': 2.545960235760626e-05, 'healthy_z_lower': 0.3697508495013861, 'healthy_z_upper': 1.209120405754721, 'contact_force_min': -0.9540417879498475, 'contact_force_max': 0.9501103084550983, 'learning_rate': 2.013397932608051e-06, 'n_steps': 4096, 'batch_size': 32, 'gamma': 0.9553076182562079, 'gae_lambda': 0.9524518789799392, 'clip_range': 0.1614922203676546, 'ent_coef': 0.03456978331191851}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:39:16,110] Trial 16 finished with value: 2177.2201087900717 and parameters: {'reset_noise_scale': 0.1956296447658316, 'forward_reward_weight': 1.7312131365516596, 'ctrl_cost_weight': 1.270011895699225, 'healthy_reward': 2.1685500756410976, 'contact_cost_weight': 2.8182487082312142e-05, 'healthy_z_lower': 0.28579749941078014, 'healthy_z_upper': 1.0849581998048217, 'contact_force_min': -1.028676180496403, 'contact_force_max': 1.05992919242785, 'learning_rate': 1.016286170611e-06, 'n_steps': 6144, 'batch_size': 32, 'gamma': 0.9487532091147881, 'gae_lambda': 0.9630920960385579, 'clip_range': 0.11965336963591197, 'ent_coef': 0.07050846422449564}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:39:57,478] Trial 17 finished with value: 588.4352368791697 and parameters: {'reset_noise_scale': 0.2789275936058129, 'forward_reward_weight': 1.619395208166893, 'ctrl_cost_weight': 1.2764933963164737, 'healthy_reward': 2.260645762138939, 'contact_cost_weight': 2.636639543050484e-05, 'healthy_z_lower': 0.3982656157351193, 'healthy_z_upper': 1.2935116963460462, 'contact_force_min': -1.0379796957861338, 'contact_force_max': 1.0584483534787732, 'learning_rate': 1.088956284613748e-06, 'n_steps': 4096, 'batch_size': 256, 'gamma': 0.9490662059772131, 'gae_lambda': 0.958747770581315, 'clip_range': 0.11457198836990187, 'ent_coef': 0.07175882207202695}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:40:51,016] Trial 18 finished with value: 1130.5853380370943 and parameters: {'reset_noise_scale': 0.46797338556107, 'forward_reward_weight': 1.6621407326246649, 'ctrl_cost_weight': 1.3910433985307253, 'healthy_reward': 2.1809343443102214, 'contact_cost_weight': 5.431643192669799e-05, 'healthy_z_lower': 0.2764744741792172, 'healthy_z_upper': 1.0855110836873598, 'contact_force_min': -0.9571372553221577, 'contact_force_max': 1.0481241728466613, 'learning_rate': 2.3935230432783095e-06, 'n_steps': 6144, 'batch_size': 128, 'gamma': 0.9488537685612026, 'gae_lambda': 0.9638814192584169, 'clip_range': 0.0723340959023526, 'ent_coef': 0.0640450475400414}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:42:18,506] Trial 19 finished with value: 1791.8465231094253 and parameters: {'reset_noise_scale': 0.36967376563745713, 'forward_reward_weight': 1.750276203693683, 'ctrl_cost_weight': 1.2791648546659098, 'healthy_reward': 2.2401719209317066, 'contact_cost_weight': 5.4072877155571505e-05, 'healthy_z_lower': 0.35636608220601557, 'healthy_z_upper': 1.1710219314697523, 'contact_force_min': -0.9033653978144843, 'contact_force_max': 0.9605673676386982, 'learning_rate': 1.0156334183460527e-06, 'n_steps': 4096, 'batch_size': 32, 'gamma': 0.941186036534714, 'gae_lambda': 0.9577554139012607, 'clip_range': 0.0028737840634542045, 'ent_coef': 0.08424788051809488}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:43:35,236] Trial 20 finished with value: 22.238002401445993 and parameters: {'reset_noise_scale': 0.7917462390507268, 'forward_reward_weight': 1.7196331868100116, 'ctrl_cost_weight': 1.3943069564828157, 'healthy_reward': 2.1577405407954786, 'contact_cost_weight': 1.0147086355028684e-05, 'healthy_z_lower': 0.42843240958618767, 'healthy_z_upper': 1.104440263229405, 'contact_force_min': -1.03364252331089, 'contact_force_max': 1.0591840151690366, 'learning_rate': 1.6797019810886645e-06, 'n_steps': 6144, 'batch_size': 32, 'gamma': 0.955220183159346, 'gae_lambda': 0.9616538115063649, 'clip_range': 0.07059884464794258, 'ent_coef': 0.04879043018945263}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:45:09,703] Trial 21 finished with value: 2160.8237483724065 and parameters: {'reset_noise_scale': 0.1813142180094123, 'forward_reward_weight': 1.741377918269433, 'ctrl_cost_weight': 1.1672688499028971, 'healthy_reward': 2.1452346438225387, 'contact_cost_weight': 2.8656192366629636e-05, 'healthy_z_lower': 0.2790579944701771, 'healthy_z_upper': 1.0394004473209826, 'contact_force_min': -0.9917492739033364, 'contact_force_max': 1.081350616051815, 'learning_rate': 1.341635564035821e-06, 'n_steps': 6144, 'batch_size': 32, 'gamma': 0.9573936025418587, 'gae_lambda': 0.9669533716331599, 'clip_range': 0.11854450373831414, 'ent_coef': 0.08249330111835126}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:46:48,952] Trial 22 finished with value: 2007.1749896943093 and parameters: {'reset_noise_scale': 0.24984100133125742, 'forward_reward_weight': 1.6357081960124387, 'ctrl_cost_weight': 1.1763650301173065, 'healthy_reward': 2.073793186732643, 'contact_cost_weight': 2.8540930338323623e-05, 'healthy_z_lower': 0.28135171066217096, 'healthy_z_upper': 1.0363669661430426, 'contact_force_min': -0.9748379936872617, 'contact_force_max': 1.0728483225701593, 'learning_rate': 1.3067020410762262e-06, 'n_steps': 6144, 'batch_size': 32, 'gamma': 0.9518313579453745, 'gae_lambda': 0.9658740700718188, 'clip_range': 0.11916107035321977, 'ent_coef': 0.08375252548981389}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:48:19,938] Trial 23 finished with value: 2169.611000637226 and parameters: {'reset_noise_scale': 0.11136915138590871, 'forward_reward_weight': 1.7484207992160887, 'ctrl_cost_weight': 1.1657409693523877, 'healthy_reward': 2.1563541416228724, 'contact_cost_weight': 1.90126350315675e-05, 'healthy_z_lower': 0.33076624955138745, 'healthy_z_upper': 1.0021147566479887, 'contact_force_min': -0.9308497853685425, 'contact_force_max': 1.1379683531996687, 'learning_rate': 1.214428935584862e-06, 'n_steps': 4096, 'batch_size': 32, 'gamma': 0.9550509218328473, 'gae_lambda': 0.9618403183869197, 'clip_range': 0.11924960741833598, 'ent_coef': 0.09983032480717775}. Best is trial 13 with value: 2205.662493450197.
# [I 2025-02-20 19:49:50,067] Trial 24 finished with value: 2240.1591939795017 and parameters: {'reset_noise_scale': 0.0010620000142161495, 'forward_reward_weight': 1.691312740027428, 'ctrl_cost_weight': 1.244616151733166, 'healthy_reward': 2.225658700012103, 'contact_cost_weight': 1.8764976122612222e-05, 'healthy_z_lower': 0.3359629552494777, 'healthy_z_upper': 1.0049382486628855, 'contact_force_min': -0.9300034994591404, 'contact_force_max': 1.1320715609397027, 'learning_rate': 1.005058974156716e-06, 'n_steps': 4096, 'batch_size': 32, 'gamma': 0.9465765228316961, 'gae_lambda': 0.9609946043793294, 'clip_range': 0.1640071710175336, 'ent_coef': 0.0991793058183505}. Best is trial 24 with value: 2240.1591939795017.
# [I 2025-02-20 19:51:20,683] Trial 25 finished with value: 2234.781053643711 and parameters: {'reset_noise_scale': 0.04795968407523407, 'forward_reward_weight': 1.6957867614799667, 'ctrl_cost_weight': 1.260500350560815, 'healthy_reward': 2.226004528114912, 'contact_cost_weight': 1.843288151484185e-05, 'healthy_z_lower': 0.34586235532282994, 'healthy_z_upper': 1.1165683160495004, 'contact_force_min': -0.9292455349952788, 'contact_force_max': 1.1221502110768196, 'learning_rate': 2.738902181753676e-06, 'n_steps': 4096, 'batch_size': 32, 'gamma': 0.9449822118112607, 'gae_lambda': 0.9577753225292255, 'clip_range': 0.17258392019563473, 'ent_coef': 0.06743399043982318}. Best is trial 24 with value: 2240.1591939795017.
# [I 2025-02-20 19:52:12,461] Trial 26 finished with value: 2301.526353570819 and parameters: {'reset_noise_scale': 0.0075253785535566164, 'forward_reward_weight': 1.6912704219747807, 'ctrl_cost_weight': 1.2491593615726693, 'healthy_reward': 2.2977803299024964, 'contact_cost_weight': 1.60671909907419e-05, 'healthy_z_lower': 0.3466074363378393, 'healthy_z_upper': 1.2386317047718807, 'contact_force_min': -0.9253550489376939, 'contact_force_max': 1.1261973605040687, 'learning_rate': 2.8312426114755592e-06, 'n_steps': 4096, 'batch_size': 256, 'gamma': 0.9390059740945315, 'gae_lambda': 0.9501130918715822, 'clip_range': 0.17347276101089346, 'ent_coef': 0.0635069456713282}. Best is trial 26 with value: 2301.526353570819.
# [I 2025-02-20 19:52:51,349] Trial 27 finished with value: 162.0238918571092 and parameters: {'reset_noise_scale': 0.003800417526739309, 'forward_reward_weight': 1.6934083698175608, 'ctrl_cost_weight': 1.2440074108238433, 'healthy_reward': 2.3044485499179737, 'contact_cost_weight': 1.7622250303882823e-05, 'healthy_z_lower': 0.38507655204918945, 'healthy_z_upper': 1.1156690203278274, 'contact_force_min': -0.9280344922314855, 'contact_force_max': 1.1497927593602237, 'learning_rate': 2.95004144626704e-06, 'n_steps': 4096, 'batch_size': 256, 'gamma': 0.938217270632926, 'gae_lambda': 0.9508180325822152, 'clip_range': 0.16872090182379573, 'ent_coef': 0.09059580579522672}. Best is trial 26 with value: 2301.526353570819.
# [I 2025-02-20 19:53:45,047] Trial 28 finished with value: 2250.433170133829 and parameters: {'reset_noise_scale': 0.04706525464940583, 'forward_reward_weight': 1.5880768541361174, 'ctrl_cost_weight': 1.3068037978553453, 'healthy_reward': 2.2405533748192563, 'contact_cost_weight': 1.0288950524074811e-05, 'healthy_z_lower': 0.3134222114786319, 'healthy_z_upper': 1.1646644784483429, 'contact_force_min': -0.9206800707922548, 'contact_force_max': 1.1366583848573144, 'learning_rate': 2.671970205239866e-06, 'n_steps': 4096, 'batch_size': 256, 'gamma': 0.9445996952447547, 'gae_lambda': 0.9557256879720716, 'clip_range': 0.17620782745608046, 'ent_coef': 0.0569709293595677}. Best is trial 26 with value: 2301.526353570819.
# [I 2025-02-20 19:54:41,707] Trial 29 finished with value: 2297.826965522319 and parameters: {'reset_noise_scale': 0.13127896969412683, 'forward_reward_weight': 1.5907872829839684, 'ctrl_cost_weight': 1.3326807619561767, 'healthy_reward': 2.28859973771136, 'contact_cost_weight': 1.1117488506017197e-05, 'healthy_z_lower': 0.3211546329675186, 'healthy_z_upper': 1.2412185159255809, 'contact_force_min': -0.9172973448631763, 'contact_force_max': 1.1277691901830944, 'learning_rate': 7.430239324906457e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.9386890859701428, 'gae_lambda': 0.9547104602520646, 'clip_range': 0.19028142542169904, 'ent_coef': 0.03691968108191371}. Best is trial 26 with value: 2301.526353570819.
# [I 2025-02-20 19:55:39,761] Trial 30 finished with value: 2308.0772662433983 and parameters: {'reset_noise_scale': 0.10951673899414721, 'forward_reward_weight': 1.5810231806932722, 'ctrl_cost_weight': 1.304597678054345, 'healthy_reward': 2.300008831544309, 'contact_cost_weight': 1.0097274493547702e-05, 'healthy_z_lower': 0.31516194234149025, 'healthy_z_upper': 1.2418203573967042, 'contact_force_min': -0.904246305577029, 'contact_force_max': 1.16323565085796, 'learning_rate': 8.020482576418814e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.9389372522769445, 'gae_lambda': 0.9546195061342578, 'clip_range': 0.19225493872523589, 'ent_coef': 0.03664242399684756}. Best is trial 30 with value: 2308.0772662433983.
# [I 2025-02-20 19:56:37,261] Trial 31 finished with value: 2302.8093543079494 and parameters: {'reset_noise_scale': 0.09545540512850827, 'forward_reward_weight': 1.5676057124343001, 'ctrl_cost_weight': 1.3300414632427058, 'healthy_reward': 2.299710133107881, 'contact_cost_weight': 1.006146363052969e-05, 'healthy_z_lower': 0.31177567034428605, 'healthy_z_upper': 1.2457670080684915, 'contact_force_min': -0.9034242037232953, 'contact_force_max': 1.1622712019713362, 'learning_rate': 8.892843547410978e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.9385399654572415, 'gae_lambda': 0.9545312955027726, 'clip_range': 0.1976981114844914, 'ent_coef': 0.03447332591500478}. Best is trial 30 with value: 2308.0772662433983.
# [I 2025-02-20 19:57:34,165] Trial 32 finished with value: 2340.129864426255 and parameters: {'reset_noise_scale': 0.12356257815135085, 'forward_reward_weight': 1.5760618234136308, 'ctrl_cost_weight': 1.359133015125306, 'healthy_reward': 2.3330048853370506, 'contact_cost_weight': 1.4052711088455958e-05, 'healthy_z_lower': 0.3010709339270886, 'healthy_z_upper': 1.2439765588293819, 'contact_force_min': -0.9154872220260659, 'contact_force_max': 1.1605132737242714, 'learning_rate': 9.368319239286716e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.9380077417687964, 'gae_lambda': 0.9503626224997899, 'clip_range': 0.19229205844545386, 'ent_coef': 0.03228646515081779}. Best is trial 32 with value: 2340.129864426255.
# [I 2025-02-20 19:58:30,807] Trial 33 finished with value: 2356.8453675872834 and parameters: {'reset_noise_scale': 0.1402254064550032, 'forward_reward_weight': 1.5436102714300335, 'ctrl_cost_weight': 1.3694207658768074, 'healthy_reward': 2.3428494517308143, 'contact_cost_weight': 1.4893759447824277e-05, 'healthy_z_lower': 0.295920030176269, 'healthy_z_upper': 1.2855704267696222, 'contact_force_min': -0.9033291565329955, 'contact_force_max': 1.1675837029665517, 'learning_rate': 8.735864185625202e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.937392540069887, 'gae_lambda': 0.951552950329929, 'clip_range': 0.19304010089834747, 'ent_coef': 0.02740363022480347}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 19:59:26,755] Trial 34 finished with value: 2336.842311537862 and parameters: {'reset_noise_scale': 0.14335350401420846, 'forward_reward_weight': 1.5026904886639336, 'ctrl_cost_weight': 1.3791400167107617, 'healthy_reward': 2.327705012269884, 'contact_cost_weight': 2.3606633712485354e-05, 'healthy_z_lower': 0.2984576433985099, 'healthy_z_upper': 1.2949066745111943, 'contact_force_min': -0.9005534091924772, 'contact_force_max': 1.1636215725160148, 'learning_rate': 9.914494800260203e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.9362713391797467, 'gae_lambda': 0.9534300314989851, 'clip_range': 0.19990179024593568, 'ent_coef': 0.026930564248119793}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 20:00:22,261] Trial 35 finished with value: 2350.990035195947 and parameters: {'reset_noise_scale': 0.1446750443123297, 'forward_reward_weight': 1.4913478064771901, 'ctrl_cost_weight': 1.4876747873171647, 'healthy_reward': 2.3465667346963617, 'contact_cost_weight': 2.2527262263739314e-05, 'healthy_z_lower': 0.26524750623888327, 'healthy_z_upper': 1.299709155761833, 'contact_force_min': -0.9619909526607575, 'contact_force_max': 1.1937349436948173, 'learning_rate': 7.741334645758566e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.9361489705436776, 'gae_lambda': 0.9527701005689079, 'clip_range': 0.18523345785707748, 'ent_coef': 0.026611587996921947}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 20:01:13,141] Trial 36 finished with value: 2354.79785594292 and parameters: {'reset_noise_scale': 0.1528511715753378, 'forward_reward_weight': 1.474850287502677, 'ctrl_cost_weight': 1.418032875356594, 'healthy_reward': 2.3441231536240292, 'contact_cost_weight': 3.2882451682085697e-05, 'healthy_z_lower': 0.2635619699611266, 'healthy_z_upper': 1.2965118144588, 'contact_force_min': -0.9697155616730327, 'contact_force_max': 1.188191499378886, 'learning_rate': 6.80225472892221e-06, 'n_steps': 10240, 'batch_size': 256, 'gamma': 0.9361250994430901, 'gae_lambda': 0.9527613710112884, 'clip_range': 0.15178358907360032, 'ent_coef': 0.02504225234843612}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 20:02:01,321] Trial 37 finished with value: 2001.1894706649973 and parameters: {'reset_noise_scale': 0.34135677321784197, 'forward_reward_weight': 1.4524959959968555, 'ctrl_cost_weight': 1.4838585338459036, 'healthy_reward': 2.359702536886184, 'contact_cost_weight': 3.549369974719314e-05, 'healthy_z_lower': 0.2649759467530024, 'healthy_z_upper': 1.2679869510653408, 'contact_force_min': -0.9634073778954625, 'contact_force_max': 1.198457152777371, 'learning_rate': 6.5313647508677066e-06, 'n_steps': 10240, 'batch_size': 256, 'gamma': 0.9359427194064222, 'gae_lambda': 0.951550901515684, 'clip_range': 0.1504466397646058, 'ent_coef': 0.01334746587898865}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 20:02:42,702] Trial 38 finished with value: 1114.5817268201586 and parameters: {'reset_noise_scale': 0.5540185927210715, 'forward_reward_weight': 1.5250490814837243, 'ctrl_cost_weight': 1.4225119193087448, 'healthy_reward': 2.388706221332478, 'contact_cost_weight': 4.968584686947554e-05, 'healthy_z_lower': 0.2660406966964876, 'healthy_z_upper': 1.2764697029723757, 'contact_force_min': -0.9432137706882602, 'contact_force_max': 1.1966222552357653, 'learning_rate': 6.117327065189591e-06, 'n_steps': 10240, 'batch_size': 256, 'gamma': 0.9322339055010678, 'gae_lambda': 0.9563009896484281, 'clip_range': 0.1838113207423438, 'ent_coef': 0.021011694465600566}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 20:05:11,635] Trial 39 finished with value: 2314.385441585511 and parameters: {'reset_noise_scale': 0.238735171711212, 'forward_reward_weight': 1.4699921682209824, 'ctrl_cost_weight': 1.4848432283326645, 'healthy_reward': 2.361657225172186, 'contact_cost_weight': 2.233301674648867e-05, 'healthy_z_lower': 0.29851717859216137, 'healthy_z_upper': 1.2816751790204828, 'contact_force_min': -1.0580027545027337, 'contact_force_max': 1.1756646099173516, 'learning_rate': 5.168138014569014e-06, 'n_steps': 12288, 'batch_size': 16, 'gamma': 0.9360775279258851, 'gae_lambda': 0.9528192757708588, 'clip_range': 0.15251127509373416, 'ent_coef': 0.027185307723173555}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 20:05:43,851] Trial 40 finished with value: 28.438416429158533 and parameters: {'reset_noise_scale': 0.15874451889943314, 'forward_reward_weight': 1.434971694886139, 'ctrl_cost_weight': 1.4302927131457477, 'healthy_reward': 2.3229856013236607, 'contact_cost_weight': 3.234959614059358e-05, 'healthy_z_lower': 0.4598478477873803, 'healthy_z_upper': 1.2997755355851768, 'contact_force_min': -1.0134511217226572, 'contact_force_max': 1.186298597561905, 'learning_rate': 7.3527760517778665e-06, 'n_steps': 10240, 'batch_size': 256, 'gamma': 0.9300375343341152, 'gae_lambda': 0.9517252564237136, 'clip_range': 0.18254461986377993, 'ent_coef': 0.019620563545297735}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 20:06:39,435] Trial 41 finished with value: 2355.273762519546 and parameters: {'reset_noise_scale': 0.15610289322580326, 'forward_reward_weight': 1.506660735879394, 'ctrl_cost_weight': 1.3810513824230395, 'healthy_reward': 2.3311418410342575, 'contact_cost_weight': 2.2725577949888702e-05, 'healthy_z_lower': 0.29765554404812694, 'healthy_z_upper': 1.2822624642341434, 'contact_force_min': -0.9776740628754688, 'contact_force_max': 1.1611586567311711, 'learning_rate': 9.98309896285751e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.9364051178865741, 'gae_lambda': 0.9531102656450621, 'clip_range': 0.19907829652033182, 'ent_coef': 0.027575801625812916}. Best is trial 33 with value: 2356.8453675872834.
# [I 2025-02-20 20:07:34,338] Trial 42 finished with value: 2369.4510241599382 and parameters: {'reset_noise_scale': 0.0756416498245236, 'forward_reward_weight': 1.5029934417049429, 'ctrl_cost_weight': 1.4119096333357073, 'healthy_reward': 2.3600021656856156, 'contact_cost_weight': 4.068863571988677e-05, 'healthy_z_lower': 0.26948971780947373, 'healthy_z_upper': 1.2811272639279794, 'contact_force_min': -0.9745568277424985, 'contact_force_max': 1.1122037554581796, 'learning_rate': 8.42110095211217e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.9427159010304595, 'gae_lambda': 0.9529184757210343, 'clip_range': 0.1840900885298448, 'ent_coef': 0.00801563604950532}. Best is trial 42 with value: 2369.4510241599382.
# [I 2025-02-20 20:08:29,765] Trial 43 finished with value: 2374.568731185496 and parameters: {'reset_noise_scale': 0.0796464867181021, 'forward_reward_weight': 1.497601127820699, 'ctrl_cost_weight': 1.415235598483021, 'healthy_reward': 2.367324828217111, 'contact_cost_weight': 4.045085302343206e-05, 'healthy_z_lower': 0.2655831948613639, 'healthy_z_upper': 1.2621491443928545, 'contact_force_min': -0.975630557597442, 'contact_force_max': 1.17597370739262, 'learning_rate': 8.185087067250305e-06, 'n_steps': 12288, 'batch_size': 256, 'gamma': 0.942326830735747, 'gae_lambda': 0.9533781481719301, 'clip_range': 0.18100265044695055, 'ent_coef': 0.008625241913504781}. Best is trial 43 with value: 2374.568731185496.
# [I 2025-02-20 20:09:31,616] Trial 44 finished with value: 2404.0238720166685 and parameters: {'reset_noise_scale': 0.07128081180507044, 'forward_reward_weight': 1.5204042321907212, 'ctrl_cost_weight': 1.4077746062466552, 'healthy_reward': 2.395647207807275, 'contact_cost_weight': 4.7132478642097225e-05, 'healthy_z_lower': 0.25314253143344273, 'healthy_z_upper': 1.262573758606217, 'contact_force_min': -0.976523012875199, 'contact_force_max': 1.11373744654249, 'learning_rate': 4.009303770216917e-06, 'n_steps': 12288, 'batch_size': 128, 'gamma': 0.942253212122157, 'gae_lambda': 0.9563918919662341, 'clip_range': 0.13522983310188877, 'ent_coef': 0.006908147055792628}. Best is trial 44 with value: 2404.0238720166685.
# [I 2025-02-20 20:10:34,018] Trial 45 finished with value: 2380.295804113746 and parameters: {'reset_noise_scale': 0.07072012695207049, 'forward_reward_weight': 1.5430442223709657, 'ctrl_cost_weight': 1.4609442020342356, 'healthy_reward': 2.3735317217830216, 'contact_cost_weight': 4.245092038508952e-05, 'healthy_z_lower': 0.25057670268888405, 'healthy_z_upper': 1.260788456615766, 'contact_force_min': -1.0112801577868633, 'contact_force_max': 1.1082359751912123, 'learning_rate': 3.840223470797491e-06, 'n_steps': 12288, 'batch_size': 128, 'gamma': 0.9423757051070529, 'gae_lambda': 0.9567558377192251, 'clip_range': 0.14095355921886912, 'ent_coef': 0.0066071199385020025}. Best is trial 44 with value: 2404.0238720166685.
# [I 2025-02-20 20:11:36,155] Trial 46 finished with value: 2405.8907974112035 and parameters: {'reset_noise_scale': 0.06887812987655939, 'forward_reward_weight': 1.5475161253390741, 'ctrl_cost_weight': 1.4652242212500908, 'healthy_reward': 2.396749740373582, 'contact_cost_weight': 4.111545630651725e-05, 'healthy_z_lower': 0.250111750449222, 'healthy_z_upper': 1.2649747326159615, 'contact_force_min': -1.0147319591497108, 'contact_force_max': 1.1162663483949338, 'learning_rate': 3.6951786965629855e-06, 'n_steps': 12288, 'batch_size': 128, 'gamma': 0.9432033724529962, 'gae_lambda': 0.9570815786063964, 'clip_range': 0.1387001095826153, 'ent_coef': 0.007727769194199684}. Best is trial 46 with value: 2405.8907974112035.
# [I 2025-02-20 20:12:35,587] Trial 47 finished with value: 2397.911855056882 and parameters: {'reset_noise_scale': 0.07492805153055182, 'forward_reward_weight': 1.5488998807527248, 'ctrl_cost_weight': 1.469469256533861, 'healthy_reward': 2.3964213735559237, 'contact_cost_weight': 4.096809720749497e-05, 'healthy_z_lower': 0.25099771616773187, 'healthy_z_upper': 1.2630819617889248, 'contact_force_min': -1.0140724266198067, 'contact_force_max': 1.1125038223924864, 'learning_rate': 4.033933385071244e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9427139938837625, 'gae_lambda': 0.95605164293119, 'clip_range': 0.13505080831727154, 'ent_coef': 0.006920093899485246}. Best is trial 46 with value: 2405.8907974112035.
# [I 2025-02-20 20:13:35,132] Trial 48 finished with value: 2392.096857904196 and parameters: {'reset_noise_scale': 0.04872759381598851, 'forward_reward_weight': 1.5478231586633493, 'ctrl_cost_weight': 1.4635759819158212, 'healthy_reward': 2.396671866685225, 'contact_cost_weight': 4.6735346674231794e-05, 'healthy_z_lower': 0.2500917436401516, 'healthy_z_upper': 1.2604482003409707, 'contact_force_min': -1.018554139613783, 'contact_force_max': 1.024291925391631, 'learning_rate': 3.7500926133773507e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9407650771978863, 'gae_lambda': 0.9595233884348552, 'clip_range': 0.1340916471490888, 'ent_coef': 0.0059990520650244255}. Best is trial 46 with value: 2405.8907974112035.
# [I 2025-02-20 20:14:34,524] Trial 49 finished with value: 2403.8765272265673 and parameters: {'reset_noise_scale': 0.03956404171833562, 'forward_reward_weight': 1.5465479813875866, 'ctrl_cost_weight': 1.466844365230336, 'healthy_reward': 2.3965988909046927, 'contact_cost_weight': 6.233301997209988e-05, 'healthy_z_lower': 0.25064275305704176, 'healthy_z_upper': 1.196441901817283, 'contact_force_min': -1.0132553174335508, 'contact_force_max': 1.0280775480720015, 'learning_rate': 3.683715146397907e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9405856261445463, 'gae_lambda': 0.9589234549082365, 'clip_range': 0.13426040003354933, 'ent_coef': 0.00432974124920779}. Best is trial 46 with value: 2405.8907974112035.
# [I 2025-02-20 20:15:33,792] Trial 50 finished with value: 2405.427201165557 and parameters: {'reset_noise_scale': 0.05569519100917338, 'forward_reward_weight': 1.556646203207642, 'ctrl_cost_weight': 1.4597555859755975, 'healthy_reward': 2.3963222474324364, 'contact_cost_weight': 6.391639477827342e-05, 'healthy_z_lower': 0.255598771642775, 'healthy_z_upper': 1.1946206088495936, 'contact_force_min': -1.0792593019303727, 'contact_force_max': 1.0284254605540635, 'learning_rate': 3.6655305803971067e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.940360327995271, 'gae_lambda': 0.9594773554550057, 'clip_range': 0.1300021212255299, 'ent_coef': 0.0028431631452735502}. Best is trial 46 with value: 2405.8907974112035.
# [I 2025-02-20 20:16:32,172] Trial 51 finished with value: 2404.0190012408793 and parameters: {'reset_noise_scale': 0.04148299137346976, 'forward_reward_weight': 1.5630346035372993, 'ctrl_cost_weight': 1.4633909588080667, 'healthy_reward': 2.3961939189593506, 'contact_cost_weight': 6.368969166190987e-05, 'healthy_z_lower': 0.25457250438158213, 'healthy_z_upper': 1.2068742491207458, 'contact_force_min': -1.07064545113145, 'contact_force_max': 1.0237736619038025, 'learning_rate': 3.6824720526520017e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9411714136692289, 'gae_lambda': 0.9585273195989048, 'clip_range': 0.13041657478202667, 'ent_coef': 0.0028698621132088294}. Best is trial 46 with value: 2405.8907974112035.
# [I 2025-02-20 20:17:31,344] Trial 52 finished with value: 2412.16929443717 and parameters: {'reset_noise_scale': 0.03473808093102475, 'forward_reward_weight': 1.5586265234811865, 'ctrl_cost_weight': 1.4698539302435298, 'healthy_reward': 2.3993853582524136, 'contact_cost_weight': 6.52492074102448e-05, 'healthy_z_lower': 0.25838925070969554, 'healthy_z_upper': 1.1965043098064776, 'contact_force_min': -1.0957652368858637, 'contact_force_max': 0.9935568105238005, 'learning_rate': 4.453702011511181e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.943617983527611, 'gae_lambda': 0.9594712393523707, 'clip_range': 0.12748685861301023, 'ent_coef': 0.0004415081006586925}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:18:30,864] Trial 53 finished with value: 2392.556962695122 and parameters: {'reset_noise_scale': 0.03236563642272904, 'forward_reward_weight': 1.5236280852392143, 'ctrl_cost_weight': 1.4386701447042147, 'healthy_reward': 2.382459666695424, 'contact_cost_weight': 6.361348323756349e-05, 'healthy_z_lower': 0.2859871847876561, 'healthy_z_upper': 1.1990091320463299, 'contact_force_min': -1.0882154749442388, 'contact_force_max': 0.9866825041228882, 'learning_rate': 3.3790799766147924e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9399930296324872, 'gae_lambda': 0.9599385084567591, 'clip_range': 0.12795806872433713, 'ent_coef': 0.00036036686749676874}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:19:30,709] Trial 54 finished with value: 2408.0282035404443 and parameters: {'reset_noise_scale': 0.03508377394188646, 'forward_reward_weight': 1.563259672457593, 'ctrl_cost_weight': 1.4947143508089327, 'healthy_reward': 2.398454863802074, 'contact_cost_weight': 7.287375271606408e-05, 'healthy_z_lower': 0.2592220373142525, 'healthy_z_upper': 1.1908244387125833, 'contact_force_min': -1.0688930519089748, 'contact_force_max': 1.0288526665053337, 'learning_rate': 4.348012758228353e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9440931105416934, 'gae_lambda': 0.9580085322881773, 'clip_range': 0.10348180623278852, 'ent_coef': 0.016237360729213283}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:20:31,060] Trial 55 finished with value: 2387.1002469962837 and parameters: {'reset_noise_scale': 0.02473940429727728, 'forward_reward_weight': 1.562294802139809, 'ctrl_cost_weight': 1.494748496119858, 'healthy_reward': 2.3770622145845683, 'contact_cost_weight': 7.403601316846033e-05, 'healthy_z_lower': 0.27246828219275915, 'healthy_z_upper': 1.1832380170296146, 'contact_force_min': -1.0650070734384212, 'contact_force_max': 0.9932896529576202, 'learning_rate': 4.502040255934096e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9438396753564329, 'gae_lambda': 0.9581467522709499, 'clip_range': 0.10765836077506133, 'ent_coef': 0.017487559002910703}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:21:30,695] Trial 56 finished with value: 2390.0618799605963 and parameters: {'reset_noise_scale': 0.09413463719360282, 'forward_reward_weight': 1.607624891388646, 'ctrl_cost_weight': 1.4440704016419081, 'healthy_reward': 2.380605939572132, 'contact_cost_weight': 7.579805262890087e-05, 'healthy_z_lower': 0.28408534012756637, 'healthy_z_upper': 1.1571984582754433, 'contact_force_min': -1.1159365547157893, 'contact_force_max': 1.0103104291531841, 'learning_rate': 4.519081680991476e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9466953159027709, 'gae_lambda': 0.9604748316157126, 'clip_range': 0.08729359722528332, 'ent_coef': 0.011898385087293961}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:22:31,471] Trial 57 finished with value: 2351.382841133294 and parameters: {'reset_noise_scale': 0.23343980719629814, 'forward_reward_weight': 1.6331053994063127, 'ctrl_cost_weight': 1.498666728404645, 'healthy_reward': 2.35316329997139, 'contact_cost_weight': 7.951882483716766e-05, 'healthy_z_lower': 0.25892681927042627, 'healthy_z_upper': 1.2215203400526824, 'contact_force_min': -1.0821516682640817, 'contact_force_max': 1.0322638427832158, 'learning_rate': 5.49502234081879e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9437840832443876, 'gae_lambda': 0.9629247468406719, 'clip_range': 0.1057194062741667, 'ent_coef': 0.003288723107424777}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:23:30,901] Trial 58 finished with value: 2405.5950741937104 and parameters: {'reset_noise_scale': 0.18271446528599367, 'forward_reward_weight': 1.5642743287135659, 'ctrl_cost_weight': 1.4778471075505728, 'healthy_reward': 2.3989279364544474, 'contact_cost_weight': 6.965906940894297e-05, 'healthy_z_lower': 0.27546477587784585, 'healthy_z_upper': 1.1437744330113016, 'contact_force_min': -1.0976475079038246, 'contact_force_max': 0.9793880509088828, 'learning_rate': 3.356582194882304e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9474617610234237, 'gae_lambda': 0.956875625954645, 'clip_range': 0.12509595650661043, 'ent_coef': 0.011553274392028703}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:24:30,558] Trial 59 finished with value: 2366.228326153234 and parameters: {'reset_noise_scale': 0.18169440162162356, 'forward_reward_weight': 1.5226312099789572, 'ctrl_cost_weight': 1.4750941403185138, 'healthy_reward': 2.3727040757990085, 'contact_cost_weight': 6.98223924601225e-05, 'healthy_z_lower': 0.27548554955885574, 'healthy_z_upper': 1.1399360223790662, 'contact_force_min': -1.1477133660225742, 'contact_force_max': 0.9079514725364306, 'learning_rate': 3.3471409356236725e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9459978656193617, 'gae_lambda': 0.9575148556960931, 'clip_range': 0.14408360464353306, 'ent_coef': 0.016892197169256537}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:25:29,816] Trial 60 finished with value: 2324.037006509341 and parameters: {'reset_noise_scale': 0.09808504310940466, 'forward_reward_weight': 1.5951229041483928, 'ctrl_cost_weight': 1.448804952533715, 'healthy_reward': 2.3180047092534495, 'contact_cost_weight': 8.575702981511114e-05, 'healthy_z_lower': 0.2879174547912571, 'healthy_z_upper': 1.1786393062146914, 'contact_force_min': -1.10058964285341, 'contact_force_max': 0.9543835671376948, 'learning_rate': 4.40499464667391e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9480284889665644, 'gae_lambda': 0.9567399029399936, 'clip_range': 0.126374113230578, 'ent_coef': 0.010554257202956977}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:26:28,119] Trial 61 finished with value: 2408.5909805348515 and parameters: {'reset_noise_scale': 0.045743453790236005, 'forward_reward_weight': 1.573002652078053, 'ctrl_cost_weight': 1.4531662328863297, 'healthy_reward': 2.3982300108954613, 'contact_cost_weight': 5.873041055394072e-05, 'healthy_z_lower': 0.2610559923608697, 'healthy_z_upper': 1.2074943438704173, 'contact_force_min': -1.0468702357918174, 'contact_force_max': 0.9722246922647615, 'learning_rate': 4.236956313345806e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9500486483556058, 'gae_lambda': 0.9588481753377865, 'clip_range': 0.10786487075485605, 'ent_coef': 0.002383316898767236}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:27:27,159] Trial 62 finished with value: 2397.2860296177864 and parameters: {'reset_noise_scale': 0.017131532129502372, 'forward_reward_weight': 1.5598601208865839, 'ctrl_cost_weight': 1.478396057258781, 'healthy_reward': 2.384364003691849, 'contact_cost_weight': 5.83620169406253e-05, 'healthy_z_lower': 0.275595723617771, 'healthy_z_upper': 1.1867115857350967, 'contact_force_min': -1.0415000701239703, 'contact_force_max': 0.972925396042812, 'learning_rate': 4.215830952886542e-06, 'n_steps': 8192, 'batch_size': 128, 'gamma': 0.9501649792595086, 'gae_lambda': 0.979613677607584, 'clip_range': 0.10882149387940662, 'ent_coef': 0.01591510940009457}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:28:23,144] Trial 63 finished with value: 2384.024327724725 and parameters: {'reset_noise_scale': 0.06661313015646216, 'forward_reward_weight': 1.6241162095486252, 'ctrl_cost_weight': 1.4347645444648152, 'healthy_reward': 2.369144853751189, 'contact_cost_weight': 6.68414459609115e-05, 'healthy_z_lower': 0.25846207319989617, 'healthy_z_upper': 1.2134310048604109, 'contact_force_min': -1.050661742499035, 'contact_force_max': 0.9995057902113508, 'learning_rate': 5.032524182471669e-06, 'n_steps': 10240, 'batch_size': 128, 'gamma': 0.9458389778397912, 'gae_lambda': 0.9595504034893138, 'clip_range': 0.09418544930048367, 'ent_coef': 0.0014728063199977454}. Best is trial 52 with value: 2412.16929443717.
# [I 2025-02-20 20:29:18,327] Trial 64 finished with value: 2407.2147766744347 and parameters: {'reset_noise_scale': 0.1118798113863141, 'forward_reward_weight': 1.6053768956594932, 'ctrl_cost_weight': 1.4531768859822878, 'healthy_reward': 2.397256017266699, 'contact_cost_weight': 5.9509696138831024e-05, 'healthy_z_lower': 0.26015760276645855, 'healthy_z_upper': 1.1520514427442332, 'contact_force_min': -1.1123069996383206, 'contact_force_max': 0.9781773480601327, 'learning_rate': 3.139226834811921e-06, 'n_steps': 10240, 'batch_size': 128, 'gamma': 0.9475502768845245, 'gae_lambda': 0.9627822899223755, 'clip_range': 0.10022158693145444, 'ent_coef': 0.010283198219749826}. Best is trial 52 with value: 2412.16929443717.
# ...
# [I 2025-02-21 11:57:32,712] Trial 279 finished with value: 2427.370193166538 and parameters: {'reset_noise_scale': 0.05833443808477487, 'forward_reward_weight': 1.6697253454629022, 'ctrl_cost_weight': 1.4251586705570072, 'healthy_reward': 2.3779146679965537, 'contact_cost_weight': 5.537553708139375e-05, 'healthy_z_lower': 0.2875270886166234, 'healthy_z_upper': 1.0311960171726657, 'contact_force_min': -1.166066686212322, 'contact_force_max': 1.038162040715751, 'learning_rate': 2.6506230397504143e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9593891265891346, 'gae_lambda': 0.9610700190061648, 'clip_range': 0.14076909850691693, 'ent_coef': 0.04837225999101622}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 11:59:46,694] Trial 280 finished with value: 2497.6138648410983 and parameters: {'reset_noise_scale': 0.06432839052557772, 'forward_reward_weight': 1.6793107633862638, 'ctrl_cost_weight': 1.4186665797570823, 'healthy_reward': 2.374060222601359, 'contact_cost_weight': 5.543569480506214e-05, 'healthy_z_lower': 0.28689764170074167, 'healthy_z_upper': 1.0262367388482232, 'contact_force_min': -1.1682050773500623, 'contact_force_max': 1.0542096632781008, 'learning_rate': 2.4931482545461696e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9583659015243887, 'gae_lambda': 0.9610970481635952, 'clip_range': 0.14104391999438864, 'ent_coef': 0.04817586935057567}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:01:09,745] Trial 281 finished with value: 1309.01499955907 and parameters: {'reset_noise_scale': 0.42776779362510575, 'forward_reward_weight': 1.6750463647545364, 'ctrl_cost_weight': 1.4154493317571606, 'healthy_reward': 2.3574987142335053, 'contact_cost_weight': 4.98065280339397e-05, 'healthy_z_lower': 0.28722505979808477, 'healthy_z_upper': 1.0611176027301372, 'contact_force_min': -1.1672534066920304, 'contact_force_max': 1.055472806946433, 'learning_rate': 2.376243039294031e-06, 'n_steps': 10240, 'batch_size': 32, 'gamma': 0.9576730404307778, 'gae_lambda': 0.9610430801533592, 'clip_range': 0.14185306433910144, 'ent_coef': 0.04791099165920994}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:03:21,905] Trial 282 finished with value: 2429.6696978445584 and parameters: {'reset_noise_scale': 0.070862611684949, 'forward_reward_weight': 1.6957614647351968, 'ctrl_cost_weight': 1.404594170403853, 'healthy_reward': 2.3490371894622766, 'contact_cost_weight': 5.6417306972353236e-05, 'healthy_z_lower': 0.30011236601003766, 'healthy_z_upper': 1.0249356052001455, 'contact_force_min': -1.1712001247448194, 'contact_force_max': 1.0585730980073467, 'learning_rate': 2.5517192260167862e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9593852717870579, 'gae_lambda': 0.9611254011527619, 'clip_range': 0.14042223493136044, 'ent_coef': 0.0484150558433563}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:05:40,099] Trial 283 finished with value: 2405.7642952563333 and parameters: {'reset_noise_scale': 0.07220149133594676, 'forward_reward_weight': 1.7034304141269134, 'ctrl_cost_weight': 1.4042328266958484, 'healthy_reward': 2.3482433012600703, 'contact_cost_weight': 5.520385056436775e-05, 'healthy_z_lower': 0.30070315818810744, 'healthy_z_upper': 1.0210010875740898, 'contact_force_min': -1.1751320327697383, 'contact_force_max': 1.0640263424265939, 'learning_rate': 2.27340470842905e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9595774866986182, 'gae_lambda': 0.9607799126348101, 'clip_range': 0.13868280129609775, 'ent_coef': 0.044770959181572076}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:07:50,324] Trial 284 finished with value: 2323.991711470326 and parameters: {'reset_noise_scale': 0.07475866928828245, 'forward_reward_weight': 1.6883162834395637, 'ctrl_cost_weight': 1.4102838265245605, 'healthy_reward': 2.3523053994648926, 'contact_cost_weight': 5.313968082042595e-05, 'healthy_z_lower': 0.29555263309396207, 'healthy_z_upper': 1.0278780696118615, 'contact_force_min': -1.171182090869282, 'contact_force_max': 1.0600936585246654, 'learning_rate': 2.654745106601064e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9582431002310444, 'gae_lambda': 0.9613288856182279, 'clip_range': 0.15056236366532474, 'ent_coef': 0.048806119433799394}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:10:12,763] Trial 285 finished with value: 2375.739625191962 and parameters: {'reset_noise_scale': 0.06107445951757881, 'forward_reward_weight': 1.70043231893569, 'ctrl_cost_weight': 1.3942846898687873, 'healthy_reward': 2.3622577312854567, 'contact_cost_weight': 5.552304158098463e-05, 'healthy_z_lower': 0.291613245837436, 'healthy_z_upper': 1.031603485428658, 'contact_force_min': -1.1806713466645606, 'contact_force_max': 1.0485049056485407, 'learning_rate': 2.567519466685498e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9590763744015461, 'gae_lambda': 0.9608951481013288, 'clip_range': 0.1408728270162728, 'ent_coef': 0.04985371049220724}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:12:25,020] Trial 286 finished with value: 2328.9249438628553 and parameters: {'reset_noise_scale': 0.054957623236935794, 'forward_reward_weight': 1.6695092325732332, 'ctrl_cost_weight': 1.420644515187198, 'healthy_reward': 2.3705456492019787, 'contact_cost_weight': 5.660056057850272e-05, 'healthy_z_lower': 0.28684429515052096, 'healthy_z_upper': 1.02117995286817, 'contact_force_min': -1.0033195752305502, 'contact_force_max': 1.068468456548035, 'learning_rate': 2.479538805094364e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9596727383942176, 'gae_lambda': 0.9614376965715573, 'clip_range': 0.14080479368293305, 'ent_coef': 0.07177917352740955}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:14:37,705] Trial 287 finished with value: 2413.4526107989263 and parameters: {'reset_noise_scale': 0.07490305339235317, 'forward_reward_weight': 1.6963923059296404, 'ctrl_cost_weight': 1.428216681554429, 'healthy_reward': 2.3709888693314984, 'contact_cost_weight': 5.3487623718083906e-05, 'healthy_z_lower': 0.2933002518334117, 'healthy_z_upper': 1.0148893854095877, 'contact_force_min': -1.1843814097522138, 'contact_force_max': 1.0536571843770262, 'learning_rate': 2.5497246481802918e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9588947478964421, 'gae_lambda': 0.9605761463502764, 'clip_range': 0.14290694924826966, 'ent_coef': 0.051902540678747826}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:16:46,331] Trial 288 finished with value: 2275.8316064378805 and parameters: {'reset_noise_scale': 0.049313715453627574, 'forward_reward_weight': 1.6716555412295149, 'ctrl_cost_weight': 1.4057796301281995, 'healthy_reward': 2.2576576673864595, 'contact_cost_weight': 5.13928853071577e-05, 'healthy_z_lower': 0.2842108790535617, 'healthy_z_upper': 1.0278552645959156, 'contact_force_min': -1.164160513541334, 'contact_force_max': 1.0568700168565501, 'learning_rate': 2.646693392714949e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9583256750560621, 'gae_lambda': 0.9644203148356528, 'clip_range': 0.1363026973117171, 'ent_coef': 0.04384957480938871}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:24:00,924] Trial 289 finished with value: 2268.050653841769 and parameters: {'reset_noise_scale': 0.08560946096584444, 'forward_reward_weight': 1.6755917121904182, 'ctrl_cost_weight': 1.4166505538484047, 'healthy_reward': 2.332042663831677, 'contact_cost_weight': 4.459613528153853e-05, 'healthy_z_lower': 0.28588715335306075, 'healthy_z_upper': 1.0050506091301497, 'contact_force_min': -1.1706435937233568, 'contact_force_max': 1.077099682823615, 'learning_rate': 2.5064319702576505e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9599215391875814, 'gae_lambda': 0.9619017875752744, 'clip_range': 0.1663596990527076, 'ent_coef': 0.04723515149914671}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:45:40,493] Trial 290 finished with value: 2443.307145899132 and parameters: {'reset_noise_scale': 0.001028209718533589, 'forward_reward_weight': 1.6628896210028739, 'ctrl_cost_weight': 1.43444601424638, 'healthy_reward': 2.3768121252677354, 'contact_cost_weight': 5.464072438465513e-05, 'healthy_z_lower': 0.289892385630608, 'healthy_z_upper': 1.034417702051616, 'contact_force_min': -1.1918768351513187, 'contact_force_max': 1.0493160129463701, 'learning_rate': 2.834504621395348e-06, 'n_steps': 6144, 'batch_size': 16, 'gamma': 0.9574329625445623, 'gae_lambda': 0.9604003122789655, 'clip_range': 0.1396898674062044, 'ent_coef': 0.05586470701864281}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:48:09,773] Trial 291 finished with value: 2231.6604240686806 and parameters: {'reset_noise_scale': 0.2670459136710426, 'forward_reward_weight': 1.6839523501099918, 'ctrl_cost_weight': 1.4372394504538484, 'healthy_reward': 2.360312610264985, 'contact_cost_weight': 5.432234417298891e-05, 'healthy_z_lower': 0.29991654292351927, 'healthy_z_upper': 1.0368799161461413, 'contact_force_min': -1.160946028307163, 'contact_force_max': 1.052075344396882, 'learning_rate': 2.7207645381980915e-06, 'n_steps': 6144, 'batch_size': 16, 'gamma': 0.9563485794843749, 'gae_lambda': 0.9602447566977449, 'clip_range': 0.1378483643726533, 'ent_coef': 0.05513933303360395}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:50:53,885] Trial 292 finished with value: 2393.302169240144 and parameters: {'reset_noise_scale': 0.0054132897542684116, 'forward_reward_weight': 1.6521216681891033, 'ctrl_cost_weight': 1.431230116664397, 'healthy_reward': 2.3757392053430824, 'contact_cost_weight': 5.525579524089618e-05, 'healthy_z_lower': 0.3118913998114705, 'healthy_z_upper': 1.0347528113776931, 'contact_force_min': -1.1873429456430789, 'contact_force_max': 1.0472416556155564, 'learning_rate': 2.2533594964404253e-06, 'n_steps': 12288, 'batch_size': 16, 'gamma': 0.9574442845430057, 'gae_lambda': 0.9609098969154284, 'clip_range': 0.13658844260455977, 'ent_coef': 0.051955446393752526}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:53:28,417] Trial 293 finished with value: 2444.3669247207104 and parameters: {'reset_noise_scale': 0.06284885838826085, 'forward_reward_weight': 1.6671911344774848, 'ctrl_cost_weight': 1.3924631336842157, 'healthy_reward': 2.368855394551816, 'contact_cost_weight': 5.036107467776205e-05, 'healthy_z_lower': 0.2907520121240747, 'healthy_z_upper': 1.0156927284960413, 'contact_force_min': -1.1692635758937457, 'contact_force_max': 1.044833457770152, 'learning_rate': 2.829132570667151e-06, 'n_steps': 6144, 'batch_size': 16, 'gamma': 0.9579458482022234, 'gae_lambda': 0.9601352334034532, 'clip_range': 0.14527650430169306, 'ent_coef': 0.053025434910753955}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:56:14,101] Trial 294 finished with value: 2386.1079025819226 and parameters: {'reset_noise_scale': 0.06394205015598578, 'forward_reward_weight': 1.6589451886351123, 'ctrl_cost_weight': 1.3674435054155103, 'healthy_reward': 2.3654147730288235, 'contact_cost_weight': 5.071941820561169e-05, 'healthy_z_lower': 0.2910705373747077, 'healthy_z_upper': 1.0170139526482889, 'contact_force_min': -1.1884537666821366, 'contact_force_max': 1.0639678864799802, 'learning_rate': 2.863647307023247e-06, 'n_steps': 6144, 'batch_size': 16, 'gamma': 0.9576381846644779, 'gae_lambda': 0.9602394444917374, 'clip_range': 0.14499738235707813, 'ent_coef': 0.049734291645824644}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 12:58:46,338] Trial 295 finished with value: 2384.567562325776 and parameters: {'reset_noise_scale': 0.10131008307361938, 'forward_reward_weight': 1.7149432777619917, 'ctrl_cost_weight': 1.3970097464498312, 'healthy_reward': 2.3401806077769596, 'contact_cost_weight': 5.2405026183138743e-05, 'healthy_z_lower': 0.2988235276221695, 'healthy_z_upper': 1.0094029258988313, 'contact_force_min': -1.1776641828307608, 'contact_force_max': 1.0396874987377482, 'learning_rate': 2.398806925566979e-06, 'n_steps': 6144, 'batch_size': 16, 'gamma': 0.9568094347837446, 'gae_lambda': 0.9612060946583392, 'clip_range': 0.15562715624527096, 'ent_coef': 0.05755785944004573}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 13:01:04,122] Trial 296 finished with value: 2192.9343789171758 and parameters: {'reset_noise_scale': 0.00478100960765138, 'forward_reward_weight': 1.6622614697960816, 'ctrl_cost_weight': 1.3869169924638436, 'healthy_reward': 2.355097707645005, 'contact_cost_weight': 4.9784107811440395e-05, 'healthy_z_lower': 0.30536240840089074, 'healthy_z_upper': 1.0296409299762723, 'contact_force_min': -1.1939385729057852, 'contact_force_max': 1.0408815013152857, 'learning_rate': 2.834628708857702e-06, 'n_steps': 6144, 'batch_size': 16, 'gamma': 0.9580789791335279, 'gae_lambda': 0.9602137139087935, 'clip_range': 0.14746372437753533, 'ent_coef': 0.053575560229541866}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 13:03:23,739] Trial 297 finished with value: 2209.4908168335423 and parameters: {'reset_noise_scale': 0.07647478202539705, 'forward_reward_weight': 1.6805543280954625, 'ctrl_cost_weight': 1.2682169928253566, 'healthy_reward': 2.1937449113153558, 'contact_cost_weight': 5.621340263207132e-05, 'healthy_z_lower': 0.29465133157810586, 'healthy_z_upper': 1.0238528536763503, 'contact_force_min': -1.1681926728462904, 'contact_force_max': 1.0375145973402278, 'learning_rate': 2.5822175684902544e-06, 'n_steps': 6144, 'batch_size': 16, 'gamma': 0.9573275117612714, 'gae_lambda': 0.9606264895287621, 'clip_range': 0.14227643369657125, 'ent_coef': 0.056617838524745286}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 13:05:41,597] Trial 298 finished with value: 1336.9991971784655 and parameters: {'reset_noise_scale': 0.38736506253194103, 'forward_reward_weight': 1.6657736731407424, 'ctrl_cost_weight': 1.408515089127662, 'healthy_reward': 2.3699634393304514, 'contact_cost_weight': 4.621081865493241e-05, 'healthy_z_lower': 0.2891331742231265, 'healthy_z_upper': 1.0332438338752064, 'contact_force_min': -1.1952671703775195, 'contact_force_max': 1.058250193055304, 'learning_rate': 2.6708395484533488e-06, 'n_steps': 6144, 'batch_size': 16, 'gamma': 0.9582885933031118, 'gae_lambda': 0.9616253466242105, 'clip_range': 0.1606166169777405, 'ent_coef': 0.05175804340403616}. Best is trial 270 with value: 2515.529357174921.
# [I 2025-02-21 13:06:36,855] Trial 299 finished with value: 2386.6130095797776 and parameters: {'reset_noise_scale': 0.04254833308856768, 'forward_reward_weight': 1.6506480511351487, 'ctrl_cost_weight': 1.4163076856628576, 'healthy_reward': 2.3771171852230712, 'contact_cost_weight': 5.269706391043996e-05, 'healthy_z_lower': 0.28356942674036356, 'healthy_z_upper': 1.016638024369323, 'contact_force_min': -1.1800506475567412, 'contact_force_max': 1.1019667753685698, 'learning_rate': 2.774976370013487e-06, 'n_steps': 6144, 'batch_size': 256, 'gamma': 0.9588984115740572, 'gae_lambda': 0.9610933790427039, 'clip_range': 0.1506448790083041, 'ent_coef': 0.045814910133601304}. Best is trial 270 with value: 2515.529357174921.
# Best hyperparameters:  {'reset_noise_scale': 0.036384281716755174, 'forward_reward_weight': 1.6734584377802377, 'ctrl_cost_weight': 1.4114977503409765, 'healthy_reward': 2.3778485263135485, 'contact_cost_weight': 5.2035838720379083e-05, 'healthy_z_lower': 0.28072846666427437, 'healthy_z_upper': 1.0352095932018308, 'contact_force_min': -1.1644341511298375, 'contact_force_max': 1.0234607887152494, 'learning_rate': 3.1894181556364527e-06, 'n_steps': 10240, 'batch_size': 16, 'gamma': 0.9594058727562937, 'gae_lambda': 0.9620126823049164, 'clip_range': 0.14604633707952877, 'ent_coef': 0.06672931495998022}
