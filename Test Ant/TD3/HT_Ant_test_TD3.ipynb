# %%
import gymnasium as gym
from stable_baselines3 import TD3
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import numpy as np
import tensorboard
import optuna
import gc
from stable_baselines3.common.noise import NormalActionNoise

# %%
def make_env(reset_noise_scale, forward_reward_weight, ctrl_cost_weight, healthy_reward, contact_cost_weight, healthy_z_range, contact_force_range):
    """
    Crea e restituisce l'ambiente Ant-v5 dalla libreria Gymnasium con i parametri specificati.
    """
    # Ant-v5 è l’ambiente più recente in Gymnasium.
    return gym.make("Ant-v5", 
                    reset_noise_scale=reset_noise_scale, 
                    forward_reward_weight=forward_reward_weight, 
                    ctrl_cost_weight=ctrl_cost_weight, 
                    healthy_reward=healthy_reward, 
                    contact_cost_weight = contact_cost_weight,
                    healthy_z_range=healthy_z_range,
                    contact_force_range=contact_force_range)
                   # render_mode='none')

# %%
def objective(trial):
    # Parametri dell'environment
    reset_noise_scale = trial.suggest_float('reset_noise_scale', 0, 0.3)
    forward_reward_weight = trial.suggest_float('forward_reward_weight', 1.6, 1.9)
    ctrl_cost_weight = trial.suggest_float('ctrl_cost_weight', 1.2, 1.6)
    healthy_reward = trial.suggest_float('healthy_reward', 2.1, 2.5)
    contact_cost_weight = trial.suggest_float('contact_cost_weight', 1e-6, 1e-4)
    healthy_z_lower = trial.suggest_float('healthy_z_lower', 0.1, 0.4)
    healthy_z_upper = trial.suggest_float('healthy_z_upper', 1.1, 1.4)
    contact_force_min = trial.suggest_float('contact_force_min', -1.3, -1)
    contact_force_max = trial.suggest_float('contact_force_max', 0.8, 1.1)

    NUM_ENVS = 6
    env = SubprocVecEnv([
        lambda: make_env(
            reset_noise_scale,
            forward_reward_weight,
            ctrl_cost_weight,
            healthy_reward,
            contact_cost_weight, 
            healthy_z_range=(healthy_z_lower, healthy_z_upper),
            contact_force_range=(contact_force_min, contact_force_max)
        ) for _ in range(NUM_ENVS)
    ])
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    env.training = False
    env.norm_reward = False

    # Parametri di ottimizzazione per TD3
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True)
    learning_starts = trial.suggest_int('learning_starts', 1000, 10000, step=1000)
    batch_size = trial.suggest_categorical('batch_size', [256, 512, 1024, 2048])  
    gamma = trial.suggest_float('gamma', 0.93, 0.96)
    tau = trial.suggest_float('tau', 0.005, 0.05)
    noise_std = trial.suggest_float('noise_std', 0.1, 0.5)  # Stddev per NormalActionNoise
    noise_clip = trial.suggest_float('noise_clip', 0.2, 0.5)
    policy_delay = trial.suggest_int('policy_delay', 1, 3)
    train_freq = trial.suggest_int('train_freq', 1, 10)
    gradient_steps = trial.suggest_int('gradient_steps', 1, 10)

    # Definiamo il noise per l'azione
    action_noise = NormalActionNoise(mean=np.zeros(8), sigma=noise_std * np.ones(8))

    model = TD3("MlpPolicy", env,
                learning_rate=learning_rate,
                buffer_size=50000,
                learning_starts=learning_starts,
                batch_size=batch_size,
                gamma=gamma,
                tau=tau,
                action_noise=action_noise,
                policy_delay=policy_delay,
                train_freq=train_freq,
                gradient_steps=gradient_steps,
                seed=42,
                verbose=0)
    model.learn(total_timesteps=50000)

    episodes = 200
    mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=episodes)

    env.close()
    del model, env
    gc.collect()

    return mean_reward

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=300)

print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2025-02-18 09:34:26,458] A new study created in memory with name: no-name-d41f3e7c-b192-488e-92c1-47df582b5a34
# /Users/fabiodigregorio/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2025-02-18 09:35:56,316] Trial 0 finished with value: 1908.7595740269455 and parameters: {'reset_noise_scale': 0.00897325206209999, 'forward_reward_weight': 1.742233833714926, 'ctrl_cost_weight': 1.4779971438910726, 'healthy_reward': 2.1232070898906956, 'contact_cost_weight': 9.672108021212856e-06, 'healthy_z_lower': 0.30548411186006724, 'healthy_z_upper': 1.2978014501390338, 'contact_force_min': -1.2030516632763952, 'contact_force_max': 1.0144279949808082, 'learning_rate': 0.0006235893581706442, 'learning_starts': 6000, 'batch_size': 1024, 'gamma': 0.9477150142917476, 'tau': 0.04045128932455767, 'noise_std': 0.4441567435302099, 'noise_clip': 0.24980649346041434, 'policy_delay': 3, 'train_freq': 6, 'gradient_steps': 4}. Best is trial 0 with value: 1908.7595740269455.
# [I 2025-02-18 09:36:34,045] Trial 1 finished with value: -1805.9762292411515 and parameters: {'reset_noise_scale': 0.2162568207717528, 'forward_reward_weight': 1.6073971336204613, 'ctrl_cost_weight': 1.495960845316337, 'healthy_reward': 2.243224615956436, 'contact_cost_weight': 7.891932864165733e-05, 'healthy_z_lower': 0.18183000012666634, 'healthy_z_upper': 1.3111931074209018, 'contact_force_min': -1.203725980087081, 'contact_force_max': 1.096556291090194, 'learning_rate': 4.0835602246749295e-05, 'learning_starts': 7000, 'batch_size': 512, 'gamma': 0.9383780074010117, 'tau': 0.019780283115790283, 'noise_std': 0.1021604941204195, 'noise_clip': 0.3535995445840996, 'policy_delay': 2, 'train_freq': 10, 'gradient_steps': 1}. Best is trial 0 with value: 1908.7595740269455.
# [I 2025-02-18 09:37:57,762] Trial 2 finished with value: 1039.2157514941691 and parameters: {'reset_noise_scale': 0.020502951712440976, 'forward_reward_weight': 1.6550565896193812, 'ctrl_cost_weight': 1.4871007326228975, 'healthy_reward': 2.4116716663025963, 'contact_cost_weight': 9.877146595209113e-05, 'healthy_z_lower': 0.3108497603217022, 'healthy_z_upper': 1.3700837442977465, 'contact_force_min': -1.1729529059377544, 'contact_force_max': 0.9399518766470714, 'learning_rate': 0.00011770051367968489, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9589716947209256, 'tau': 0.04634749436067831, 'noise_std': 0.47926107589782463, 'noise_clip': 0.23727917734123627, 'policy_delay': 3, 'train_freq': 7, 'gradient_steps': 9}. Best is trial 0 with value: 1908.7595740269455.
# [I 2025-02-18 09:38:57,353] Trial 3 finished with value: 1997.5454817285156 and parameters: {'reset_noise_scale': 0.2189940055269433, 'forward_reward_weight': 1.6786929193343678, 'ctrl_cost_weight': 1.512239956353252, 'healthy_reward': 2.2508118154274275, 'contact_cost_weight': 6.035315261483589e-05, 'healthy_z_lower': 0.10555728473063387, 'healthy_z_upper': 1.1588481436840419, 'contact_force_min': -1.134063580321412, 'contact_force_max': 0.8462397031395735, 'learning_rate': 0.00024679724419146505, 'learning_starts': 10000, 'batch_size': 512, 'gamma': 0.9512085148362904, 'tau': 0.025615165306503578, 'noise_std': 0.22115184460322646, 'noise_clip': 0.2882580403733054, 'policy_delay': 3, 'train_freq': 9, 'gradient_steps': 6}. Best is trial 3 with value: 1997.5454817285156.
. Best is trial 4 with value: 1998.41974148918.
# [I 2025-02-18 10:12:50,417] Trial 13 finished with value: 1931.0029923641077 and parameters: {'reset_noise_scale': 0.23680758179291833, 'forward_reward_weight': 1.6445255834264492, 'ctrl_cost_weight': 1.4006228034912178, 'healthy_reward': 2.4998684582293036, 'contact_cost_weight': 2.7480698587255177e-05, 'healthy_z_lower': 0.39097071277994894, 'healthy_z_upper': 1.2721712302654549, 'contact_force_min': -1.1337401476412905, 'contact_force_max': 0.996154816317641, 'learning_rate': 0.00028028868628516684, 'learning_starts': 4000, 'batch_size': 512, 'gamma': 0.9532366796730607, 'tau': 0.011497091797391425, 'noise_std': 0.28025213921643716, 'noise_clip': 0.3109432414201258, 'policy_delay': 2, 'train_freq': 3, 'gradient_steps': 3}. Best is trial 4 with value: 1998.41974148918.
# [I 2025-02-18 10:14:18,408] Trial 14 finished with value: 1951.761835894615 and parameters: {'reset_noise_scale': 0.17495949288552823, 'forward_reward_weight': 1.714994159425056, 'ctrl_cost_weight': 1.3987758875468643, 'healthy_reward': 2.299975095970417, 'contact_cost_weight': 6.341396631260437e-05, 'healthy_z_lower': 0.21248204580549435, 'healthy_z_upper': 1.1932470075910921, 'contact_force_min': -1.265879985180473, 'contact_force_max': 0.8442639314750386, 'learning_rate': 6.299730783696625e-05, 'learning_starts': 5000, 'batch_size': 512, 'gamma': 0.9448385844921129, 'tau': 0.02855667839224409, 'noise_std': 0.129912128093644, 'noise_clip': 0.4833753453444042, 'policy_delay': 1, 'train_freq': 6, 'gradient_steps': 5}. Best is trial 4 with value: 1998.41974148918.
# [I 2025-02-18 10:17:47,516] Trial 15 finished with value: 1865.973017736699 and parameters: {'reset_noise_scale': 0.2986599883698767, 'forward_reward_weight': 1.6354268114386843, 'ctrl_cost_weight': 1.3065199840181332, 'healthy_reward': 2.4105234783004206, 'contact_cost_weight': 5.273297327665221e-05, 'healthy_z_lower': 0.13633012552517004, 'healthy_z_upper': 1.1037714216844579, 'contact_force_min': -1.1645477870057714, 'contact_force_max': 0.98071758652038, 'learning_rate': 0.0001723434234424706, 'learning_starts': 9000, 'batch_size': 512, 'gamma': 0.9531954709277242, 'tau': 0.03441537115913893, 'noise_std': 0.2813684155052278, 'noise_clip': 0.2985451947110873, 'policy_delay': 2, 'train_freq': 2, 'gradient_steps': 7}. Best is trial 4 with value: 1998.41974148918.
# [I 2025-02-18 10:19:01,080] Trial 16 finished with value: 2192.3353770538697 and parameters: {'reset_noise_scale': 0.24921388807855813, 'forward_reward_weight': 1.6348003730010006, 'ctrl_cost_weight': 1.3592840362505747, 'healthy_reward': 2.369541630669224, 'contact_cost_weight': 2.531900136116385e-05, 'healthy_z_lower': 0.27141903755915303, 'healthy_z_upper': 1.2696870938459157, 'contact_force_min': -1.1142599247656884, 'contact_force_max': 0.8473626775572939, 'learning_rate': 0.0005415527020062639, 'learning_starts': 1000, 'batch_size': 256, 'gamma': 0.9385208567087783, 'tau': 0.01465736144651368, 'noise_std': 0.16480325924451372, 'noise_clip': 0.42425998481277466, 'policy_delay': 2, 'train_freq': 5, 'gradient_steps': 3}. Best is trial 16 with value: 2192.3353770538697.
# [I 2025-02-18 10
 'train_freq': 7, 'gradient_steps': 3}. Best is trial 16 with value: 2192.3353770538697.
# [I 2025-02-18 10:25:05,429] Trial 22 finished with value: 2183.415923222563 and parameters: {'reset_noise_scale': 0.2348955161418841, 'forward_reward_weight': 1.8822508717051454, 'ctrl_cost_weight': 1.3533909292850355, 'healthy_reward': 2.385566706091039, 'contact_cost_weight': 1.9050617220035284e-05, 'healthy_z_lower': 0.28076559946986185, 'healthy_z_upper': 1.3199608566728014, 'contact_force_min': -1.1013695193484765, 'contact_force_max': 1.047777224706272, 'learning_rate': 0.00048798364575504177, 'learning_starts': 2000, 'batch_size': 256, 'gamma': 0.9304036123065855, 'tau': 0.01730374096367153, 'noise_std': 0.17191582907279387, 'noise_clip': 0.4066107411071238, 'policy_delay': 2, 'train_freq': 7, 'gradient_steps': 2}. Best is trial 16 with value: 2192.3353770538697.
# [I 2025-02-18 10:26:08,540] Trial 23 finished with value: 2066.6575742705445 and parameters: {'reset_noise_scale': 0.18109299672297313, 'forward_reward_weight': 1.8844736417214571, 'ctrl_cost_weight': 1.3654932127970023, 'healthy_reward': 2.308670192254982, 'contact_cost_weight': 2.4399101865762324e-05, 'healthy_z_lower': 0.2785570822841676, 'healthy_z_upper': 1.3208714822648249, 'contact_force_min': -1.0571593187053894, 'contact_force_max': 1.0415190489259296, 'learning_rate': 0.0007391275622024796, 'learning_starts': 2000, 'batch_size': 256, 'gamma': 0.9309105813990989, 'tau': 0.009414306001248294, 'noise_std': 0.25151961517807464, 'noise_clip': 0.49979722579657304, 'policy_delay': 2, 'train_freq': 7, 'gradient_steps': 3}. Best is trial 16 with value: 2192.3353770538697.
# [I 2025-02-18 10:26:50,194] Trial 24 finished with value: 2175.469175363769 and parameters: {'reset_noise_scale': 0.2243100392249091, 'forward_reward_weight': 1.8515708077792596, 'ctrl_cost_weight': 1.355939953811455, 'healthy_reward': 2.391279909927834, 'contact_cost_weight': 1.1731374969793415e-06, 'healthy_z_lower': 0.2933576626469321, 'healthy_z_upper': 1.3467542652978273, 'contact_force_min': -1.105556778495086, 'contact_force_max': 0.959213493873726, 'learning_rate': 0.0005754332903562873, 'learning_starts': 3000, 'batch_size': 256, 'gamma': 0.9340468254559966, 'tau': 0.01750649590645436, 'noise_std': 0.10207279152962213, 'noise_clip': 0.40378524703687935, 'policy_delay': 2, 'train_freq': 8, 'gradient_steps': 1}. Best is trial 16 with value: 2192.3353770538697.
# [I 2025-02-18 10:27:44,877] Trial 25 finished with value: 2224.15804688314 and parameters: {'reset_noise_scale': 0.1512055860669347, 'forward_reward_weight': 1.889377939151372, 'ctrl_cost_weight': 1.4178541278644394, 'healthy_reward': 2.374220513974552, 'contact_cost_weight': 1.430227004069403e-05, 'healthy_z_lower': 0.36773524105706135, 'healthy_z_upper': 1.2213969883941993, 'contact_force_min': -1.070488295334776, 'contact_force_max': 0.9810599599292003, 'learning_rate': 0.00037303528315461046, 'learning_starts': 2000, 'batch_size': 256, 'gamma': 0.9361711791755638, 'tau': 0.005779758997061535, 'noise_std': 0.18393890769866414, 'noise_clip': 0.36134301394889323, 'policy_delay': 2, 'train_freq': 6, 'gradient_steps': 3}. Best is trial 25 with value: 2224.15804688314.
# [I 2025-02-18 10:28:41,127] Trial 26 finished with value: 2193.3304935565593 and parameters: {'reset_noise_scale': 0.13006895797242032, 'forward_reward_weight': 1.826976351730603, 'ctrl_cost_weight': 1.4314346255147126, 'healthy_reward': 2.312304011909675, 'contact_cost_weight': 1.086342823570736e-05, 'healthy_z_lower': 0.38571071456793604, 'healthy_z_upper': 1.218861686026116, 'contact_force_min': -1.0354728086960423, 'contact_force_max': 0.9814245564430397, 'learning_rate': 0.00032482008748070093, 'learning_starts': 4000, 'batch_size': 256, 'gamma': 0.9365645498227668, 'tau': 0.005821254421606782, 'noise_std': 0.1776867382107817, 'noise_clip': 0.3463777163241733, 'policy_delay': 2, 'train_freq': 6, 'gradient_steps': 4}. Best is trial 25 with value: 2224.15804688314.
# [I 2025-02-18 10:31:44,889] Trial 27 finished with value: 2253.880494498168 and parameters: {'reset_noise_scale': 0.13374196105371142, 'forward_reward_weight': 1.8296202078926296, 'ctrl_cost_weight': 1.4275270326523244, 'healthy_reward': 2.2915524070086097, 'contact_cost_weight': 1.0112690008140967e-05, 'healthy_z_lower': 0.3952126025660908, 'healthy_z_upper': 1.2085488783140155, 'contact_force_min': -1.0087154432012038, 'contact_force_max': 0.9699560528554483, 'learning_rate': 0.0002986422892309409, 'learning_starts': 4000, 'batch_size': 2048, 'gamma': 0.936731642421743, 'tau': 0.009205428578603767, 'noise_std': 0.24977234431243497, 'noise_clip': 0.3411388960595293, 'policy_delay': 2, 'train_freq': 5, 'gradient_steps': 4}. Best is trial 27 with value: 2253.880494498168.
# [I 2025-02-18 10:34:57,960] Trial 28 finished with value: 2076.022841166854 and parameters: {'reset_noise_scale': 0.1301545743807933, 'forward_reward_weight': 1.833585121958169, 'ctrl_cost_weight': 1.4360081229649202, 'healthy_reward': 2.2918219112640945, 'contact_cost_weight': 9.814997481109293e-06, 'healthy_z_lower': 0.39943776830047817, 'healthy_z_upper': 1.2109563603090294, 'contact_force_min': -1.0073395609780011, 'contact_force_max': 0.9705735182452163, 'learning_rate': 0.0003257421049773478, 'learning_starts': 5000, 'batch_size': 2048, 'gamma': 0.9411219034919536, 'tau': 0.010234786835633208, 'noise_std': 0.2637625904585856, 'noise_clip': 0.3344917661676854, 'policy_delay': 2, 'train_freq': 6, 'gradient_steps': 5}. Best is trial 27 with value: 2253.880494498168.
# [I 2025-02-18 10:36:34,315] Trial 29 finished with value: 1432.9843691915273 and parameters: {'reset_noise_scale': 0.07844994270915705, 'forward_reward_weight': 1.821331853066432, 'ctrl_cost_weight': 1.4272842300054218, 'healthy_reward': 2.198676986939185, 'contact_cost_weight': 1.1599576628339178e-05, 'healthy_z_lower': 0.3725744219412708, 'healthy_z_upper': 1.1891188389360754, 'contact_force_min': -1.03460419931133, 'contact_force_max': 1.0010202683990836, 'learning_rate': 0.0001871111823347358, 'learning_starts': 4000, 'batch_size': 1024, 'gamma': 0.936525201101709, 'tau': 0.005669853442787669, 'noise_std': 0.3431567710806709, 'noise_clip': 0.35849634081583487, 'policy_delay': 2, 'train_freq': 6, 'gradient_steps': 4}. Best is trial 27 with value: 2253.880494498168.
# [I 2025-02-18 10:39:40,015] Trial 30 finished with value: 2026.9229054615646 and parameters: {'reset_noise_scale': 0.11897953185634667, 'forward_reward_weight': 1.7816085361329912, 'ctrl_cost_weight': 1.4574874678966714, 'healthy_reward': 2.316520640079005, 'contact_cost_weight': 6.201924902636163e-06, 'healthy_z_lower': 0.36387514926260783, 'healthy_z_upper': 1.2291182072672189, 'contact_force_min': -1.0736332701777345, 'contact_force_max': 0.9217937013158582, 'learning_rate': 6.778689904643382e-05, 'learning_starts': 4000, 'batch_size': 2048, 'gamma': 0.9448939783754086, 'tau': 0.008592230344570718, 'noise_std': 0.24275327678003608, 'noise_clip': 0.32917751252119, 'policy_delay': 2, 'train_freq': 5, 'gradient_steps': 4}. Best is trial 27 with value: 2253.880494498168.
# [I 2025-02-18 10:43:16,410] Trial 31 finished with value: 2311.489730344368 and parameters: {'reset_noise_scale': 0.14814717173043535, 'forward_reward_weight': 1.7261876981250588, 'ctrl_cost_weight': 1.4013757260540334, 'healthy_reward': 2.358021373668937, 'contact_cost_weight': 1.2909722225196873e-05, 'healthy_z_lower': 0.38043252156177787, 'healthy_z_upper': 1.1971130949273712, 'contact_force_min': -1.0269989663753971, 'contact_force_max': 0.9863886656721899, 'learning_rate': 0.00033393349570452947, 'learning_starts': 6000, 'batch_size': 2048, 'gamma': 0.9396005989564142, 'tau': 0.011363966456244746, 'noise_std': 0.17202693563859653, 'noise_clip': 0.3740590015269449, 'policy_delay': 2, 'train_freq': 4, 'gradient_steps': 4}. Best is trial 31 with value: 2311.489730344368.
# [I 2025-02-18 10:45:54,219] Trial 32 finished with value: 2167.8312412961295 and parameters: {'reset_noise_scale': 0.14710607460919117, 'forward_reward_weight': 1.7712885132257545, 'ctrl_cost_weight': 1.4106677120615243, 'healthy_reward': 2.2684153682539083, 'contact_cost_weight': 1.310367477741058e-05, 'healthy_z_lower': 0.38231822637907803, 'healthy_z_upper': 1.1957278035124728, 'contact_force_min': -1.0022641896618472, 'contact_force_max': 1.0103077275341137, 'learning_rate': 0.0003237980271103652, 'learning_starts': 6000, 'batch_size': 2048, 'gamma': 0.9363919935828809, 'tau': 0.012293376628233222, 'noise_std': 0.18608754173224384, 'noise_clip': 0.37209098319502043, 'policy_delay': 2, 'train_freq': 6, 'gradient_steps': 4}. Best is trial 31 with value: 2311.489730344368.
# [I 2025-02-18 10:50:24,691] Trial 33 finished with value: 2182.5671838171875 and parameters: {'reset_noise_scale': 0.0939398800215625, 'forward_reward_weight': 1.719615021429754, 'ctrl_cost_weight': 1.4636136009645464, 'healthy_reward': 2.328606770066729, 'contact_cost_weight': 1.4427578527525008e-05, 'healthy_z_lower': 0.3528832728615465, 'healthy_z_upper': 1.2469944734471445, 'contact_force_min': -1.0323200566836241, 'contact_force_max': 0.9870256192777184, 'learning_rate': 0.00035572914395599046, 'learning_starts': 5000, 'batch_size': 2048, 'gamma': 0.9397349799973964, 'tau': 0.009647970138522886, 'noise_std': 0.13763184457545524, 'noise_clip': 0.3458072755131433, 'policy_delay': 2, 'train_freq': 4, 'gradient_steps': 5}. Best is trial 31 with value: 2311.489730344368.
# [I 2025-02-18 10:55:58,234] Trial 34 finished with value: 2022.6966078916378 and parameters: {'reset_noise_scale': 0.0458742368873092, 'forward_reward_weight': 1.7623726484145674, 'ctrl_cost_weight': 1.51005309483608, 'healthy_reward': 2.283396644076827, 'contact_cost_weight': 1.2441926257215854e-06, 'healthy_z_lower': 0.39656512538261207, 'healthy_z_upper': 1.1794815969538708, 'contact_force_min': -1.0001145155997015, 'contact_force_max': 0.9509114763626912, 'learning_rate': 0.00021985826037263802, 'learning_starts': 6000, 'batch_size': 2048, 'gamma': 0.
 'gradient_steps': 7}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 11:18:05,280] Trial 39 finished with value: 1528.2158082024735 and parameters: {'reset_noise_scale': 0.20055951752015166, 'forward_reward_weight': 1.8649840032243252, 'ctrl_cost_weight': 1.3870509401026354, 'healthy_reward': 2.1387433673474865, 'contact_cost_weight': 4.140283771694104e-05, 'healthy_z_lower': 0.3561057781038553, 'healthy_z_upper': 1.1677602634864022, 'contact_force_min': -1.2206977121013927, 'contact_force_max': 0.9177732440142895, 'learning_rate': 9.084204525651094e-05, 'learning_starts': 5000, 'batch_size': 2048, 'gamma': 0.9451810329935173, 'tau': 0.013369947434442957, 'noise_std': 0.3072142958900536, 'noise_clip': 0.3770179818339329, 'policy_delay': 3, 'train_freq': 3, 'gradient_steps': 8}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 11:26:45,891] Trial 40 finished with value: 2234.3760044147257 and parameters: {'reset_noise_scale': 0.01247249782653903, 'forward_reward_weight': 1.896353598804824, 'ctrl_cost_weight': 1.4164412305503935, 'healthy_reward': 2.1440483386434988, 'contact_cost_weight': 8.276416276620193e-05, 'healthy_z_lower': 0.31966997574829387, 'healthy_z_upper': 1.203659089887021, 'contact_force_min': -1.1514135849097769, 'contact_force_max': 0.9515328843539839, 'learning_rate': 0.0001392957211137082, 'learning_starts': 7000, 'batch_size': 2048, 'gamma': 0.946326688338766, 'tau': 0.025075157523093687, 'noise_std': 0.19160560212225378, 'noise_clip': 0.3931853129554511, 'policy_delay': 3, 'train_freq': 2, 'gradient_steps': 6}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 11:35:21,963] Trial 41 finished with value: 1565.9800027463457 and parameters: {'reset_noise_scale': 0.019013187207493926, 'forward_reward_weight': 1.895948008831939, 'ctrl_cost_weight': 1.4189756422695583, 'healthy_reward': 2.124064916438262, 'contact_cost_weight': 8.446335129135292e-05, 'healthy_z_lower': 0.37824926571597206, 'healthy_z_upper': 1.2062644681946193, 'contact_force_min': -1.1562479875777252, 'contact_force_max': 0.9504658851941846, 'learning_rate': 0.00014433419561397497, 'learning_starts': 7000, 'batch_size': 2048, 'gamma': 0.9460528770139949, 'tau': 0.025893637588036738, 'noise_std': 0.2003811001077928, 'noise_clip': 0.3846759848056003, 'policy_delay': 3, 'train_freq': 2, 'gradient_steps': 6}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 11:43:54,988] Trial 42 finished with value: 1449.4919179212302 and parameters: {'reset_noise_scale': 0.0069293339617607225, 'forward_reward_weight': 1.860682775690792, 'ctrl_cost_weight': 1.4413372754281084, 'healthy_reward': 2.155514484015522, 'contact_cost_weight': 9.66552129464367e-05, 'healthy_z_lower': 0.318824631930482, 'healthy_z_upper': 1.1778613547637462, 'contact_force_min': -1.1914994948056583, 'contact_force_max': 0.9106275554741331, 'learning_rate': 6.913003905145666e-05, 'learning_starts': 8000, 'batch_size': 2048, 'gamma': 0.9465063235749372, 'tau': 0.020488722243539544, 'noise_std': 0.1937063856968706, 'noise_clip': 0.36716476113786434, 'policy_delay': 3, 'train_freq': 2, 'gradient_steps': 6}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 11:48:50,805] Trial 43 finished with value: 1946.9700946440446 and parameters: {'reset_noise_scale': 0.04507407961362028, 'forward_reward_weight': 1.8759973693197125, 'ctrl_cost_weight': 1.3769095493904244, 'healthy_reward': 2.1014919484716654, 'contact_cost_weight': 7.456994589890103e-05, 'healthy_z_lower': 0.348166546417013, 'healthy_z_upper': 1.234601601443812, 'contact_force_min': -1.1757889429493116, 'contact_force_max': 0.9612361364719244, 'learning_rate': 0.0002541179827704066, 'learning_starts': 8000, 'batch_size': 2048, 'gamma': 0.9475583600137237, 'tau': 0.022848345868851875, 'noise_std': 0.21153980890388435, 'noise_clip': 0.39368178234184636, 'policy_delay': 3, 'train_freq': 3, 'gradient_steps': 5}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 11:53:12,397] Trial 44 finished with value: 1692.2585213535372 and parameters: {'reset_noise_scale': 0.1908265342677037, 'forward_reward_weight': 1.838327595826113, 'ctrl_cost_weight': 1.340803473049589, 'healthy_reward': 2.2320234627388604, 'contact_cost_weight': 1.5369334214607495e-05, 'healthy_z_lower': 0.3651573354951331, 'healthy_z_upper': 1.2025634303640318, 'contact_force_min': -1.1463483084351955, 'contact_force_max': 0.9405714381462013, 'learning_rate': 3.93788841274987e-05, 'learning_starts': 6000, 'batch_size': 2048, 'gamma': 0.9416398960489836, 'tau': 0.032198375721371644, 'noise_std': 0.26197370887534754, 'noise_clip': 0.3403692049497151, 'policy_delay': 3, 'train_freq': 5, 'gradient_steps': 7}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 11:57:49,531] Trial 45 finished with value: 1588.211394615725 and parameters: {'reset_noise_scale': 0.15794188461860315, 'forward_reward_weight': 1.7425934289625773, 'ctrl_cost_weight': 1.4501280400631242, 'healthy_reward': 2.1924556424347377, 'contact_cost_weight': 5.047916698828731e-05, 'healthy_z_lower': 0.3042750936569524, 'healthy_z_upper': 1.2279420767785758, 'contact_force_min': -1.2171383703147316, 'contact_force_max': 0.8837929918208156, 'learning_rate': 0.00020307862237179566, 'learning_starts': 7000, 'batch_size': 2048, 'gamma': 0.9493162405908685, 'tau': 0.025513094336451488, 'noise_std': 0.2222660079992863, 'noise_clip': 0.20541155038696307, 'policy_delay': 3, 'train_freq': 4, 'gradient_steps': 6}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 11:59:34,653] Trial 46 finished with value: 2229.303785519302 and parameters: {'reset_noise_scale': 0.04759391555142866, 'forward_reward_weight': 1.895790973082321, 'ctrl_cost_weight': 1.5077149854491863, 'healthy_reward': 2.4052783506228486, 'contact_cost_weight': 6.97442897111752e-05, 'healthy_z_lower': 0.38253131966695203, 'healthy_z_upper': 1.1546046945435202, 'contact_force_min': -1.254958844476713, 'contact_force_max': 0.9972723819502675, 'learning_rate': 0.0001500747188896999, 'learning_starts': 5000, 'batch_size': 1024, 'gamma': 0.943633865948463, 'tau': 0.00823476649680571, 'noise_std': 0.11889226516450727, 'noise_clip': 0.3182225104935072, 'policy_delay': 3, 'train_freq': 10, 'gradient_steps': 8}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 12:01:31,784] Trial 47 finished with value: 2216.462061107941 and parameters: {'reset_noise_scale': 0.035107190272974334, 'forward_reward_weight': 1.8726941316466743, 'ctrl_cost_weight': 1.539326154178291, 'healthy_reward': 2.4034286726619096, 'contact_cost_weight': 8.83206353084792e-05, 'healthy_z_lower': 0.3876127968805172, 'healthy_z_upper': 1.1536914932820217, 'contact_force_min': -1.258074435969355, 'contact_force_max': 1.0070190981838598, 'learning_rate': 8.540170043304466e-05, 'learning_starts': 5000, 'batch_size': 1024, 'gamma': 0.9440819860909829, 'tau': 0.019224819674000037, 'noise_std': 0.12049249911362682, 'noise_clip': 0.3224912687049908, 'policy_delay': 3, 'train_freq': 10, 'gradient_steps': 10}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 12:14:06,622] Trial 48 finished with value: 1920.0067419832194 and parameters: {'reset_noise_scale': 0.061592305323421755, 'forward_reward_weight': 1.8586788582485803, 'ctrl_cost_weight': 1.590358801054428, 'healthy_reward': 2.4319326494776448, 'contact_cost_weight': 7.860776895242093e-05, 'healthy_z_lower': 0.39933068449685344, 'healthy_z_upper': 1.128798950493979, 'contact_force_min': -1.245728075410634, 'contact_force_max': 0.9353727546890499, 'learning_rate': 0.00014517726500649854, 'learning_starts': 5000, 'batch_size': 1024, 'gamma': 0.9479093965906561, 'tau': 0.030582111960784253, 'noise_std': 0.13858341096568888, 'noise_clip': 0.27985747326927085, 'policy_delay': 3, 'train_freq': 1, 'gradient_steps': 9}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 12:15:49,394] Trial 49 finished with value: 1754.9599621015786 and parameters: {'reset_noise_scale': 0.0005851410132533957, 'forward_reward_weight': 1.8998406337604636, 'ctrl_cost_weight': 1.5415409412345225, 'healthy_reward': 2.1672367703073587, 'contact_cost_weight': 6.779416920417466e-05, 'healthy_z_lower': 0.3832213208329481, 'healthy_z_upper': 1.1786833411067645, 'contact_force_min': -1.2682972520274234, 'contact_force_max': 0.9073032465182047, 'learning_rate': 0.00011455352295973368, 'learning_starts': 6000, 'batch_size': 1024, 'gamma': 0.9398021597536114, 'tau': 0.038064592232502796, 'noise_std': 0.10003781319574785, 'noise_clip': 0.3161273069928186, 'policy_delay': 3, 'train_freq': 9, 'gradient_steps': 8}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 12:24:31,405] Trial 50 finished with value: 1903.1144421259385 and parameters: {'reset_noise_scale': 0.023188650339277014, 'forward_reward_weight': 1.8447080552042294, 'ctrl_cost_weight': 1.5038771886882876, 'healthy_reward': 2.121016988206065, 'contact_cost_weight': 8.420809725929142e-05, 'healthy_z_lower': 0.295157330342863, 'healthy_z_upper': 1.1372605166421546, 'contact_force_min': -1.1839870135897523, 'contact_force_max': 0.9925252746764723, 'learning_rate': 0.000156510624376613, 'learning_starts': 6000, 'batch_size': 2048, 'gamma': 0.9526109303098079, 'tau': 0.011112285182505711, 'noise_std': 0.1146039144978743, 'noise_clip': 0.2973361809048129, 'policy_delay': 3, 'train_freq': 3, 'gradient_steps': 9}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 12:30:08,778] Trial 51 finished with value: 2237.1178181493924 and parameters: {'reset_noise_scale': 0.10765591741427327, 'forward_reward_weight': 1.8880591325251956, 'ctrl_cost_weight': 1.409813894928349, 'healthy_reward': 2.3352373079707385, 'contact_cost_weight': 5.936981133780856e-05, 'healthy_z_lower': 0.3672482044302942, 'healthy_z_upper': 1.16239828446485, 'contact_force_min': -1.0184846715013096, 'contact_force_max': 0.9731812161177372, 'learning_rate': 0.0002385281353805884, 'learning_starts': 3000, 'batch_size': 1024, 'gamma': 0.937647055691266, 'tau': 0.008297128747674385, 'noise_std': 0.19201402044750102, 'noise_clip': 0.3556970060532877, 'policy_delay': 3, 'train_freq': 2, 'gradient_steps': 7}. Best is trial 37 with value: 2555.160988201676.
# [I 2025-02-18 12:36:29,560] Trial 52 finished with value: 2521.77550741236 and parameters: {'reset_noise_scale': 0.11168120969706122, 'forward_reward_weight': 1.6884450776286686, 'ctrl_cost_weight': 1.4033990469627777, 'healthy_reward': 2.3455008675483064, 'contact_cost_weight': 5.991981398952386e-05, 'healthy_z_lower': 0.3577775935330352, 'healthy_z_upper': 1.1636849383067172, 'contact_force_min': -1.0189110928107314, 'contact_force_max': 0.9676220303679028, 'learning_rate': 0.0002623353335541491, 'learning_starts': 3000, 'batch_size': 1024, 'gamma': 0
# [I 2025-02-18 15:15:43,417] Trial 58 finished with value: 2181.4310719537048 and parameters: {'reset_noise_scale': 0.09593149156976012, 'forward_reward_weight': 1.6889072044893214, 'ctrl_cost_weight': 1.3923312028908443, 'healthy_reward': 2.2671230494678087, 'contact_cost_weight': 4.362387196953862e-05, 'healthy_z_lower': 0.3735741502082182, 'healthy_z_upper': 1.1865537970396374, 'contact_force_min': -1.0110834724785605, 'contact_force_max': 1.0191094354375947, 'learning_rate': 0.0002819228011844717, 'learning_starts': 3000, 'batch_size': 1024, 'gamma': 0.9416587122137728, 'tau': 0.014546520931901927, 'noise_std': 0.22060035573582096, 'noise_clip': 0.35240974780478335, 'policy_delay': 3, 'train_freq': 3, 'gradient_steps': 6}. Best is trial 37 with value: 2555.160988201676.
# [W 2025-02-18 15:16:04,413] Trial 59 failed with parameters: {'reset_noise_scale': 0.1190383741654353, 'forward_reward_weight': 1.7286027877883257, 'ctrl_cost_weight': 1.4711768379965464, 'healthy_reward': 2.362379845423811, 'contact_cost_weight': 3.832029161484234e-05, 'healthy_z_lower': 0.32909849511822126, 'healthy_z_upper': 1.2571226566375626, 'contact_force_min': -1.0839396382125368, 'contact_force_max': 0.9689945021684566, 'learning_rate': 1.8175528733262178e-05, 'learning_starts': 4000, 'batch_size': 1024, 'gamma': 0.9390831848245615, 'tau': 0.013230606418659578, 'noise_std': 0.4020963664164528, 'noise_clip': 0.2278517801252003, 'policy_delay': 3, 'train_freq': 4, 'gradient_steps': 5} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Users/fabiodigregorio/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/d5/8f8lxk3x1gddrb19zv8xl57m0000gn/T/ipykernel_14319/1405304250.py", line 58, in objective
#     model.learn(total_timesteps=50000)
#   File "/Users/fabiodigregorio/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/td3/td3.py", line 222, in learn
#     return super().learn(
#   File "/Users/fabiodigregorio/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py", line 347, in learn
#     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#   File "/Users/fabiodigregorio/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/td3/td3.py", line 188, in train
#     critic_loss.backward()
#   File "/Users/fabiodigregorio/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/torch/_tensor.py", line 626, in backward
#     torch.autograd.backward(
#   File "/Users/fabiodigregorio/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/Users/fabiodigregorio/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
# [W 2025-02-18 15:16:04,416] Trial 59 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 70
#      67     return mean_reward
#      69 study = optuna.create_study(direction='maximize')
# ---> 70 study.optimize(objective, n_trials=300)
#      72 print("Best hyperparameters: ", study.best_params)
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[9], line 58, in objective(trial)
#      43 action_noise = NormalActionNoise(mean=np.zeros(8), sigma=noise_std * np.ones(8))
#      45 model = TD3("MlpPolicy", env,
#      46             learning_rate=learning_rate,
#      47             buffer_size=50000,
#    (...)
#      56             seed=42,
#      57             verbose=0)
# ---> 58 model.learn(total_timesteps=50000)
#      60 episodes = 200
#      61 mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=episodes)
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:188, in TD3.train(self, gradient_steps, batch_size)
#     186 # Optimize the critics
#     187 self.critic.optimizer.zero_grad()
# --> 188 critic_loss.backward()
#     189 self.critic.optimizer.step()
#     191 # Delayed policy updates
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Desktop/campus bio iscrizione/ Magistrale/Merone/RL/Reinforcement_Learning_Ant_MuJoCu/venv/lib/python3.10/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:
